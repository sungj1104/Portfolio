# %%
import requests
from bs4 import BeautifulSoup
import xmltodict

# %% [markdown]
# # 영화진흥위원회 api
#
# - 예시 url

# %%
url = "	http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20120101"

res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
data = res.json()

# %%
data
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20120101~20120101',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20112207',
#     'movieNm': '미션임파서블:고스트프로토콜',
#     'openDt': '2011-12-15',
#     'salesAmt': '2776060500',
#     'salesShare': '36.3',
#     'salesInten': '-415699000',
#     'salesChange': '-13',
#     'salesAcc': '40541108500',
#     'audiCnt': '353274',
#     'audiInten': '-60106',
#     'audiChange': '-14.5',
#     'audiAcc': '5328435',
#     'scrnCnt': '697',
#     'showCnt': '3223'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20110295',
#     'movieNm': '마이 웨이',
#     'openDt': '2011-12-21',
#     'salesAmt': '1189058500',
#     'salesShare': '15.6',
#     'salesInten': '-105894500',
#     'salesChange': '-8.2',
#     'salesAcc': '13002897500',
#     'audiCnt': '153501',
# ...

# %% [markdown]
# - 개인 키

# %%
url = "	http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=d6c9909e50a58cd098264c4392cbdf27&targetDt=20240122"

res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
data = res.json()

# %%
data
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20240122~20240122',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20235253',
#     'movieNm': '외계+인 2부',
#     'openDt': '2024-01-10',
#     'salesAmt': '274438190',
#     'salesShare': '30.9',
#     'salesInten': '-824392230',
#     'salesChange': '-75',
#     'salesAcc': '10884908623',
#     'audiCnt': '28746',
#     'audiInten': '-82725',
#     'audiChange': '-74.2',
#     'audiAcc': '1121624',
#     'scrnCnt': '1223',
#     'showCnt': '4160'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20235834',
#     'movieNm': '위시',
#     'openDt': '2024-01-03',
#     'salesAmt': '131548445',
#     'salesShare': '14.8',
#     'salesInten': '-367576762',
#     'salesChange': '-73.6',
#     'salesAcc': '11765205471',
#     'audiCnt': '14157',
#     'audiInten': '-37025',
# ...

# %%
for i in data["boxOfficeResult"]["dailyBoxOfficeList"]:
    print(i["movieNm"])
# Out:
# 외계+인 2부
# 위시
# 서울의 봄
# 노량: 죽음의 바다
# 인투 더 월드
# 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 길위에 김대중
# 덤 머니
# 괴물
# 엔드 오브 에반게리온

# %%
key = "d6c9909e50a58cd098264c4392cbdf27"

url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json"

params = {"key" : key,
         "targetDt" : "20240121",
         "repNationCd" : "K"}

res= requests.get(url, params = params)

# %%
res
# Out:
# <Response [200]>

# %%
res.url
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=d6c9909e50a58cd098264c4392cbdf27&targetDt=20240121&repNationCd=K'

# %%
res.json()
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20240121~20240121',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20235253',
#     'movieNm': '외계+인 2부',
#     'openDt': '2024-01-10',
#     'salesAmt': '1098830420',
#     'salesShare': '56.8',
#     'salesInten': '-42646600',
#     'salesChange': '-3.7',
#     'salesAcc': '10610470433',
#     'audiCnt': '111471',
#     'audiInten': '-3399',
#     'audiChange': '-3',
#     'audiAcc': '1092878',
#     'scrnCnt': '1356',
#     'showCnt': '5009'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20212866',
#     'movieNm': '서울의 봄',
#     'openDt': '2023-11-22',
#     'salesAmt': '337249165',
#     'salesShare': '17.4',
#     'salesInten': '-44540749',
#     'salesChange': '-11.7',
#     'salesAcc': '126213474803',
#     'audiCnt': '33327',
#     'audiInten': '-4404',
# ...

# %% [markdown]
# # 네이버 검색 api

# %%
url = "https://openapi.naver.com/v1/search/blog.json"

word = "신촌 맛집"

params = {"query" : word}

headers = {"X-Naver-Client-ID" : "6KH_tnTykMsXq0nYqo7i",
          "X-Naver-Client-Secret" : "dKUPws6gHa"}

res = requests.get(url, params = params, headers = headers)

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'lastBuildDate': 'Tue, 23 Jan 2024 09:45:46 +0900',
#  'total': 212719,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>신촌 맛집</b> | 신촌 스테이크, 이빠네마 그릴',
#    'link': 'https://blog.naver.com/happygirlbg/223284079874',
#    'description': '딱 그 맛, 그냥 헤어지기 아쉬워 근처 카페에 가서 차 한 잔 하며 마무리해줬네요〰️ 연말 <b>신촌 맛집</b>이나 신촌 스테이크 가게 찾으시는 분들에게 조금이나마 도움되길 바라며 글 마무리할게요, 편안한 하루... ',
#    'bloggername': '크고 넓게 하늘을 날 고 싶 다.',
#    'bloggerlink': 'blog.naver.com/happygirlbg',
#    'postdate': '20231205'},
#   {'title': '<b>신촌 맛집</b> 아소비바 등심 안심카츠 돈까스',
#    'link': 'https://blog.naver.com/jjakggung/223299322077',
#    'description': '특별활동을 일찍 끝난 딸과 함께 오랫만에 신촌나들이, 맛나는 돈까스 먹고, 홍익문고 들려 문구 한가득 담고, 스벅에서 커피로 마무리까지... 날씨가 추워서 어떨까 싶었는데 이런것도 추억!!! <b>신촌 맛집</b>... ',
#    'bloggername': '더 이상 뚱뚱하지 않을 다이어리;노뚱줌의 식도락여행',
#    'bloggerlink': 'blog.naver.com/jjakggung',
#    'postdate': '20231221'},
#   {'title': '<b>신촌맛집</b> 신촌칼국수 김광석 신촌칼국수',
#    'link': 'https://blog.naver.com/crew0729/223330709774',
# ...

# %% [markdown]
# # imdb

# %%
url = "https://www.imdb.com/chart/top/"

res = requests.get(url)

# %%
res
# Out:
# <Response [403]>

# %%
res.text
# Out:
# '<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body>\r\n<center><h1>403 Forbidden</h1></center>\r\n</body>\r\n</html>\r\n'

# %%
url = "https://www.imdb.com/chart/top/"

headers = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}

res = requests.get(url, headers = headers)

# %%
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1705973034726);
#         }
# ...

# %%
soup.select("div.cli-children h3.ipc-title__text")
# Out:
# [<h3 class="ipc-title__text">1. 쇼생크 탈출</h3>,
#  <h3 class="ipc-title__text">2. Daeboo</h3>,
#  <h3 class="ipc-title__text">3. 다크 나이트</h3>,
#  <h3 class="ipc-title__text">4. The Godfather Part II</h3>,
#  <h3 class="ipc-title__text">5. 12명의 성난 사람들</h3>,
#  <h3 class="ipc-title__text">6. 쉰들러 리스트</h3>,
#  <h3 class="ipc-title__text">7. 반지의 제왕: 왕의 귀환</h3>,
#  <h3 class="ipc-title__text">8. 펄프 픽션</h3>,
#  <h3 class="ipc-title__text">9. 반지의 제왕: 반지 원정대</h3>,
#  <h3 class="ipc-title__text">10. 석양의 무법자</h3>,
#  <h3 class="ipc-title__text">11. 포레스트 검프</h3>,
#  <h3 class="ipc-title__text">12. 파이트 클럽</h3>,
#  <h3 class="ipc-title__text">13. The Lord of the Rings: The Two Towers</h3>,
#  <h3 class="ipc-title__text">14. 인셉션</h3>,
#  <h3 class="ipc-title__text">15. 스타워즈 에피소드 5 - 제국의 역습</h3>,
#  <h3 class="ipc-title__text">16. 매트릭스</h3>,
#  <h3 class="ipc-title__text">17. 좋은 친구들</h3>,
#  <h3 class="ipc-title__text">18. 뻐꾸기 둥지 위로 날아간 새</h3>,
#  <h3 class="ipc-title__text">19. 세븐</h3>,
# ...

# %%
url = "https://www.imdb.com/chart/top/"

headers = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
"Accept-Language" : "en"}

res = requests.get(url, headers = headers)

# %%
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, "lxml")
soup.select("div.cli-children h3.ipc-title__text")
# Out:
# [<h3 class="ipc-title__text">1. The Shawshank Redemption</h3>,
#  <h3 class="ipc-title__text">2. The Godfather</h3>,
#  <h3 class="ipc-title__text">3. The Dark Knight</h3>,
#  <h3 class="ipc-title__text">4. The Godfather Part II</h3>,
#  <h3 class="ipc-title__text">5. 12 Angry Men</h3>,
#  <h3 class="ipc-title__text">6. Schindler's List</h3>,
#  <h3 class="ipc-title__text">7. The Lord of the Rings: The Return of the King</h3>,
#  <h3 class="ipc-title__text">8. Pulp Fiction</h3>,
#  <h3 class="ipc-title__text">9. The Lord of the Rings: The Fellowship of the Ring</h3>,
#  <h3 class="ipc-title__text">10. The Good, the Bad and the Ugly</h3>,
#  <h3 class="ipc-title__text">11. Forrest Gump</h3>,
#  <h3 class="ipc-title__text">12. Fight Club</h3>,
#  <h3 class="ipc-title__text">13. The Lord of the Rings: The Two Towers</h3>,
#  <h3 class="ipc-title__text">14. Inception</h3>,
#  <h3 class="ipc-title__text">15. Star Wars: Episode V - The Empire Strikes Back</h3>,
# ...

# %% [markdown]
# ## 공공데이터 포털 api
#
# - 약국 정보 조회 서비스

# %%
key = "sUcH/wCaqWYGBXIDnxw8DtVEwOJBy+VOyP0Vjekhc8/NN+QnpcyOyu+QcID8/vQ5Fxhe60/3QfsQEApZAoovbQ=="

url = "http://apis.data.go.kr/B552657/ErmctInsttInfoInqireService/getParmacyListInfoInqire"

params = {"serviceKey" : key,
         "numOfRows" : 1000}

res = requests.get(url, params = params)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><dutyAddr>경기도 안양시 만안구 박달로 518 (박달동)</dutyAddr><dutyName>1(일)약국</dutyName><dutyTel1>031-468-3354</dutyTel1><dutyTime1c>2000</dutyTime1c><dutyTime1s>0900</dutyTime1s><dutyTime2c>2000</dutyTime2c><dutyTime2s>0900</dutyTime2s><dutyTime3c>2000</dutyTime3c><dutyTime3s>0900</dutyTime3s><dutyTime4c>2000</dutyTime4c><dutyTime4s>0900</dutyTime4s><dutyTime5c>2000</dutyTime5c><dutyTime5s>0900</dutyTime5s><dutyTime6c>1700</dutyTime6c><dutyTime6s>0900</dutyTime6s><hpid>C2101741</hpid><postCdn1>140</postCdn1><postCdn2>09 </postCdn2><rnum>1</rnum><wgs84Lat>37.40242465877038</wgs84Lat><wgs84Lon>126.9102104886459</wgs84Lon></item><item><dutyAddr>경기도 남양주시 오남읍 양지로 47-63</dutyAddr><dutyName>1,2,3약국</dutyName><dutyTel1>031-529-8099</dutyTel1><dutyTime1c>1800</dutyTime1c><dutyTime1s>0900</dutyTime1s><dutyTime2c>1800</dutyTime2c><dutyTime2s>09
# ...

# %%
res_dict = xmltodict.parse(res.text)

# %%
len(res_dict["response"]["body"]["items"]["item"])
# Out:
# 1000

# %%
# 화요일 20:00 이후에 이용 가능한 약국
key = "sUcH/wCaqWYGBXIDnxw8DtVEwOJBy+VOyP0Vjekhc8/NN+QnpcyOyu+QcID8/vQ5Fxhe60/3QfsQEApZAoovbQ=="

url = "http://apis.data.go.kr/B552657/ErmctInsttInfoInqireService/getParmacyListInfoInqire"

params = {"serviceKey" : key,
         "Q0" : "서울특별시",
         "Q1" : "마포구",
         "QT" : "2",
         "numOfRows" : "1000"}

res = requests.get(url, params = params)

# %%
res_dict = xmltodict.parse(res.text)

# %%
for i in res_dict["response"]["body"]["items"]["item"]:
    if int(i["dutyTime2c"]) > 2000:
        print(i["dutyName"], " : " ,i["dutyAddr"])
# Out:
# 365열린약국  :  서울특별시 마포구 백범로 199, 메트로디오빌빌딩 108호 (신공덕동)
# delight이화약국  :  서울특별시 마포구 월드컵로3길 14, 220호 (합정동)
# 건강약국  :  서울특별시 마포구 방울내로 70, (망원동)
# 고래약국  :  서울특별시 마포구 신촌로 지하 90, 신촌역 B1 240-107호 (노고산동)
# 공덕역마트약국  :  서울특별시 마포구 백범로 212, 2층 (신공덕동, 대우 월드마크마포)
# 공덕오거리약국  :  서울특별시 마포구 새창로 11, 1층 (도화동)
# 광명약국  :  서울특별시 마포구 양화로 191, 1층 (동교동)
# 나무약국  :  서울특별시 마포구 백범로 202, 101호 (신공덕동, 마포케이씨씨웰츠타워)
# 늘푸른약국  :  서울특별시 마포구 백범로 202, 1층 102호 (신공덕동, 마포케이씨씨웰츠타워)
# 다나약국  :  서울특별시 마포구 대흥로 186-2, 1층 (대흥동)
# 대교약국  :  서울특별시 마포구 도화길 10, 1층 (도화동)
# 대흥365약국  :  서울특별시 마포구 백범로 98, 1층 (대흥동)
# 더블유스토어연세약국  :  서울특별시 마포구 신촌로 92, 1층 (노고산동, 카리스빌딩)
# 독일약국  :  서울특별시 마포구 도화4길 19, (도화동)
# 동경약국  :  서울특별시 마포구 신촌로16길 4, 1층 101호 (노고산동)
# 롱약국  :  서울특별시 마포구 양화로 지하 55, 합정역 B1  238-105호 (서교동)
# 마래푸약국  :  서울특별시 마포구 신촌로34길 37, 1층 (아현동)
# 마포보건약국  :  서울특별시 마포구 월드컵로 204, 이안상암 105호 (성산동)
# 마포삼성약국  :  서울특별시 마포구 도화길 33, 1층 우측호 (도화동)
# 마포온누리약국  :  서울특별시 마포구 큰우물로 76, 고려빌딩 101호 (도화동)
# 마포초록약국  :  서울특별시 마포구 토정로 271, 대현빌딩 1층 (용강동)
# ...
