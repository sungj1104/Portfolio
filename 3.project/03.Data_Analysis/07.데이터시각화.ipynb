# %% [markdown]
# # 데이터시각화
#
# - 데이터를 분석한 결과를 쉽게 이해할 수 있도록 표현하여 전달하는 것
# - 데이터의 시각화가 필요한 이유
#     - 많은 양의 데이터를 한 눈에 살펴볼 수 있음
#     - 전문 지식이 없더라도 누구나 쉽게 데이터를 인지하고 사용할 수 있음
#     - 단순한 데이터의 요약이나 나열보다 더 정확한 데이터 분석 결과를 얻을 수 있음
#     - 단순한 데이터에서는 알 수 없었던 중요한 정보를 파악할 수 있음
#
# - 파이썬의 시각화 라이브러리
#     - matplotlib
#         - 파이썬에서 가장 많이 사용하는 시각화 라이브러리
#         - 판다스의 데이터프레임을 바로 시각화 할 때도 내부적으로 matplotlib을 사용
#         - 데이터 분석 이전의 데이터의 이해를 위한 시각화 또는 데이터 분석 이후의 결과를 시각화하기 위해 사용
#
#     - seaborn
#         - matplotlib을 기반으로 색 테마, 차트 기능 등을 추가해주는 라이브러리
#         - matplotlib과 함께 사용하며 히트맵, 카운트플롯 등을 제공
#
#     - folium
#         - 지도 데이터를 이용하여 위치 정보를 시각화하는 라이브러리
#         - 자바스크립트 기반의 인터랙티브 그래프를 그릴 수 있음
#
#     - plotly
#         - 인터랙티브 그래프를 그려주는 라이브러리
#
#     - wordcloud

# %% [markdown]
# # 시각화 단계
#
# 1. 시각화 라이브러리 불러오기
# 2. x축, y축에 표시할 데이터 정하기
# 3. plot() 함수에 데이터 입력하기
# 4. 그래프 보여주기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# matplotlib 한글 폰트 수정
from matplotlib import font_manager, rc
import matplotlib
font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family=font_name)

# %% [markdown]
# # 그래프란
#
# - 서로 연관성이 있는 1개 또는 그 이상의 양에 대한 상대 값을 도형으로 나타내는 것

# %% [markdown]
# ## 데이터의 갯수, 데이터의 종류에 따른 그래프의 종류
#
# - 일변량(데이터 개수가 1개)
#     - 연속형
#         - 히스토그램(histogram)
#         - 상자수염 그래프(boxplot)
#         - 바이올린 그래프(violin)
#         - 커널 밀도 그래프(kernel density curve)
#
#     - 범주형
#         - 막대 그래프(bar chart)
#         - 파이 그래프(pie chart)
#
# - 다변량(데이터 개수가 2개 이상)
#     - 연속형
#         - 산점도(scatter plot)
#         - 선 그래프(line)
#         - 시계열 그래프
#
#     - 범주형
#         - 모자이크 그래프(mosaic graph)
#         - Tree Map 그래프

# %% [markdown]
# # 기본 그래프

# %%
# 기본 시각화 문법
plt.plot([1, 2 ,3, 4])
plt.ylabel("y축")
plt.show()

# %% [markdown]
# - 리스트의 값이 y값이라고 가정하고 x값을 자동으로 생성 [0, 1, 2, 3]

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], "ro")
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], "ro-") # 기본은 "b-"
plt.axis([0, 6, 0, 20]) # xmin, xmax, ymin, ymax
plt.show()

# %% [markdown]
# ## 범례 추가

# %%
plt.plot([1, 2, 3], [1, 4, 9])
plt.plot([2, 3, 4], [5, 6, 7])
plt.xlabel("Sequence")
plt.ylabel("Time(secs)")
plt.title("실험결과")
plt.legend(["쥐", "고양이"])
plt.show()

# %% [markdown]
# # 여러 개의 그래프 그리기

# %%
t = np.arange(0, 5, 0.2)
plt.plot(t, t, "r--", t, t**2, "bs", t, t**3, "g^")
plt.show()

# %% [markdown]
# <img src = "./image/matplotlib_Set_marker.png">

# %% [markdown]
# # 그래프 영역 채우기

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.xlabel("X축")
plt.ylabel("Y축")
plt.fill_between(x[1:3], y[1:3], alpha = 0.5)
plt.show()

# %%
plt.plot(x, y)
plt.xlabel("X축")
plt.ylabel("Y축")
plt.fill_betweenx(y[2:4], x[2:4], alpha = 0.5)
plt.show()

# %% [markdown]
# # 임의의 영역 채우기

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel("x축")
plt.ylabel("yㅊㄱ")
plt.fill([1.9, 1.9, 3.1, 3.1], [2, 5, 11, 8], color = 'lightgray', alpha = 0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a**2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a**3, color = "springgreen", marker = "^", markersize = 9)
plt.show()

# %% [markdown]
# # 격자 설정

# %%
plt.plot(a, a, "bo")
plt.plot(a, a**2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a**3, color = "springgreen", marker = "^", markersize = 9)
plt.grid()
plt.show()

# %%
plt.plot(a, a, "bo")
plt.plot(a, a**2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a**3, color = "springgreen", marker = "^", markersize = 9)
plt.grid(True, axis = "y", color = "red", alpha = 0.5, linestyle = "--")
plt.show()

# %% [markdown]
# # 눈금표시

# %%
plt.plot(a, a, "bo")
plt.plot(a, a**2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a**3, color = "springgreen", marker = "^", markersize = 9)

plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %%
plt.plot(a, a, "bo")
plt.plot(a, a**2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a**3, color = "springgreen", marker = "^", markersize = 9)

plt.xticks([0, 1, 2], labels = ["Jan", "Feb", "Mar"])
plt.yticks(np.arange(1, 6))

plt.show()

# %%
plt.plot(a, a, "bo")
plt.plot(a, a**2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a**3, color = "springgreen", marker = "^", markersize = 9)

plt.xticks([0, 1, 2], labels = ["Jan", "Feb", "Mar"])
plt.yticks(np.arange(1, 6))

plt.tick_params(axis = "x", direction = "inout", length = 13, pad = 6, labelsize = 14, labelcolor = "green", top = True)
plt.tick_params(axis = "y", direction = "in", length = 10, pad = 15, labelsize = 12, width = 12, color = "r")

plt.show()

# %% [markdown]
# - tick_params() : 눈금의 스타일을 설정
# - axis : 설정이 적용될 축을 지정. x, y, both 중 선택
# - diretion : 눈금이 안에서 표시될지 밖에서 표시될지. in, out, inout
# - length : 눈금의 길이
# - pad : 눈금과 레이블과의 거리
# - labelsize : 레이블의 크기
# - labelcolor : 레이블의 색상
# - top/bottom/left/right : 눈금이 표시될 위치 선택
# - width : 눈금의 너비
# - color : 눈금의 색상

# %% [markdown]
# # 꺾은선 그래프
#
# - 연속적으로 변화하는 데이터를 살펴보고자 할 때 주로 사용
#     - 시간에 따른 데이터의 연속적인 변화량을 관찰할 때
#         - 예) 시간에 따른 기온의 변화, 물을 끓인 다음 식히면서 시간에 따른 물의 온도 변화 등
# - 수량을 점으로 표시하면서 선으로 이어 그리기 때문에 증가와 감소 상태를 쉽게 확인할 수 있음

# %%
df = pd.read_csv("C:/Users/sungj/바탕 화면/project/pandas/data/주요발생국가주간동향(4월2째주).csv", index_col = "국가")
df.head()
# Out:
#        4월06일   4월07일   4월08일   4월09일   4월10일   4월11일   4월12일
# 국가
# 미국    335524  364723  387547  424945  461437  495535  524903
# 스페인   130709  135032  140510  146690  152446  157022  161852
# 이탈리아  128948  132547  135586  139422  143626  147577  152271
# 독일    100024  102453  107591  112113  118181  122171  124908
# 프랑스    70478   74390   78167   82048   86334   90276   93790

# %%
chartdata = df["4월06일"]
chartdata
# Out:
# 국가
# 미국      335524
# 스페인     130709
# 이탈리아    128948
# 독일      100024
# 프랑스      70478
# 중국       81708
# 영국       47806
# 이란       58226
# 스위스      21104
# 한국       10284
# Name: 4월06일, dtype: int64

# %%
plt.plot(chartdata)
plt.show()

# %%
plt.plot(chartdata, "b-o")
plt.grid(True)
plt.xlabel("국가명")
plt.ylabel("발생건수")
plt.title("4월 6일 코로나 발생 건수")
plt.show()

# %%
fig = plt.figure(figsize = (10, 5))

plt.plot(chartdata, "b-o")
plt.grid(True)
plt.xlabel("국가명")
plt.ylabel("발생건수")
plt.title("4월 6일 코로나 발생 건수")
plt.show()

# %%
df.head()
# Out:
#        4월06일   4월07일   4월08일   4월09일   4월10일   4월11일   4월12일
# 국가
# 미국    335524  364723  387547  424945  461437  495535  524903
# 스페인   130709  135032  140510  146690  152446  157022  161852
# 이탈리아  128948  132547  135586  139422  143626  147577  152271
# 독일    100024  102453  107591  112113  118181  122171  124908
# 프랑스    70478   74390   78167   82048   86334   90276   93790

# %%
chartdata = df.loc[["스페인", "프랑스", "독일", "중국", "영국", "이란"]]
chartdata = chartdata.T
chartdata
# Out:
# 국가        스페인    프랑스      독일     중국     영국     이란
# 4월06일  130709  70478  100024  81708  47806  58226
# 4월07일  135032  74390  102453  81740  51608  60500
# 4월08일  140510  78167  107591  81802  55242  62589
# 4월09일  146690  82048  112113  81865  60733  64586
# 4월10일  152446  86334  118181  81907  65077  66220
# 4월11일  157022  90276  122171  81953  73758  68192
# 4월12일  161852  93790  124908  82052  78991  70029

# %%
fig = plt.figure(figsize = (15, 8))
plt.plot(chartdata, marker = "o")

plt.legend(chartdata.columns, loc = "upper right")
plt.title("일자별 꺾은 선 그래프")
plt.xlabel("일자")
plt.ylabel("국가명")
plt.grid(True)
plt.show()

# %%
# 2019년도 미세먼지 선 그래프
data = pd.read_excel("./data/fine_dust.xlsx", index_col = "area")
data.head()
# Out:
#           2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# area
# Seoul     71.0  76.0  69.0  61.0  58.0    60    61  55.0  54.0  49.0    47
# Gyeonggi  71.0  74.0  68.0  67.0  65.0    68    66  60.0  60.0  58.0    56
# Incheon   52.0  57.0  61.0  62.0  61.0    68    64  57.0  60.0  55.0    55
# Busan     60.0  69.0  55.0  60.0  58.0    59    57  51.0  49.0  49.0    47
# Daegu     67.0  71.0  59.0   0.0  55.0    54    53  57.0  48.0  51.0    47
#
#           2012  2013  2014  2015  2016  2017  2018  2019
# area
# Seoul     41.0  45.0  46.0  45.0  48.0  44.0  40.0  42.0
# Gyeonggi  49.0  54.0  54.0  53.0  53.0  51.0  44.0  46.0
# Incheon   47.0  49.0  49.0  53.0  49.0  46.0  40.0  43.0
# Busan     43.0  49.0  48.0  46.0  44.0  44.0  41.0  36.0
# Daegu     42.0  45.0  45.0  46.0  43.0  42.0  39.0  39.0

# %%
plt.figure(figsize = (15, 4))
plt.plot(data[2019], "bo-")
plt.xlabel("area")
plt.ylabel("micrometer")
plt.title("2019년 미세먼지 선 그래프")
plt.grid()
plt.show()

# %%
# 2016 ~ 2019년 지역별 미세먼지 선 그래프
plt.figure(figsize = (15, 4))

for year in range(2016, 2020):
    chartdata = data[year]
    plt.plot(chartdata, "s-", label = year)
    
plt.xlabel("area")
plt.ylabel("micrometer")
plt.title("2019년 미세먼지 선 그래프")
plt.grid()
plt.show()

# %% [markdown]
# # 막대 그래프
#
# - 집단별 차이를 표현할 때 주로 사용
#     - 크고 작음의 차이를 한 눈에 파악하기 위해
#     - 예) 수량의 많고 적음 비교, 변화된 양에 대한 일별, 월별 연별 통계 등의 자료
#
# - 가독성 면에서 막대 그래프는 일반적으로 항목의 개수가 적으면 가로 막대가 보기 좋고, 항목이 많으면 세로 막대가 보기 편함

# %%
x = np.arange(3)
years = ["2022", "2023", "2024"]
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)
plt.show()

# %%
x = np.arange(3)
years = ["2022", "2023", "2024"]
values = [100, 400, 900]

plt.bar(x, values, width = 0.6)
plt.xticks(x, years)
plt.show()

# %%
x = np.arange(3)
years = ["2022", "2023", "2024"]
values = [100, 400, 900]

plt.bar(x, values, width = 0.6, align = "edge", color ="springgreen", edgecolor = "gray", linewidth = 3, tick_label = years)
plt.xticks(x, years)
plt.show()

# %%
x = np.arange(3)
years = ["2022", "2023", "2024"]
values = [100, 400, 900]

plt.bar(x, values, width = 0.6, align = "edge", color ="springgreen", edgecolor = "gray", linewidth = 3, tick_label = years, log = True)
plt.xticks(x, years)
plt.show()

# %% [markdown]
# - width : 막대의 너비
# - align : 틱과 막대의 위치, edge로 설정하면 왼쪽 끝에 표시
# - color : 막대의 색
# - edgecolor : 막대의 테두리 색
# - linewidth : 테두리의 두께
# - log : y축이 로그 스케일로 표시

# %% [markdown]
# ## 미세먼지 세로 막대 그래프
#
# - 2019년 지역별 미세먼지 세로 막대 그래프

# %%
data.head()
# Out:
#           2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# area
# Seoul     71.0  76.0  69.0  61.0  58.0    60    61  55.0  54.0  49.0    47
# Gyeonggi  71.0  74.0  68.0  67.0  65.0    68    66  60.0  60.0  58.0    56
# Incheon   52.0  57.0  61.0  62.0  61.0    68    64  57.0  60.0  55.0    55
# Busan     60.0  69.0  55.0  60.0  58.0    59    57  51.0  49.0  49.0    47
# Daegu     67.0  71.0  59.0   0.0  55.0    54    53  57.0  48.0  51.0    47
#
#           2012  2013  2014  2015  2016  2017  2018  2019
# area
# Seoul     41.0  45.0  46.0  45.0  48.0  44.0  40.0  42.0
# Gyeonggi  49.0  54.0  54.0  53.0  53.0  51.0  44.0  46.0
# Incheon   47.0  49.0  49.0  53.0  49.0  46.0  40.0  43.0
# Busan     43.0  49.0  48.0  46.0  44.0  44.0  41.0  36.0
# Daegu     42.0  45.0  45.0  46.0  43.0  42.0  39.0  39.0

# %%
plt.figure(figsize = (15, 4))
plt.bar(data[2019].index, data[2019], color = "g")

plt.xlabel("area")
plt.ylabel("micrometer")
plt.title("2019 Fine Dust Bar Graph")
plt.grid()
plt.show()

# %%
plt.figure(figsize = (15, 4))
plt.bar(data[2019].index, data[2019], color = "g")
plt.ylim(30, 50)

plt.xlabel("area")
plt.ylabel("micrometer")
plt.title("2019 Fine Dust Bar Graph")
plt.grid()
plt.show()

# %% [markdown]
# ### 그룹 세로 막대 그래프
#
# - 2016년 ~ 2019년 데이터를 막대 그래프로 그리기

# %%
index = np.arange(4)

plt.figure(figsize= (15, 4))

data_bar = data.loc["Gyeonggi" : "Daegu", 2016 : 2019]

for year in range(2016, 2020):
    chartdata = data_bar[year]
    plt.bar(index, chartdata, width = 0.2, label = year)
    index = index + 0.2
    
plt.xlabel("area")
plt.ylabel("micrometer")
plt.xticks(index - 0.5, ["Gyeonggi", "Incheon", "Busan", "Daegu"])
plt.title("2016 ~ 2019 Fine Dust Group Bar Graph")
plt.legend()
plt.show()

# %%
index = np.arange(4)

plt.figure(figsize= (15, 4))

data_bar = data.loc["Gyeonggi" : "Daegu", 2016 : 2019]

for year in range(2016, 2020):
    chartdata = data_bar[year]
    plt.bar(index, chartdata, width = 0.2, label = year)
    index = index + 0.2
    
plt.ylim(35, 55)
plt.xlabel("area")
plt.ylabel("micrometer")
plt.xticks(index - 0.5, ["Gyeonggi", "Incheon", "Busan", "Daegu"])
plt.title("2016 ~ 2019 Fine Dust Group Bar Graph")
plt.legend()
plt.show()

# %% [markdown]
# # 수평 막대 그래프

# %%
y = np.arange(3)
years = ["2022", "2023", "2024"]
values = [100, 400, 900]

plt.barh(y, values, height = -0.6, align = "edge", color = "springgreen", edgecolor = "gray", linewidth = 3, tick_label = years, log = False)
plt.show()

# %% [markdown]
# # 산점도
#
# - 서로 다른 두 연속형 변수 사이의 관계를 나타내며 연속형 변수의 상관성을 확인할 때 산점도 그래프르 사용
#     - 예) 나이와 소득에 대한 상호 관련성 파악
# - 산점도에 표시되는 각 점들은 자료의 관측값을 의미하고, 각 점의 위치는 관측값이 가지는 x축, y축 변수의 값을 결정됨

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N)) ** 2

plt.scatter(x, y, s = area, c = colors, alpha = 0.5)
plt.show()

# %% [markdown]
# # Tips 데이터 산점도 그래프

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(tips["total_bill"], tips["tip"])

axes1.set_title("Total Bill vs Tip")
axes1.set_xlabel("Total Bill")
axes1.set_ylabel("Tip")
plt.show()

# %% [markdown]
# ## 2020년 건강검진 데이터 산점도 그래프

# %%
health = pd.read_excel("./data/health_screenings_2020_1000ea.xlsx")

# %%
health.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# ...

# %% [markdown]
# ## 키, 몸무게 산점도 그래프

# %%
plt.figure(figsize= (10, 4))

plt.scatter(health["height"], health["weight"])

plt.xlabel("height")
plt.ylabel("weight")
plt.title("2020 건강검진")
plt.grid()
plt.show()

# %% [markdown]
# # 히스토그램
#
# - 변수가 하나인 데이터의 빈도수를 막대 모양으로 나타낼 때 사용
# - 통계분석에서 히스토그램은 가장 많이 사용되는 도구로, 데이터의 분석 및 분포를 파악하는 역할을 함
# - x축에는 계급, y축에는 해당 도수 및 비율(개수)을 지정
#     - 계급은 변수의 구간을 의미
#     - 서로 겹치치 않아야하고 계끕들은 서로 붙어 있어야 함

# %%
weight = np.random.randint(55, 80, 22)

plt.hist(weight)
plt.show()

# %% [markdown]
# ## Tips 히스토그램

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)

axes1.hist(tips["total_bill"], bins = 10)
axes1.set_title("Total bill 히스토그램")
axes1.set_xlabel("Total Bill")
axes1.set_ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 건강검진 데이터 남성 키 히스토그램

# %%
male_data = health.loc[health["gender"] == 1, ["gender", "height"]]

# %%
male_data.head()
# Out:
#    gender  height
# 0       1     165
# 3       1     160
# 5       1     185
# 6       1     165
# 7       1     160

# %%
plt.figure(figsize = (10, 6))

plt.hist(male_data["height"], bins = 7, label = "Male")

plt.xlabel("height")
plt.ylabel("frequency")
plt.title("2020 건강검진 남자 키 히스토그램")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 그룹 히스토그램
#
# - 남성 및 여성 키 그룹 히스토그램

# %%
female_data = health.loc[health["gender"] == 2, ["gender", "height"]]

# %%
plt.figure(figsize = (10, 6))
plt.hist(male_data["height"], bins = 7, alpha = 0.5, label = "Male")
plt.hist(female_data["height"], bins = 7, alpha = 0.5, label = "Female")

plt.xlabel("height")
plt.ylabel("frequency")
plt.title("2020 건강검진 남자 & 여자 키 히스토그램")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 파이차트

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]

plt.pie(ratio, labels = labels, autopct = "%.1f%%")
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]

plt.pie(ratio, labels = labels, autopct = "%.1f%%", startangle = 90)
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]

plt.pie(ratio, labels = labels, autopct = "%.1f%%", startangle = 90, counterclock = False)
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ["Apple", "Banana", "Melon", "Grapes"]
explode = [ 0, 0.1, 0, 0.1]

plt.pie(ratio, labels = labels, autopct = "%.1f%%", startangle = 90, counterclock = False, explode = explode, shadow = True)
plt.show()

# %% [markdown]
# # 상자수염 그래프
#
# - 데이터분포를 시각화하여 탐색하는 방법으로 상자수염 그래프를 사용

# %% [markdown]
# ### Tips

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)

axes1.boxplot([tips[tips["sex"] == "Female"]["tip"],
              tips[tips["sex"] == "Male"]["tip"]],
             labels = ["Female", "Male"])

axes1.set_xlabel("Sex")
axes1.set_ylabel("Tip")
axes1.set_title("성별에 따른 Tip 상자수염 그래프")
plt.show()

# %% [markdown]
# ## 건강검진 데이터 남성 및 여성 키 상자수염 그래프

# %%
plt.figure(figsize = (8, 5))
plt.boxplot([male_data["height"],
           female_data["height"]],
          labels = ["Male", "Female"])

plt.xlabel("gender")
plt.ylabel("height")
plt.title("2020년 남자 & 여자 키 상자 수염 그래프")
plt.show()

# %% [markdown]
# # 서브플롯
#
# - plt.subplot(nrow, ncol, pos) : 줄, 칸, 위치

# %%
x = np.arange(1, 10)
y1 = x * 5
y2 = x * 1

plt.subplot(2, 1, 1)
plt.plot(x, y1)

plt.subplot(2, 1 ,2)
plt.plot(x, y2)

plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y1)

plt.subplot(1, 2, 2)
plt.plot(x, y2)

plt.show()

# %%
y3 = x * 0.3
y4 = x * 0.2

plt.subplot(2, 2, 1)
plt.plot(x, y1)

plt.subplot(2, 2, 2)
plt.plot(x, y2)

plt.subplot(2, 2, 3)
plt.plot(x, y3)

plt.subplot(2, 2, 4)
plt.plot(x, y4)

plt.show()

# %% [markdown]
# - figure.add_subplot(nrows. ncols, index)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.hist(np.random.randn(100), bins = 20)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - plt.subplots(nrows, ncols)

# %%
fig, axes = plt.subplots(2, 2, figsize = [10, 8])

axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes1")

axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes2")

axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes3")

axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes4")
# Out:
# Text(0.5, 1.0, 'axes4')

# %% [markdown]
# # 데이터 시각화가 필요한 이유
#
# - 앤스콤 4분할 그래프
#     - 앤스콤 4분할 데이터는 각각 평균, 분산, 상관관계, 회귀선이 모두 같음
#         - 따라서 수치값만을 확인한다면 각각의 데이터는 모두 같다 라는 착각을 할 수 있음
#         - 하지만 시각화하면 모든 데이터그룹들이 서로 다른 데이터 패턴을 가짐

# %%
anscombe = sns.load_dataset("anscombe")
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.tail()
# Out:
#    dataset     x      y
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
anscombe.groupby("dataset").agg(["mean", "std"])
# Out:
#            x                   y
#         mean       std      mean       std
# dataset
# I        9.0  3.316625  7.500909  2.031568
# II       9.0  3.316625  7.500909  2.031657
# III      9.0  3.316625  7.500000  2.030424
# IV       9.0  3.316625  7.500909  2.030579

# %%
dataset_1 = anscombe[anscombe["dataset"] == "I"]
dataset_2 = anscombe[anscombe["dataset"] == "II"]
dataset_3 = anscombe[anscombe["dataset"] == "III"]
dataset_4 = anscombe[anscombe["dataset"] == "IV"]

# %%
plt.plot(dataset_1["x"], dataset_1["y"], "o")
plt.show()

# %%
fig = plt.figure()

axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

axes1.plot(dataset_1["x"], dataset_1["y"], "o")
axes2.plot(dataset_2["x"], dataset_2["y"], "o")
axes3.plot(dataset_3["x"], dataset_3["y"], "o")
axes4.plot(dataset_4["x"], dataset_4["y"], "o")

axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig.suptitle("Anscombe Data")

fig.tight_layout() # 그래프가 겹치는 지점을 띄워서 안 겹치게 해줌

plt.show()

# %% [markdown]
# # seaborn
#
# - matplotlib을 기반으로 다양한 테마와 통계용 차트 등의 동적인 기능을 추가한 시각화 라이브러리
# - 통계와 관련된 차트를 제공하기 때문에 데이터프레임으로 다양한 통계지표를 낼 수 있으며 데이터 분석에 활발히 사용되고 있음
# - 실제 분석에서는 matplotlib과 seaborn 두 가지를 함께 사용
# - seaborn 은 기본적으로 matplotlib보다 제공하는 색상이 더 많기 때문에 색 표현력이 좋음

# %% [markdown]
# ## 단변량 히스토그램

# %%
ax = plt.subplots()
ax = sns.distplot(tips["total_bill"])
ax.set_title("Total Bill 히스토그램")
plt.show()
# Out:
# C:\Users\sungj\AppData\Local\Temp\ipykernel_4676\4094568914.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips["total_bill"])

# %%
ax = plt.subplots()
ax = sns.histplot(tips["total_bill"])
ax.set_title("Total Bill 히스토그램")
plt.show()

# %%
ax = plt.subplots()
ax = sns.histplot(tips["total_bill"], kde = True) # 밀집도 그래프 추가
ax.set_title("Total Bill 히스토그램")
plt.show()

# %% [markdown]
# ### 건강검진 데이터 남성과 여성의 허리둘레 히스토그램

# %%
health.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# ...

# %%
health["gender"] = health["gender"].map(lambda x: "Male" if x == 1 else "Female")
health["drinking"] = health["drinking"].map(lambda x: "Non-driking" if x == 0 else "Drinking")
health["smoking"] = health["smoking"].map(lambda x: "Smoking" if x == 3 else "Non-smoking")

# %%
health.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36    Male         9     165      60   72.1       1.2
# 1  2020         27  Female        13     150      65   81.0       0.8
# 2  2020         11  Female        12     155      55   70.0       0.6
# 3  2020         31    Male        13     160      70   90.8       1.0
# 4  2020         41  Female        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP      smoking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0  Non-smoking
# 1        0.8          1  ...    0.5  18.0  15.0  15.0  Non-smoking
# 2        0.7          1  ...    0.7  27.0  25.0   7.0  Non-smoking
# 3        1.0          1  ...    1.2  65.0  97.0  72.0  Non-smoking
# 4        1.2          1  ...    0.7  18.0  17.0  14.0  Non-smoking
#
#       drinking  oral_check  dental_caries  tartar  open_date
# 0  Non-driking           0            NaN     NaN 2021-12-29
# ...

# %%
male_data = health.loc[health["gender"] == "Male", ["gender", "weight", "waist", "drinking","smoking"]]
female_data = health.loc[health["gender"] == "Female", ["gender", "weight", "waist", "drinking","smoking"]]

# %%
plt.figure(figsize = (10, 6))

sns.histplot(male_data["waist"], bins = 7, alpha = 0.5, label = "Male", kde =True)
sns.histplot(female_data["waist"], bins = 7, alpha = 0.5, label = "Female", kde =True, color = "r")

plt.xlabel("waist")
plt.ylabel("count")
plt.title("Waist Seaborn Histogram")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### count 그래프

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
ax = plt.subplots()
ax = sns. countplot(data = tips, x = "day")
ax.set_title("Count of Days")
ax.set_xlabel("Day of the Week")
ax.set_ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 건강검진 데이터 count 그래프

# %%
fig = plt.figure(figsize = (17, 6))

area1 = fig.add_subplot(1, 2, 1)
area2 = fig.add_subplot(1, 2, 2)

ax1 = sns.countplot(data = health, x = "gender", hue = "drinking", ax = area1)
ax2 = sns.countplot(data = health, x = "gender", hue = "smoking", ax = area2)

fig.suptitle("2020 Drinking & Smoking", fontweight = "bold")
area1.set_title("Drinking Type")
area2.set_title("Smoking Type")

plt.show()

# %% [markdown]
# ## 산점도 그래프

# %%
ax = plt.subplots()
ax = sns.regplot(x = "total_bill", y = "tip", data = tips, fit_reg = False) # fit_Reg : 회귀선
ax.set_title("Total Bill & Tip 산점도")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
plt.show()

# %% [markdown]
# ## 산점도와 히스토그램 한 번에 그리기

# %%
joint = sns.jointplot(x = "total_bill", y = "tip", data = tips)
joint.set_axis_labels(xlabel = "Total Bil", ylabel = "Tip")
joint.fig.suptitle("Joint Plot of Total Bill & Tip", fontsize = 10, y = 1.03)
plt.show()

# %% [markdown]
# - 산점도는 점이 겹칠 경우 구분하기 어려움 -> 육각 그래프
# - 육각 그래프 : 2차원 표면에 육각형으로 데이터를 쌓아 표현, 특정 데이터의 개수가 많아지면 진한 색으로 표현

# %%
joint = sns.jointplot(x = "total_bill", y = "tip", data = tips, kind = "hex")
joint.set_axis_labels(xlabel = "Total Bil", ylabel = "Tip")
joint.fig.suptitle("Joint Plot of Total Bill & Tip", fontsize = 10, y = 1.03)
plt.show()

# %%
ax = plt.subplots()
ax = sns.kdeplot(data = tips,
                x = "total_bill",
                y = "tip",
                fill = False)

ax.set_title("Total Bill & Tip 밀집도 그래프")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
plt.show()

# %% [markdown]
# ## 상자 수염 그래프

# %%
ax = plt.subplots()
ax = sns.boxplot(x = "time", y = "total_bill", data = tips)
ax.set_title("Boxplot")
ax.set_xlabel("Time of day")
ax.set_ylabel("Total Bill")
plt.show()

# %% [markdown]
# ### 건강검진 데이터 음주 여부와 몸무게 상자수염 그래프

# %%
plt.figure(figsize = (10, 6))
plt.title("Drinking & Weight Boxplot")
sns.boxplot(data = health, x = "drinking", y = "weight", hue = "gender") 
plt.show()

# %% [markdown]
# ## 바이올린 그래프

# %%
ax = plt.subplots()
ax = sns.violinplot(x = "time", y = "total_bill", data = tips)
ax.set_title("Violin Plot")
ax.set_xlabel("Time of day")
ax.set_ylabel("Total Bill")
plt.show()

# %%
ax = plt.subplots()
ax = sns.violinplot(x = "time", y = "total_bill", hue = "sex", data = tips, split = True)
ax.set_title("Violin Plot")
ax.set_xlabel("Time of day")
ax.set_ylabel("Total Bill")
plt.show()

# %% [markdown]
# ### 건강검진 데이터 성별 몸무게를 음주 여부로 분리한 바이올린 그래프

# %%
plt.figure(figsize = (10, 6))
plt.title("Violin Plot")
sns.violinplot(data = health, x = "gender", y = "weight", hue = "drinking")
plt.show()

# %% [markdown]
# ## 관계 그래프

# %%
fig = sns.pairplot(tips)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot) # 산점도 그래프
pair_grid = pair_grid.map_diag(sns.histplot, kde = True) # 히스토그램
pair_grid = pair_grid.map_lower(sns.kdeplot, fill = False) # 이차원 밀집도
plt.show()

# %% [markdown]
# # seaborn 으로 다변량 그래프 그리기

# %%
fig = sns.pairplot(tips, hue = "sex")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## FacetGrid 로 그룹별 그래프 그리기

# %%
facet = sns.FacetGrid(tips, col = "time")
facet.map(sns.histplot, "total_bill")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
facet = sns.FacetGrid(tips, col = "day", hue = "sex")
facet = facet.map(plt.scatter, "total_bill", "tip")
facet = facet.add_legend()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
facet = sns.FacetGrid(tips, col = "time", row = "smoker", hue = "sex")
facet = facet.map(plt.scatter, "total_bill", "tip")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
