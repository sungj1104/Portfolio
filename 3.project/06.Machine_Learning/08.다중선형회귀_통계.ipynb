# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
wine = pd.read_csv("./data/winequality-red.csv", sep = ";")
wine.columns = wine.columns.map(lambda x: x.replace(" ", "_"))
wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
wine.shape
# Out:
# (1599, 12)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# 탐색적 데이터 분석
wine.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.256131     0.671703
# volatile_acidity          -0.256131          1.000000    -0.552496
# citric_acid                0.671703         -0.552496     1.000000
# residual_sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free_sulfur_dioxide       -0.153794         -0.010504    -0.060978
# total_sulfur_dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity               0.114777   0.093705            -0.153794
# volatile_acidity            0.001918   0.061298            -0.010504
# citric_acid                 0.143577   0.203823            -0.060978
# residual_sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free_sulfur_dioxide         0.187049   0.005562             1.000000
# total_sulfur_dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile_acidity                  0.076470  0.022026  0.234937  -0.260987
# citric_acid                       0.035533  0.364947 -0.541904   0.312770
# residual_sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free_sulfur_dioxide               0.667666 -0.021946  0.070377   0.051658
# total_sulfur_dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed_acidity        -0.061668  0.124052
# volatile_acidity     -0.202288 -0.390558
# citric_acid           0.109903  0.226373
# residual_sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free_sulfur_dioxide  -0.069408 -0.050656
# total_sulfur_dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
eda_columns = ["fixed_acidity", "volatile_acidity", "citric_acid", "chlorides", "total_sulfur_dioxide", "density",
              "sulphates", "alcohol", "quality"]

# %%
sns.set(style = "whitegrid")
sns.pairplot(wine[eda_columns])
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 상관관계 히트맵
#
# - 쌍 그래프와 함께 수치적 관점의 상관관계를 보여주기 위해
# - 초기 단계에서 변수가 너무 많을 경우, 탈락시킬 변수들을 선택하기 위해 사용

# %%
corr_mat = np.corrcoef(wine[eda_columns].values.T)
sns.set()
full_mat = sns.heatmap(corr_mat, cbar = True, annot = True, square = True, fmt = ".2f", annot_kws = {"size" : 15},
                       yticklabels = eda_columns, xticklabels = eda_columns)
plt.show()

# %% [markdown]
# ### 변수 선택(후진 제거법, 전진 선택법)
#
# - 후진 제거법(backward elimination)
#     - 번체 변수를 대상으로 미리 정의한 모든 통계 수치(유의 수준, 다중공선성 등)을 만족할 때까지 반복적으로 변수를 하나씩 ㅈ거
#     - 이번 옞에서는 R제곱값이 0.7 이상이면 받아들이고 그렇지 않으면 기각
#
# - 전진 선택법(forward selection)
#     - 공집합에서 출발해서 전체 모델의 적합도가 좋아질 때까지 변수를 증가

# %%
wine.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
columns = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

# %%
pdx = wine[columns]
pdy = wine["quality"]

# %%
x_train, x_test, y_train, y_test = train_test_split(pdx, pdy, test_size = 0.3, random_state = 10)

# %%
# x_train, x_test에 상수항 추가
x_train_new = sm.add_constant(x_train)
x_test_new = sm.add_constant(x_test)
full_mod = sm.OLS(y_train, x_train_new)

# %%
x_train.head()
# Out:
#      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 305           10.3              0.53         0.48             2.5      0.063
# 984           12.2              0.45         0.49             1.4      0.075
# 47             8.7              0.29         0.52             1.6      0.113
# 812           10.8              0.45         0.33             2.5      0.099
# 3             11.2              0.28         0.56             1.9      0.075
#
#      free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 305                  6.0                  25.0  0.99980  3.12       0.59
# 984                  3.0                   6.0  0.99690  3.13       0.63
# 47                  12.0                  37.0  0.99690  3.25       0.58
# 812                 20.0                  38.0  0.99818  3.24       0.71
# 3                   17.0                  60.0  0.99800  3.16       0.58
#
#      alcohol
# 305      9.3
# 984     10.4
# 47       9.5
# 812     10.8
# 3        9.8

# %%
x_train_new.head()
# Out:
#      const  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 305    1.0           10.3              0.53         0.48             2.5
# 984    1.0           12.2              0.45         0.49             1.4
# 47     1.0            8.7              0.29         0.52             1.6
# 812    1.0           10.8              0.45         0.33             2.5
# 3      1.0           11.2              0.28         0.56             1.9
#
#      chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 305      0.063                  6.0                  25.0  0.99980  3.12
# 984      0.075                  3.0                   6.0  0.99690  3.13
# 47       0.113                 12.0                  37.0  0.99690  3.25
# 812      0.099                 20.0                  38.0  0.99818  3.24
# 3        0.075                 17.0                  60.0  0.99800  3.16
#
#      sulphates  alcohol
# 305       0.59      9.3
# 984       0.63     10.4
# 47        0.58      9.5
# 812       0.71     10.8
# 3         0.58      9.8

# %%
# 모델 훈련
full_res = full_mod.fit()

# %%
# 모델 요약 출력
print(full_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     53.97
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           2.36e-95
# Time:                        10:49:53   Log-Likelihood:                -1090.5
# No. Observations:                1119   AIC:                             2205.
# Df Residuals:                    1107   BIC:                             2265.
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    9.0960     24.730      0.368      0.713     -39.427      57.619
# fixed_acidity            0.0196      0.031      0.633      0.527      -0.041       0.080
# volatile_acidity        -1.2751      0.145     -8.814      0.000      -1.559      -0.991
# citric_acid             -0.2330      0.181     -1.290      0.197      -0.587       0.121
# residual_sugar           0.0009      0.017      0.049      0.961      -0.033       0.035
# chlorides               -1.8481      0.463     -3.992      0.000      -2.757      -0.940
# free_sulfur_dioxide      0.0030      0.003      1.184      0.237      -0.002       0.008
# total_sulfur_dioxide    -0.0033      0.001     -3.822      0.000      -0.005      -0.002
# density                 -4.9100     25.263     -0.194      0.846     -54.479      44.659
# pH                      -0.3045      0.227     -1.342      0.180      -0.750       0.141
# sulphates                0.8213      0.130      6.334      0.000       0.567       1.076
# alcohol                  0.2629      0.031      8.448      0.000       0.202       0.324
# ==============================================================================
# Omnibus:                       21.966   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.912
# Skew:                          -0.207   Prob(JB):                     1.94e-07
# Kurtosis:                       3.702   Cond. No.                     1.12e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### VIF
#
# - 다중 공선성 문제
#     - 회귀분석에서 독립변수들 간에 강한 상관관계가 나타나는 문제
#
# - 다중 공선성을 없애는 가장 기본적인 방법
#     - 다른 독립변수에 의존하는 변수를 없애는 것
#
# - VIF(Variance Inflation Factor)
#     - 독립변수를 다른 독립변수로 선형회귀한 성능을 나타낸 것으로, 가장 의존적인 독립변수를 선택할 때 사용

# %%
cnames = x_train.columns

# %%
cnames
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
for i in np.arange(len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train[yvar], sm.add_constant(x_train_new[xvars]))
    res = mod.fit()
    vif = 1/(1-res.rsquared)
    print(yvar, round(vif, 3))
# Out:
# fixed_acidity 7.979
# volatile_acidity 1.789
# citric_acid 3.336
# residual_sugar 1.703
# chlorides 1.607
# free_sulfur_dioxide 1.98
# total_sulfur_dioxide 2.229
# density 6.097
# pH 3.269
# sulphates 1.509
# alcohol 2.869

# %% [markdown]
# #### 이번 예제에서 살펴볼 척도
#
# - AIC
#     - 주어진 데이터셋에 대한 통계 모델의 상대적인 품질 평가
#     - 절대 수치는 중요하지 않고, 상대 수치가 적을수록 좋다(모형 적합도가 높다 또는 정보 손실이 적다)
#
# - 수정 R 제곱
#     - 0.7 이상이어야 함
#
# - 개별 변수의 p값
#     - 유의확률. 표본 이상으로 극단적인 결과를 얻을 확률
#     - 0.05 이하여야 함
#
# - 개별 변수의 VIF
#     - 5 이하여야 함

# %% [markdown]
# **residual_sugar** 변수가 가장 높은 p값을 갖기 때문에 제거
# - 무의미한 변수가 다중공선성보다 더 심각한 문제를 유발하기 때문
# - 최종적으로는 p값이 높은 변수, VIF가 높은 변수 모두 제거되어야 함

# %% [markdown]
# # 변수 제거 1
#
# - 제거된 변수 : residual_sugar

# %%
columns = ['fixed_acidity', 'volatile_acidity', 'citric_acid',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
pdx = wine[columns]
pdy = wine["quality"]
x_train, x_test, y_train, y_test = train_test_split(pdx, pdy, test_size = 0.3, random_state = 10)
x_train_new = sm.add_constant(x_train)
x_test_new = sm.add_constant(x_test)
full_mod = sm.OLS(y_train, x_train_new)
full_res = full_mod.fit()
print(full_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     59.42
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           2.99e-96
# Time:                        10:49:53   Log-Likelihood:                -1090.5
# No. Observations:                1119   AIC:                             2203.
# Df Residuals:                    1108   BIC:                             2258.
# Df Model:                          10
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    8.3788     19.992      0.419      0.675     -30.849      47.606
# fixed_acidity            0.0189      0.028      0.684      0.494      -0.035       0.073
# volatile_acidity        -1.2752      0.145     -8.819      0.000      -1.559      -0.991
# citric_acid             -0.2321      0.180     -1.292      0.197      -0.585       0.120
# chlorides               -1.8491      0.462     -3.999      0.000      -2.756      -0.942
# free_sulfur_dioxide      0.0031      0.003      1.200      0.231      -0.002       0.008
# total_sulfur_dioxide    -0.0033      0.001     -3.825      0.000      -0.005      -0.002
# density                 -4.1772     20.423     -0.205      0.838     -44.249      35.894
# pH                      -0.3083      0.213     -1.444      0.149      -0.727       0.110
# sulphates                0.8199      0.126      6.488      0.000       0.572       1.068
# alcohol                  0.2636      0.027      9.696      0.000       0.210       0.317
# ==============================================================================
# Omnibus:                       21.796   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.637
# Skew:                          -0.206   Prob(JB):                     2.22e-07
# Kurtosis:                       3.699   Cond. No.                     9.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
cnames = x_train.columns
for i in np.arange(len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train[yvar], sm.add_constant(x_train_new[xvars]))
    res = mod.fit()
    vif = 1/(1-res.rsquared)
    print(yvar, round(vif, 3))
# Out:
# fixed_acidity 6.38
# volatile_acidity 1.789
# citric_acid 3.307
# chlorides 1.604
# free_sulfur_dioxide 1.949
# total_sulfur_dioxide 2.225
# density 3.988
# pH 2.894
# sulphates 1.434
# alcohol 2.192

# %% [markdown]
# - AIC : 2205 => 2203
# - 수정 R 제곱 : 0.343 변화없음
# - 개별 변수 p값 : density가 가장 무의미
# - 개별 변수 VIF : fixed_acidity 가 가장 높음

# %% [markdown]
# # 변수 제거 2
#
# - 제거된 변수 : residual_sugar, density

# %%
columns = ['fixed_acidity', 'volatile_acidity', 'citric_acid',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide',
       'pH', 'sulphates', 'alcohol']
pdx = wine[columns]
pdy = wine["quality"]
x_train, x_test, y_train, y_test = train_test_split(pdx, pdy, test_size = 0.3, random_state = 10)
x_train_new = sm.add_constant(x_train)
x_test_new = sm.add_constant(x_test)
full_mod = sm.OLS(y_train, x_train_new)
full_res = full_mod.fit()
print(full_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     66.07
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           3.64e-97
# Time:                        10:49:53   Log-Likelihood:                -1090.6
# No. Observations:                1119   AIC:                             2201.
# Df Residuals:                    1109   BIC:                             2251.
# Df Model:                           9
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    4.2923      0.724      5.931      0.000       2.872       5.712
# fixed_acidity            0.0148      0.019      0.783      0.434      -0.022       0.052
# volatile_acidity        -1.2794      0.143     -8.941      0.000      -1.560      -0.999
# citric_acid             -0.2338      0.179     -1.303      0.193      -0.586       0.118
# chlorides               -1.8575      0.460     -4.035      0.000      -2.761      -0.954
# free_sulfur_dioxide      0.0031      0.003      1.204      0.229      -0.002       0.008
# total_sulfur_dioxide    -0.0033      0.001     -3.905      0.000      -0.005      -0.002
# pH                      -0.3303      0.184     -1.793      0.073      -0.692       0.031
# sulphates                0.8152      0.124      6.563      0.000       0.571       1.059
# alcohol                  0.2673      0.021     12.952      0.000       0.227       0.308
# ==============================================================================
# Omnibus:                       21.710   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.489
# Skew:                          -0.205   Prob(JB):                     2.40e-07
# Kurtosis:                       3.697   Cond. No.                     2.42e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
cnames = x_train.columns
for i in np.arange(len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train[yvar], sm.add_constant(x_train_new[xvars]))
    res = mod.fit()
    vif = 1/(1-res.rsquared)
    print(yvar, round(vif, 3))
# Out:
# fixed_acidity 2.977
# volatile_acidity 1.753
# citric_acid 3.3
# chlorides 1.591
# free_sulfur_dioxide 1.948
# total_sulfur_dioxide 2.172
# pH 2.158
# sulphates 1.387
# alcohol 1.264

# %% [markdown]
# - AIC : 2203 => 2201
# - 수정 R 제곱 : 0.343 => 0.344
# - 개별 변수 p값 : fixed_acidity가 가장 무의미
# - 개별 변수 VIF : citric_acid 가 가장 높지만 3.3으로 5 미만

# %% [markdown]
# # 변수 제거 3
#
# - 제거된 변수 : residual_sugar, density, fixed_acidity

# %%
columns = ['volatile_acidity', 'citric_acid',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide',
       'pH', 'sulphates', 'alcohol']
pdx = wine[columns]
pdy = wine["quality"]
x_train, x_test, y_train, y_test = train_test_split(pdx, pdy, test_size = 0.3, random_state = 10)
x_train_new = sm.add_constant(x_train)
x_test_new = sm.add_constant(x_test)
full_mod = sm.OLS(y_train, x_train_new)
full_res = full_mod.fit()
print(full_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     74.28
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           5.54e-98
# Time:                        10:49:53   Log-Likelihood:                -1090.9
# No. Observations:                1119   AIC:                             2200.
# Df Residuals:                    1110   BIC:                             2245.
# Df Model:                           8
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    4.6606      0.550      8.479      0.000       3.582       5.739
# volatile_acidity        -1.2524      0.139     -9.019      0.000      -1.525      -0.980
# citric_acid             -0.1529      0.147     -1.043      0.297      -0.441       0.135
# chlorides               -1.9682      0.438     -4.494      0.000      -2.828      -1.109
# free_sulfur_dioxide      0.0032      0.003      1.269      0.205      -0.002       0.008
# total_sulfur_dioxide    -0.0035      0.001     -4.302      0.000      -0.005      -0.002
# pH                      -0.4049      0.158     -2.568      0.010      -0.714      -0.096
# sulphates                0.8204      0.124      6.615      0.000       0.577       1.064
# alcohol                  0.2652      0.020     12.962      0.000       0.225       0.305
# ==============================================================================
# Omnibus:                       20.970   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.167
# Skew:                          -0.202   Prob(JB):                     4.64e-07
# Kurtosis:                       3.680   Cond. No.                     1.83e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.83e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
cnames = x_train.columns
for i in np.arange(len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train[yvar], sm.add_constant(x_train_new[xvars]))
    res = mod.fit()
    vif = 1/(1-res.rsquared)
    print(yvar, round(vif, 3))
# Out:
# volatile_acidity 1.652
# citric_acid 2.203
# chlorides 1.441
# free_sulfur_dioxide 1.937
# total_sulfur_dioxide 1.999
# pH 1.581
# sulphates 1.383
# alcohol 1.242

# %% [markdown]
# - AIC : 2201 => 2200
# - 수정 R 제곱 : 0.344 로 변화없음
# - 개별 변수 p값 : citric_acid가 가장 무의미
# - 개별 변수 VIF : citric_acid 가 가장 높지만 2.2으로 5 미만

# %% [markdown]
# # 변수 제거 4
#
# - 제거된 변수 : residual_sugar, density, fixed_acidity, citric_acid

# %%
columns = ['volatile_acidity', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide',
       'pH', 'sulphates', 'alcohol']
pdx = wine[columns]
pdy = wine["quality"]
x_train, x_test, y_train, y_test = train_test_split(pdx, pdy, test_size = 0.3, random_state = 10)
x_train_new = sm.add_constant(x_train)
x_test_new = sm.add_constant(x_test)
full_mod = sm.OLS(y_train, x_train_new)
full_res = full_mod.fit()
print(full_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     84.73
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           9.92e-99
# Time:                        10:49:54   Log-Likelihood:                -1091.4
# No. Observations:                1119   AIC:                             2199.
# Df Residuals:                    1111   BIC:                             2239.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    4.3892      0.484      9.065      0.000       3.439       5.339
# volatile_acidity        -1.1777      0.119     -9.900      0.000      -1.411      -0.944
# chlorides               -2.0531      0.430     -4.770      0.000      -2.898      -1.209
# free_sulfur_dioxide      0.0036      0.003      1.419      0.156      -0.001       0.009
# total_sulfur_dioxide    -0.0037      0.001     -4.501      0.000      -0.005      -0.002
# pH                      -0.3287      0.140     -2.353      0.019      -0.603      -0.055
# sulphates                0.8129      0.124      6.566      0.000       0.570       1.056
# alcohol                  0.2604      0.020     13.054      0.000       0.221       0.300
# ==============================================================================
# Omnibus:                       21.448   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.686
# Skew:                          -0.208   Prob(JB):                     3.58e-07
# Kurtosis:                       3.681   Cond. No.                     1.68e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
cnames = x_train.columns
for i in np.arange(len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train[yvar], sm.add_constant(x_train_new[xvars]))
    res = mod.fit()
    vif = 1/(1-res.rsquared)
    print(yvar, round(vif, 3))
# Out:
# volatile_acidity 1.213
# chlorides 1.391
# free_sulfur_dioxide 1.903
# total_sulfur_dioxide 1.957
# pH 1.242
# sulphates 1.378
# alcohol 1.182

# %% [markdown]
# - AIC : 2200 => 2199
# - 수정 R 제곱 : 0.344 로 변화없음
# - 개별 변수 p값 : free_sulfur_dioxide가 가장 무의미
# - 개별 변수 VIF : total_sulfur_dioxide 가 가장 높지만 1.957 으로 5 미만

# %% [markdown]
# # 변수 제거 4
#
# - 제거된 변수 : residual_sugar, density, fixed_acidity, citric_acid, free_sulfur_dioxide

# %%
columns = ['volatile_acidity', 'chlorides', 'total_sulfur_dioxide',
       'pH', 'sulphates', 'alcohol']
pdx = wine[columns]
pdy = wine["quality"]
x_train, x_test, y_train, y_test = train_test_split(pdx, pdy, test_size = 0.3, random_state = 10)
x_train_new = sm.add_constant(x_train)
x_test_new = sm.add_constant(x_test)
full_mod = sm.OLS(y_train, x_train_new)
full_res = full_mod.fit()
print(full_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     98.43
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):           2.59e-99
# Time:                        10:49:54   Log-Likelihood:                -1092.4
# No. Observations:                1119   AIC:                             2199.
# Df Residuals:                    1112   BIC:                             2234.
# Df Model:                           6
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    4.3044      0.481      8.955      0.000       3.361       5.248
# volatile_acidity        -1.1937      0.118    -10.074      0.000      -1.426      -0.961
# chlorides               -2.0317      0.430     -4.721      0.000      -2.876      -1.187
# total_sulfur_dioxide    -0.0029      0.001     -4.830      0.000      -0.004      -0.002
# pH                      -0.2973      0.138     -2.154      0.031      -0.568      -0.026
# sulphates                0.8106      0.124      6.545      0.000       0.568       1.054
# alcohol                  0.2613      0.020     13.097      0.000       0.222       0.300
# ==============================================================================
# Omnibus:                       22.399   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.626
# Skew:                          -0.221   Prob(JB):                     2.24e-07
# Kurtosis:                       3.680   Cond. No.                     1.60e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
cnames = x_train.columns
for i in np.arange(len(cnames)):
    xvars = list(cnames)
    yvar = xvars.pop(i)
    mod = sm.OLS(x_train[yvar], sm.add_constant(x_train_new[xvars]))
    res = mod.fit()
    vif = 1/(1-res.rsquared)
    print(yvar, round(vif, 3))
# Out:
# volatile_acidity 1.202
# chlorides 1.39
# total_sulfur_dioxide 1.046
# pH 1.211
# sulphates 1.378
# alcohol 1.181

# %% [markdown]
# - AIC : 2199 로 변화 없음
# - 수정 R 제곱 : 0.344 => 0.343 으로 낮아짐
# - 개별 변수 p값 : 무의미한 변수는 모두 제거함
# - 개별 변수 VIF : 모든 변수가 5보다 작음

# %% [markdown]
# **결론 : 독립 변수와 종속 변수 사이에 어떤 강한 관계도 존재하지 않는다**

# %%
y_pred = full_res.predict(x_test_new)
y_pred_df = pd.DataFrame(y_pred)
y_pred_df.columns = ["y_pred"]

pred_data = pd.DataFrame((y_pred_df["y_pred"]))
y_test_new = pd.DataFrame(y_test)
y_test_new.reset_index(inplace = True)
pred_data["y_test"] = pd.DataFrame(y_test_new["quality"])

# %%
rsqd = r2_score(y_test_new["quality"].tolist(), y_pred_df["y_pred"].tolist())
print(round(rsqd, 4))
# Out:
# 0.3706
