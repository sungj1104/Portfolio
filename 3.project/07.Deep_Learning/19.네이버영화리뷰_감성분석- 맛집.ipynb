# %%
import pandas as pd
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re

# %%
train_df = pd.read_csv("./data/ratings_train.txt", sep = "\t")
test_df = pd.read_csv("./data/ratings_test.txt", sep = "\t")

# %%
train_df.shape, test_df.shape
# Out:
# ((150000, 3), (50000, 3))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
# 결측치 확인
train_df.isna().sum()
# Out:
# id          0
# document    5
# label       0
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# id          0
# document    3
# label       0
# dtype: int64

# %%
train_df = train_df.dropna(subset = ["document"])
test_df = test_df.dropna(subset = ["document"])

# %%
train_df.shape, test_df.shape
# Out:
# ((149995, 3), (49997, 3))

# %%
# 종속변수 확인
np.unique(train_df["label"], return_counts = True)
# Out:
# (array([0, 1], dtype=int64), array([75170, 74825], dtype=int64))

# %%
test_df.head()
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %% [markdown]
# # 데이터 전처리

# %%
# 한글 이외의 문자들 제거
train_df["document"] = train_df["document"].map(lambda x: re.sub("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]", "", x))
test_df["document"] = test_df["document"].map(lambda x: re.sub("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]", "", x))

# %%
train_df.head()
# Out:
#          id                                           document  label
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1

# %%
test_df.head()
# Out:
#         id                                   document  label
# 0  6270596                                        굳 ㅋ      1
# 1  9274899                                                 0
# 2  8544678           뭐야 이 평점들은 나쁘진 않지만 점 짜리는 더더욱 아니잖아      0
# 3  6825595                  지루하지는 않은데 완전 막장임 돈주고 보기에는      0
# 4  6723715  만 아니었어도 별 다섯 개 줬을텐데 왜 로 나와서 제 심기를 불편하게 하죠      0

# %%
train_df = train_df[train_df["document"].map(lambda x: len(x.strip()) >= 1)]
test_df = test_df[test_df["document"].map(lambda x: len(x.strip()) >= 1)]

# %%
train_df.shape, test_df.shape
# Out:
# ((148740, 3), (49575, 3))

# %%
# 중복 데이터 확인
train_df[train_df["document"].duplicated(keep = False)].sort_values("document")
# Out:
#              id               document  label
# 46599   9682597      그리고 내 감정을 불러 일으켰다      1
# 43436   9582856      그리고 내 감정을 불러 일으켰다      1
# 123713  9582855      그리고 내 감정을 불러 일으켰다      1
# 93364    171409               가입  추천바람      1
# 138373   171407               가입  추천바람      1
# ...         ...                    ...    ...
# 57831   3906478                   흥미진진      1
# 8446    5158304        힐러리 더프의 매력에 빠지다      1
# 72688   5153363        힐러리 더프의 매력에 빠지다      1
# 26889   7971814                    힘들다      0
# 122612  7415842                    힘들다      0
#
# [6449 rows x 3 columns]

# %%
# 중복제거
train_df = train_df.drop_duplicates(subset = ["document"], keep ="first")
test_df = test_df.drop_duplicates(subset = ["document"], keep ="first")

# %%
train_df.shape, test_df.shape
# Out:
# ((143660, 3), (48403, 3))

# %% [markdown]
# # 토큰화

# %%
okt = Okt()

# %%
okt.morphs("아 더빙 진짜 짜증나네요 목소리", stem = False)
# Out:
# ['아', '더빙', '진짜', '짜증나네요', '목소리']

# %%
okt.morphs("아 더빙 진짜 짜증나네요 목소리", stem = True)
# Out:
# ['아', '더빙', '진짜', '짜증나다', '목소리']

# %%
okt.nouns("아 더빙 진짜 짜증나네요 목소리")
# Out:
# ['더빙', '진짜', '목소리']

# %%
okt.pos("아 더빙 진짜 짜증나네요 목소리")
# Out:
# [('아', 'Exclamation'),
#  ('더빙', 'Noun'),
#  ('진짜', 'Noun'),
#  ('짜증나네요', 'Adjective'),
#  ('목소리', 'Noun')]

# %%
# %%time
train_df["token"] = train_df["document"].map(lambda x: okt.morphs(x, stem = True))
test_df["token"] = test_df["document"].map(lambda x: okt.morphs(x, stem = True))
# Out:
# CPU times: total: 22min 43s
# Wall time: 21min 58s

# %%
train_df.head(20)
# Out:
#           id                                           document  label  \
# 0    9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1    3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2   10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3    9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4    6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1
# 5    5403919              막 걸음마 뗀 세부터 초등학교 학년생인 살용영화ㅋㅋㅋ별반개도 아까움      0
# 6    7797314                               원작의 긴장감을 제대로 살려내지못했다      0
# 7    9443947  별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지정말 발로해도 그것보단 낫...      0
# 8    7156791                             액션이 없는데도 재미 있는 몇안되는 영화      1
# 9    5912145          왜케 평점이 낮은건데 꽤 볼만한데 헐리우드식 화려함에만 너무 길들여져 있나      1
# 10   9008700                                     걍인피니트가짱이다진짜짱이다      1
# 11  10217543             볼때마다 눈물나서 죽겠다년대의 향수자극허진호는 감성절제멜로의 달인이다      1
# 12   5957425                울면서 손들고 횡단보도 건널때 뛰쳐나올뻔 이범수 연기 드럽게못해      0
# 13   8628627   담백하고 깔끔해서 좋다 신문기사로만 보다 보면 자꾸 잊어버린다 그들도 사람이었다는 것을      1
# 14   9864035  취향은 존중한다지만 진짜 내생에 극장에서 본 영화중 가장 노잼 노감동임 스토리도 어...      0
# 15   6852435                                   ㄱ냥 매번 긴장되고 재밋음ㅠㅠ      1
# 16   9143163  참 사람들 웃긴게 바스코가 이기면 락스코라고 까고바비가 이기면 아이돌이라고 깐다그냥...      1
# 17   4891476                 굿바이 레닌 표절인것은 이해하는데 왜 뒤로 갈수록 재미없어지냐      0
# 18   7465483         이건 정말 깨알 캐스팅과 질퍽하지않은 산뜻한 내용구성이 잘 버무러진 깨알일드      1
# 19   3989148                    약탈자를 위한 변명 이라 저놈들은 착한놈들 절대 아닌걸요      1
#
#                                                 token
# 0                              [아, 더빙, 진짜, 짜증나다, 목소리]
# 1        [흠, 포스터, 보고, 초딩, 영화, 줄, 오버, 연기, 조차, 가볍다, 않다]
# 2                   [너, 무재, 밓었, 다그, 래서, 보다, 추천, 한, 다]
# 3             [교도소, 이야기, 구먼, 솔직하다, 재미, 는, 없다, 평점, 조정]
# 4   [사이, 몬페, 그, 의, 익살스럽다, 연기, 가, 돋보이다, 영화, 스파이더맨, ...
# 5   [막, 걸음, 마, 떼다, 세, 부터, 초등학교, 학년, 생인, 살다, 영화, ㅋㅋ...
# 6                       [원작, 의, 긴장감, 을, 제대로, 살리다, 하다]
# 7   [별, 반개, 도, 아깝다, 욕, 나오다, 이응경, 길용우, 연, 기, 생활, 이,...
# 8                     [액션, 이, 없다, 재미, 있다, 몇, 안되다, 영화]
# 9   [왜케, 평점, 이, 낮다, 꽤, 볼, 만, 한, 데, 헐리우드, 식, 화려하다, ...
# 10                     [걍, 인피니트, 가, 짱, 이다, 진짜, 짱, 이다]
# 11  [볼때, 마다, 눈물나다, 죽다, 년대, 의, 향수, 자, 극, 허진호, 는, 감성...
# 12  [울면, 서, 손, 들, 고, 횡단보도, 건너다, 때, 뛰다, 치다, 올, 뻔, 이...
# 13  [담백하다, 깔끔하다, 좋다, 신, 문, 기, 사, 로만, 보다, 보다, 자꾸, 잊...
# 14  [취향, 은, 존중, 한, 다지, 만, 진짜, 내생, 에, 극장, 에서, 보다, 영...
# 15                        [ㄱ, 냥, 매번, 긴장, 되다, 재밋음, ㅠㅠ]
# 16  [차다, 사람, 들, 웃기다, 바스코, 가, 이기, 면, 락스, 코, 라고, 끄다,...
# 17  [굿바이, 레닌, 표절, 인, 것, 은, 이해, 하다, 왜, 뒤, 로, 갈수록, 재...
# 18  [이건, 정말, 깨알, 캐스팅, 과, 질퍽, 하, 지, 않다, 산뜻하다, 내, 용구...
# 19  [약탈, 자, 를, 위, 한, 변명, 이르다, 저, 놈, 들, 은, 착하다, 놈, ...

# %% [markdown]
# # 맛집 코드

# %%
train_df.to_csv("nsmc_ratings_train_pre.csv", index = False)
test_df.to_csv("nsmc_ratings_test_pre.csv", index = False)

# %%
train_df = pd.read_csv("./nsmc_ratings_train_pre.csv")
test_df = pd.read_csv("./nsmc_ratings_test_pre.csv")

# %%
type(train_df.loc[0, "token"])
# Out:
# list

# %%
# 위 타입이 문자열이라면 리스트로 바꾸는 법
train_df["token"] = train_df["token"].map(lambda x: eval(x))
test_df["token"] = test_df["token"].map(lambda x: eval(x))

# %%
train_df.shape, test_df.shape
# Out:
# ((143660, 4), (48403, 4))

# %% [markdown]
# train_df["token"] = train_df["token"].map(lambda x: [i for i in x if len(i) > 1])
# test_df["token"] = test_df["token"].map(lambda x: [i for i in x if len(i) > 1])

# %%
train_df.shape, test_df.shape
# Out:
# ((143660, 4), (48403, 4))

# %%
train_df.head()
# Out:
#          id                                           document  label  \
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1
#
#                                                token
# 0                             [아, 더빙, 진짜, 짜증나다, 목소리]
# 1       [흠, 포스터, 보고, 초딩, 영화, 줄, 오버, 연기, 조차, 가볍다, 않다]
# 2                  [너, 무재, 밓었, 다그, 래서, 보다, 추천, 한, 다]
# 3            [교도소, 이야기, 구먼, 솔직하다, 재미, 는, 없다, 평점, 조정]
# 4  [사이, 몬페, 그, 의, 익살스럽다, 연기, 가, 돋보이다, 영화, 스파이더맨, ...

# %%
train_df = train_df[train_df["token"]. map(lambda x: len(x) > 0)]
test_df = test_df[test_df["token"]. map(lambda x: len(x) > 0)]

# %%
train_df.shape, test_df.shape
# Out:
# ((143660, 4), (48403, 4))

# %% [markdown]
# # 정수인코딩

# %%
tokenizer = Tokenizer()

# %%
# 단어 집합 생성
# 등장 빈도 수가 높은 순서대로 정수값 부여
tokenizer.fit_on_texts(train_df["token"])

# %%
# 단어 집합
tokenizer.word_index
# Out:
# {'이': 1,
#  '영화': 2,
#  '보다': 3,
#  '하다': 4,
#  '의': 5,
#  '에': 6,
#  '가': 7,
#  '을': 8,
#  '도': 9,
#  '들': 10,
#  '는': 11,
#  '를': 12,
#  '은': 13,
#  '없다': 14,
#  '이다': 15,
#  '있다': 16,
#  '좋다': 17,
#  '너무': 18,
#  '다': 19,
#  '정말': 20,
#  '한': 21,
#  '되다': 22,
#  '적': 23,
#  '만': 24,
#  '재밌다': 25,
#  '같다': 26,
#  '진짜': 27,
#  '으로': 28,
#  '로': 29,
#  '아니다': 30,
#  '않다': 31,
#  '점': 32,
#  '에서': 33,
#  '만들다': 34,
#  '과': 35,
#  '나오다': 36,
#  '연기': 37,
#  '것': 38,
#  '평점': 39,
#  '내': 40,
#  '최고': 41,
#  '그': 42,
#  '나': 43,
#  '안': 44,
#  '인': 45,
#  '스토리': 46,
#  '생각': 47,
#  '못': 48,
#  '왜': 49,
#  '드라마': 50,
#  '게': 51,
#  '사람': 52,
#  '감동': 53,
#  '보고': 54,
#  '이렇다': 55,
#  '고': 56,
#  '말': 57,
#  '아깝다': 58,
#  '더': 59,
#  '배우': 60,
#  '때': 61,
#  'ㅋㅋ': 62,
#  '와': 63,
#  '아': 64,
#  '감독': 65,
#  '거': 66,
#  '그냥': 67,
#  '요': 68,
#  '재미있다': 69,
#  '재미': 70,
#  '시간': 71,
#  '내용': 72,
#  '까지': 73,
#  '뭐': 74,
#  '중': 75,
#  '주다': 76,
#  '좀': 77,
#  '자다': 78,
#  '하고': 79,
#  '지루하다': 80,
#  '수': 81,
#  '재미없다': 82,
#  '네': 83,
#  '쓰레기': 84,
#  '모르다': 85,
#  '가다': 86,
#  '들다': 87,
#  '그렇다': 88,
#  '싶다': 89,
#  '지': 90,
#  '작품': 91,
#  '사랑': 92,
#  '알다': 93,
#  '하나': 94,
#  '다시': 95,
#  '마지막': 96,
#  '볼': 97,
#  '잘': 98,
#  '정도': 99,
#  '저': 100,
#  '이건': 101,
#  '오다': 102,
#  '완전': 103,
#  'ㅋ': 104,
#  'ㅠㅠ': 105,
#  '많다': 106,
#  '처음': 107,
#  'ㅋㅋㅋ': 108,
#  '장면': 109,
#  '액션': 110,
#  '주인공': 111,
#  '이렇게': 112,
#  '안되다': 113,
#  '걸': 114,
#  '차다': 115,
#  '나다': 116,
#  '개': 117,
#  '하': 118,
#  '돈': 119,
#  '이야기': 120,
#  '지금': 121,
#  '최악': 122,
#  '넘다': 123,
#  '느낌': 124,
#  '연출': 125,
#  '임': 126,
#  '라': 127,
#  'ㅡㅡ': 128,
#  '인데': 129,
#  '듯': 130,
#  '끝': 131,
#  '좋아하다': 132,
#  '명작': 133,
#  '그리고': 134,
#  '년': 135,
#  '받다': 136,
#  '역시': 137,
#  '기': 138,
#  '별로': 139,
#  '많이': 140,
#  '남다': 141,
#  '별': 142,
#  '이해': 143,
#  '면': 144,
#  '난': 145,
#  '이런': 146,
#  '이영화': 147,
#  '분': 148,
#  '느끼다': 149,
#  '괜찮다': 150,
#  '라고': 151,
#  '또': 152,
#  '버리다': 153,
#  '이나': 154,
#  '때문': 155,
#  '성': 156,
#  '여자': 157,
#  '서': 158,
#  '부터': 159,
#  '일': 160,
#  '먹다': 161,
#  '아름답다': 162,
#  '해주다': 163,
#  '꼭': 164,
#  '보기': 165,
#  '엔': 166,
#  '이고': 167,
#  '두': 168,
#  '무슨': 169,
#  '여': 170,
#  '에게': 171,
#  '기억': 172,
#  '결말': 173,
#  '편': 174,
#  '대': 175,
#  'ㅎㅎ': 176,
#  '랑': 177,
#  '야': 178,
#  '아쉽다': 179,
#  '마음': 180,
#  '소재': 181,
#  '영': 182,
#  '짱': 183,
#  '뻔하다': 184,
#  '인생': 185,
#  '끄다': 186,
#  '애': 187,
#  '보여주다': 188,
#  '님': 189,
#  '어떻다': 190,
#  '전': 191,
#  '없이': 192,
#  '수준': 193,
#  '어리다': 194,
#  '무섭다': 195,
#  '현실': 196,
#  '맞다': 197,
#  '한번': 198,
#  '속': 199,
#  '씨': 200,
#  '가장': 201,
#  '급': 202,
#  '본': 203,
#  '웃기다': 204,
#  '반전': 205,
#  '매력': 206,
#  '재다': 207,
#  '되어다': 208,
#  '전개': 209,
#  '제': 210,
#  '라는': 211,
#  '한국': 212,
#  '남자': 213,
#  '끝나다': 214,
#  '가슴': 215,
#  '뿐': 216,
#  '낮다': 217,
#  '말다': 218,
#  '아이': 219,
#  '죽다': 220,
#  '슬프다': 221,
#  '음악': 222,
#  '유치하다': 223,
#  '높다': 224,
#  '알': 225,
#  '니': 226,
#  '다른': 227,
#  '멋지다': 228,
#  '원작': 229,
#  '줄': 230,
#  '늘다': 231,
#  '인간': 232,
#  '화': 233,
#  '솔직하다': 234,
#  '크다': 235,
#  '우리': 236,
#  '추천': 237,
#  '눈물': 238,
#  '냐': 239,
#  '쓰다': 240,
#  '살다': 241,
#  '인지': 242,
#  '모든': 243,
#  '지만': 244,
#  '내다': 245,
#  '함': 246,
#  '자체': 247,
#  '번': 248,
#  '야하다': 249,
#  '눈': 250,
#  '허다': 251,
#  '찍다': 252,
#  '하지만': 253,
#  '인가': 254,
#  '캐릭터': 255,
#  '보이다': 256,
#  '코미디': 257,
#  '처럼': 258,
#  '대한': 259,
#  'ㅋㅋㅋㅋ': 260,
#  '움': 261,
#  '모두': 262,
#  '이상': 263,
#  '뭔가': 264,
#  'ㅠ': 265,
#  '돼다': 266,
#  '이네': 267,
#  '전혀': 268,
#  '대박': 269,
#  '이쁘다': 270,
#  '연기력': 271,
#  '건지다': 272,
#  '여운': 273,
#  '미치다': 274,
#  '그래도': 275,
#  '개봉': 276,
#  '공감': 277,
#  '짜증나다': 278,
#  '일본': 279,
#  '기대': 280,
#  '기대하다': 281,
#  '근데': 282,
#  '시리즈': 283,
#  '중간': 284,
#  '지다': 285,
#  '표현': 286,
#  '영상': 287,
#  '부분': 288,
#  '아주': 289,
#  '모습': 290,
#  '에는': 291,
#  '작': 292,
#  '제목': 293,
#  '계속': 294,
#  '이랑': 295,
#  '치다': 296,
#  '이라': 297,
#  '귀엽다': 298,
#  '시키다': 299,
#  'ㅜㅜ': 300,
#  '가족': 301,
#  '내내': 302,
#  '뭔': 303,
#  '믿다': 304,
#  '보지': 305,
#  '자': 306,
#  '진심': 307,
#  '몰입': 308,
#  '밖에': 309,
#  '실망': 310,
#  '후': 311,
#  '짜다': 312,
#  '기분': 313,
#  '대단하다': 314,
#  '연': 315,
#  '작가': 316,
#  '건': 317,
#  '떨어지다': 318,
#  'ㅎ': 319,
#  '잔잔하다': 320,
#  '이제': 321,
#  '위': 322,
#  '웃다': 323,
#  '요즘': 324,
#  '공포': 325,
#  '빠지다': 326,
#  '스릴러': 327,
#  '이라는': 328,
#  '시': 329,
#  '감': 330,
#  '긴장감': 331,
#  '개인': 332,
#  '용': 333,
#  '잼': 334,
#  '조금': 335,
#  '애니': 336,
#  '대사': 337,
#  '이유': 338,
#  '알바': 339,
#  '특히': 340,
#  '제대로': 341,
#  '삶': 342,
#  '극장': 343,
#  '울다': 344,
#  '노래': 345,
#  '한테': 346,
#  '딱': 347,
#  '점도': 348,
#  '욕': 349,
#  '잇다': 350,
#  '점수': 351,
#  '시작': 352,
#  '막장': 353,
#  '이란': 354,
#  '나름': 355,
#  '오랜': 356,
#  '극': 357,
#  '이상하다': 358,
#  '이지': 359,
#  '예쁘다': 360,
#  '깊다': 361,
#  '굿': 362,
#  '에도': 363,
#  '차라리': 364,
#  '제일': 365,
#  '놈': 366,
#  '노잼': 367,
#  '느껴지다': 368,
#  '친구': 369,
#  '해보다': 370,
#  '영화로': 371,
#  '당시': 372,
#  '같이': 373,
#  '어설프다': 374,
#  '의미': 375,
#  '빼다': 376,
#  '절대': 377,
#  '식': 378,
#  '력': 379,
#  '위해': 380,
#  '세상': 381,
#  '류': 382,
#  '따뜻하다': 383,
#  '찾다': 384,
#  '몇': 385,
#  '아직도': 386,
#  '훌륭하다': 387,
#  '이라고': 388,
#  '년대': 389,
#  '공포영화': 390,
#  '명': 391,
#  '미국': 392,
#  '웃음': 393,
#  '도대체': 394,
#  '생각나다': 395,
#  '설정': 396,
#  '아무': 397,
#  '앞': 398,
#  '걍': 399,
#  '무엇': 400,
#  '마다': 401,
#  '그리다': 402,
#  '너': 403,
#  '오': 404,
#  '어': 405,
#  '죽이다': 406,
#  '초반': 407,
#  '써다': 408,
#  '다르다': 409,
#  '데': 410,
#  '물': 411,
#  '뭘': 412,
#  '우리나라': 413,
#  '출연': 414,
#  '따다': 415,
#  '수작': 416,
#  '힘들다': 417,
#  '사실': 418,
#  '싫다': 419,
#  '답답하다': 420,
#  '엄청': 421,
#  '추억': 422,
#  '가지': 423,
#  '반': 424,
#  '한국영': 425,
#  '남': 426,
#  '놓다': 427,
#  '멋있다': 428,
#  '신선하다': 429,
#  '시나리오': 430,
#  '관객': 431,
#  '분위기': 432,
#  '아프다': 433,
#  '이야': 434,
#  '대다': 435,
#  '기다': 436,
#  '팬': 437,
#  '시대': 438,
#  '해': 439,
#  '어이없다': 440,
#  '지루함': 441,
#  '필요없다': 442,
#  '세': 443,
#  '장난': 444,
#  '잊다': 445,
#  '살': 446,
#  '자신': 447,
#  '나쁘다': 448,
#  '소리': 449,
#  '이딴': 450,
#  '감정': 451,
#  '졸작': 452,
#  '엔딩': 453,
#  '이지만': 454,
#  '영화관': 455,
#  '엄마': 456,
#  '안타깝다': 457,
#  '오늘': 458,
#  '준': 459,
#  '멀다': 460,
#  '구': 461,
#  '결국': 462,
#  '접': 463,
#  '정신': 464,
#  '제발': 465,
#  '주': 466,
#  '봄': 467,
#  '인상': 468,
#  '부족하다': 469,
#  '배우다': 470,
#  '스럽다': 471,
#  '원': 472,
#  '더빙': 473,
#  '포스터': 474,
#  '캐스팅': 475,
#  '라면': 476,
#  '평가': 477,
#  '더럽다': 478,
#  '코믹': 479,
#  '문제': 480,
#  '니까': 481,
#  '얼마나': 482,
#  '아무리': 483,
#  '엉': 484,
#  '최고다': 485,
#  '애니메이션': 486,
#  '함께': 487,
#  '어색하다': 488,
#  '그저': 489,
#  '몰입도': 490,
#  '신': 491,
#  '서다': 492,
#  '낫다': 493,
#  '티비': 494,
#  '기도': 495,
#  '든': 496,
#  '배경': 497,
#  '첨': 498,
#  '두다': 499,
#  '대해': 500,
#  '유쾌하다': 501,
#  '쓸다': 502,
#  '살리다': 503,
#  '뒤': 504,
#  '맘': 505,
#  '비다': 506,
#  '망하다': 507,
#  '킬링타임': 508,
#  '나가다': 509,
#  '스릴': 510,
#  '충격': 511,
#  '음': 512,
#  '전쟁': 513,
#  '만화': 514,
#  '얘기': 515,
#  '진부하다': 516,
#  '완벽하다': 517,
#  '존나': 518,
#  '적다': 519,
#  '책': 520,
#  '건가': 521,
#  '등': 522,
#  '예술': 523,
#  '개연': 524,
#  '그렇게': 525,
#  '간': 526,
#  '머리': 527,
#  '갈수록': 528,
#  '매우': 529,
#  '머': 530,
#  '놀라다': 531,
#  '조': 532,
#  '질': 533,
#  '즐겁다': 534,
#  '얼굴': 535,
#  '보단': 536,
#  '후회': 537,
#  '웃기': 538,
#  '이름': 539,
#  '읽다': 540,
#  '영화인': 541,
#  '옛날': 542,
#  '구성': 543,
#  '어디': 544,
#  '너무나': 545,
#  '어울리다': 546,
#  '행복하다': 547,
#  '집중': 548,
#  '이후': 549,
#  '들이다': 550,
#  '울': 551,
#  '총': 552,
#  '장르': 553,
#  '꽤': 554,
#  '집': 555,
#  '새롭다': 556,
#  '주연': 557,
#  '날': 558,
#  '다큐': 559,
#  '시즌': 560,
#  '상황': 561,
#  '누구': 562,
#  '그래서': 563,
#  '이리': 564,
#  '상': 565,
#  '억지': 566,
#  '언제': 567,
#  '씬': 568,
#  '짜증': 569,
#  '생기다': 570,
#  '예전': 571,
#  '충분하다': 572,
#  '글': 573,
#  '아직': 574,
#  '후반': 575,
#  '비': 576,
#  '다운': 577,
#  '역사': 578,
#  '어느': 579,
#  '강추': 580,
#  '궁금하다': 581,
#  '걸작': 582,
#  '여기': 583,
#  '불쌍하다': 584,
#  '누가': 585,
#  '밉다': 586,
#  '진': 587,
#  '약간': 588,
#  '훨씬': 589,
#  '자기': 590,
#  '소름': 591,
#  '그것': 592,
#  '인물': 593,
#  '발연기': 594,
#  '그나마': 595,
#  '실화': 596,
#  '해도': 597,
#  '그대로': 598,
#  '방송': 599,
#  '심하다': 600,
#  '분들': 601,
#  '시절': 602,
#  '잔인하다': 603,
#  '회': 604,
#  '비디오': 605,
#  '대체': 606,
#  '순수하다': 607,
#  '비슷하다': 608,
#  '만점': 609,
#  '그런': 610,
#  '소설': 611,
#  '한마디': 612,
#  '사회': 613,
#  '아들': 614,
#  '어렵다': 615,
#  '부': 616,
#  '로맨스': 617,
#  '드리다': 618,
#  '비교': 619,
#  '초딩': 620,
#  '감성': 621,
#  '판': 622,
#  '네이버': 623,
#  '필요하다': 624,
#  '쉬다': 625,
#  '따르다': 626,
#  '보': 627,
#  '남기다': 628,
#  '다음': 629,
#  '만나다': 630,
#  '여주': 631,
#  '여배우': 632,
#  '전체': 633,
#  '간만': 634,
#  '타다': 635,
#  '죠': 636,
#  '떠나다': 637,
#  '상당하다': 638,
#  '라도': 639,
#  '휴': 640,
#  '장': 641,
#  '편이': 642,
#  '나이': 643,
#  '만큼': 644,
#  '이라도': 645,
#  '당하다': 646,
#  '사랑스럽다': 647,
#  '꿈': 648,
#  '나라': 649,
#  '코': 650,
#  '재': 651,
#  '굉장하다': 652,
#  '성룡': 653,
#  '동안': 654,
#  '이르다': 655,
#  '혼자': 656,
#  '열': 657,
#  '터지다': 658,
#  '순간': 659,
#  '돌리다': 660,
#  '교훈': 661,
#  '쯤': 662,
#  '삼류': 663,
#  '보다는': 664,
#  '빨리': 665,
#  '재밋': 666,
#  '감사하다': 667,
#  '그만': 668,
#  '존재': 669,
#  '힘': 670,
#  'ㅉㅉ': 671,
#  '바로': 672,
#  '풀다': 673,
#  '주제': 674,
#  '바라다': 675,
#  '진정하다': 676,
#  '목소리': 677,
#  '년도': 678,
#  '억': 679,
#  '에요': 680,
#  '잡다': 681,
#  '망치다': 682,
#  '화려하다': 683,
#  '죽': 684,
#  '당신': 685,
#  '돋다': 686,
#  '거의': 687,
#  '지나다': 688,
#  '안보': 689,
#  '몇번': 690,
#  '낭비': 691,
#  '질질': 692,
#  '년전': 693,
#  '가볍다': 694,
#  '라니': 695,
#  '독특하다': 696,
#  '말고': 697,
#  '엄청나다': 698,
#  '줄거리': 699,
#  '맞추다': 700,
#  '성하다': 701,
#  '뜨다': 702,
#  'ㅜ': 703,
#  '의도': 704,
#  '에선': 705,
#  '딸': 706,
#  '아버지': 707,
#  '좀비': 708,
#  '판타지': 709,
#  '이번': 710,
#  '담다': 711,
#  '갑자기': 712,
#  '그러나': 713,
#  '어른': 714,
#  '넣다': 715,
#  '피': 716,
#  '전부': 717,
#  '당': 718,
#  '상영': 719,
#  '점주': 720,
#  '모': 721,
#  '시청률': 722,
#  '흥미롭다': 723,
#  '실제': 724,
#  '소': 725,
#  'ㅎㅎㅎ': 726,
#  '넘치다': 727,
#  'ㅡ': 728,
#  '힘드다': 729,
#  '평론가': 730,
#  '곳': 731,
#  '맛': 732,
#  '점점': 733,
#  '으로도': 734,
#  '땜': 735,
#  '만하': 736,
#  '단': 737,
#  '기다리다': 738,
#  '막': 739,
#  '한편': 740,
#  '그녀': 741,
#  '히': 742,
#  '필요': 743,
#  '제작': 744,
#  '화면': 745,
#  '사': 746,
#  '바': 747,
#  '대로': 748,
#  '극장판': 749,
#  '만들어지다': 750,
#  '초': 751,
#  '이기다': 752,
#  '중국': 753,
#  '형': 754,
#  '온': 755,
#  '답': 756,
#  '각본': 757,
#  '에서도': 758,
#  '볼때': 759,
#  '간다': 760,
#  '억지스럽다': 761,
#  '래': 762,
#  '밑': 763,
#  '평': 764,
#  '달다': 765,
#  '바꾸다': 766,
#  '관람': 767,
#  '란': 768,
#  '오글거리다': 769,
#  '저런': 770,
#  '스타일': 771,
#  '세계': 772,
#  '이하': 773,
#  '선택': 774,
#  '선': 775,
#  '성우': 776,
#  '요소': 777,
#  '터': 778,
#  '둘': 779,
#  '복수': 780,
#  '항상': 781,
#  '일단': 782,
#  '가치': 783,
#  '똥': 784,
#  '햇': 785,
#  '어디서': 786,
#  '굳다': 787,
#  '에서는': 788,
#  '첫': 789,
#  '갖다': 790,
#  '뻔': 791,
#  '올리다': 792,
#  '흥행': 793,
#  '부르다': 794,
#  '참고': 795,
#  '그때': 796,
#  '가보다': 797,
#  '드': 798,
#  '여러': 799,
#  '보내다': 800,
#  '더욱': 801,
#  '걸리다': 802,
#  '치고': 803,
#  '확실하다': 804,
#  '너무하다': 805,
#  '라서': 806,
#  '들어가다': 807,
#  '또한': 808,
#  '아빠': 809,
#  '씩': 810,
#  '물론': 811,
#  '역대': 812,
#  '평범하다': 813,
#  '거기': 814,
#  '수가': 815,
#  '불편하다': 816,
#  '발': 817,
#  'ㅋㅋㅋㅋㅋ': 818,
#  '인거': 819,
#  '완성': 820,
#  '편집': 821,
#  '단순하다': 822,
#  '이냐': 823,
#  '상미': 824,
#  '멜로': 825,
#  '듣다': 826,
#  '끼다': 827,
#  '흐르다': 828,
#  '잃다': 829,
#  '전형': 830,
#  '짧다': 831,
#  '새끼': 832,
#  '허무하다': 833,
#  '짓': 834,
#  'ㅠㅠㅠ': 835,
#  '때리다': 836,
#  '역': 837,
#  '걸다': 838,
#  '어이': 839,
#  '술': 840,
#  '탄탄하다': 841,
#  '군': 842,
#  '귀': 843,
#  '가지다': 844,
#  '화이팅': 845,
#  '진행': 846,
#  '개그': 847,
#  '에겐': 848,
#  '돋보이다': 849,
#  '엉망': 850,
#  '불륜': 851,
#  '거지': 852,
#  '예상': 853,
#  '이에요': 854,
#  '잠': 855,
#  '사건': 856,
#  '즐기다': 857,
#  '병맛': 858,
#  '중반': 859,
#  '미화': 860,
#  '지겹다': 861,
#  '그게': 862,
#  '똑같다': 863,
#  '소중하다': 864,
#  '어쩔': 865,
#  '설명': 866,
#  '과거': 867,
#  '메다': 868,
#  '찾아보다': 869,
#  '적당하다': 870,
#  '프랑스': 871,
#  '중요하다': 872,
#  '화보': 873,
#  '키': 874,
#  '불다': 875,
#  '도저히': 876,
#  '손': 877,
#  '노력': 878,
#  '훈훈하다': 879,
#  '댓글': 880,
#  '그래픽': 881,
#  '흥미': 882,
#  '닿다': 883,
#  '갈다': 884,
#  '흥미진진': 885,
#  '거리': 886,
#  '여서': 887,
#  '죽음': 888,
#  '꿀잼': 889,
#  '싸우다': 890,
#  '티': 891,
#  '무조건': 892,
#  '원래': 893,
#  '몸': 894,
#  '취향': 895,
#  '식상하다': 896,
#  '척': 897,
#  '리': 898,
#  '화가': 899,
#  '새': 900,
#  '뛰어나다': 901,
#  '마르다': 902,
#  '현': 903,
#  '자극': 904,
#  '일이': 905,
#  '비추다': 906,
#  '배': 907,
#  '감상': 908,
#  '며': 909,
#  '역겹다': 910,
#  '만으로도': 911,
#  '만이': 912,
#  '한심하다': 913,
#  '예': 914,
#  '학교': 915,
#  '길다': 916,
#  '자꾸': 917,
#  '무': 918,
#  '액션영화': 919,
#  '관': 920,
#  '뭐라다': 921,
#  '예고편': 922,
#  '오히려': 923,
#  '괜히': 924,
#  '결혼': 925,
#  '암': 926,
#  '다가': 927,
#  '바보': 928,
#  '심리': 929,
#  '다루다': 930,
#  '이라니': 931,
#  '게임': 932,
#  '아저씨': 933,
#  '속편': 934,
#  '용도': 935,
#  '연기자': 936,
#  '보이': 937,
#  '잘만': 938,
#  '마무리': 939,
#  '나서다': 940,
#  '올': 941,
#  '강하다': 942,
#  '관계': 943,
#  '양': 944,
#  '나르다': 945,
#  '왠만하다': 946,
#  '천재': 947,
#  '법': 948,
#  '미안하다': 949,
#  '맨': 950,
#  'ㄷㄷ': 951,
#  '억지로': 952,
#  '표정': 953,
#  '땐': 954,
#  '참신하다': 955,
#  '영환': 956,
#  '귀신': 957,
#  '최근': 958,
#  '한다는': 959,
#  '순': 960,
#  '기억나다': 961,
#  '현재': 962,
#  '상상': 963,
#  '동': 964,
#  '흠': 965,
#  '유치': 966,
#  '전설': 967,
#  '젠': 968,
#  '타임': 969,
#  '촬영': 970,
#  '오빠': 971,
#  '헐다': 972,
#  '아쉬움': 973,
#  '봣': 974,
#  '오래': 975,
#  '다니다': 976,
#  '산': 977,
#  '대한민국': 978,
#  '조차': 979,
#  '빠져들다': 980,
#  '우연히': 981,
#  '엇': 982,
#  '흘리다': 983,
#  '짐': 984,
#  '전편': 985,
#  '길': 986,
#  '스타': 987,
#  '잊혀지다': 988,
#  '묘사': 989,
#  '메세지': 990,
#  '진지하다': 991,
#  '만의': 992,
#  '대작': 993,
#  '철학': 994,
#  '겁나다': 995,
#  '타': 996,
#  '프로그램': 997,
#  '마': 998,
#  '동화': 999,
#  '프로': 1000,
#  ...}

# %%
# 단어 등장 수
tokenizer.word_counts
# Out:
# OrderedDict([('아', 4121),
#              ('더빙', 572),
#              ('진짜', 8288),
#              ('짜증나다', 1002),
#              ('목소리', 374),
#              ('흠', 246),
#              ('포스터', 572),
#              ('보고', 4653),
#              ('초딩', 422),
#              ('영화', 50172),
#              ('줄', 1240),
#              ('오버', 142),
#              ('연기', 6326),
#              ('조차', 242),
#              ('가볍다', 360),
#              ('않다', 7718),
#              ('너', 670),
#              ('무재', 69),
#              ('밓었', 1),
#              ('다그', 75),
#              ('래서', 20),
#              ('보다', 40991),
#              ('추천', 1180),
#              ('한', 9615),
#              ('다', 10077),
#              ('교도소', 16),
#              ('이야기', 2171),
#              ('구먼', 11),
#              ('솔직하다', 1199),
#              ('재미', 3854),
#              ('는', 16911),
#              ('없다', 15519),
#              ('평점', 6245),
#              ('조정', 40),
#              ('사이', 222),
#              ('몬페', 2),
#              ('그', 5667),
#              ('의', 30737),
#              ('익살스럽다', 9),
#              ('가', 26578),
#              ('돋보이다', 288),
#              ('스파이더맨', 64),
#              ('에서', 6979),
#              ('늙다', 198),
#              ('보이다', 1073),
#              ('하다', 40759),
#              ('커스틴', 4),
#              ('던스트', 2),
#              ('너무나도', 206),
#              ('이쁘다', 1033),
#              ('막', 333),
#              ('걸음', 20),
#              ('마', 236),
#              ('떼다', 151),
#              ('세', 599),
#              ('부터', 1717),
#              ('초등학교', 116),
#              ('학년', 121),
#              ('생인', 6),
#              ('살다', 1173),
#              ('ㅋㅋㅋ', 2448),
#              ('별', 1918),
#              ('반개', 202),
#              ('도', 21058),
#              ('아깝다', 4373),
#              ('움', 1049),
#              ('원작', 1253),
#              ('긴장감', 832),
#              ('을', 23197),
#              ('제대로', 796),
#              ('살리다', 532),
#              ('욕', 778),
#              ('나오다', 6394),
#              ('이응경', 8),
#              ('길용우', 4),
#              ('연', 882),
#              ('기', 1967),
#              ('생활', 126),
#              ('이', 55570),
#              ('몇', 697),
#              ('년', 1989),
#              ('인지', 1170),
#              ('정말', 9662),
#              ('발', 299),
#              ('로', 7830),
#              ('해도', 440),
#              ('그것', 444),
#              ('보단', 508),
#              ('낫다', 543),
#              ('납치', 49),
#              ('감금', 11),
#              ('만', 8653),
#              ('반복', 151),
#              ('드라마', 5024),
#              ('가족', 937),
#              ('못', 5294),
#              ('사람', 4836),
#              ('모', 344),
#              ('엿', 207),
#              ('네', 3411),
#              ('액션', 2394),
#              ('있다', 12424),
#              ('안되다', 2320),
#              ('왜케', 131),
#              ('낮다', 1309),
#              ('꽤', 490),
#              ('볼', 2728),
#              ('데', 652),
#              ('헐리우드', 143),
#              ('식', 713),
#              ('화려하다', 368),
#              ('너무', 11069),
#              ('길들이다', 20),
#              ('걍', 678),
#              ('인피니트', 27),
#              ('짱', 1503),
#              ('이다', 13140),
#              ('볼때', 324),
#              ('마다', 675),
#              ('눈물나다', 174),
#              ('죽다', 1295),
#              ('년대', 687),
#              ('향수', 66),
#              ('자', 921),
#              ('극', 754),
#              ('허진호', 6),
#              ('감성', 420),
#              ('절제', 67),
#              ('멜로', 297),
#              ('달인', 21),
#              ('울면', 78),
#              ('서', 1723),
#              ('손', 277),
#              ('들', 18140),
#              ('고', 4500),
#              ('횡단보도', 1),
#              ('건너다', 8),
#              ('때', 4277),
#              ('뛰다', 171),
#              ('치다', 948),
#              ('올', 253),
#              ('뻔', 311),
#              ('이범수', 39),
#              ('드럽다', 233),
#              ('담백하다', 68),
#              ('깔끔하다', 174),
#              ('좋다', 11911),
#              ('신', 547),
#              ('문', 181),
#              ('사', 332),
#              ('로만', 139),
#              ('자꾸', 263),
#              ('잊어버리다', 15),
#              ('것', 6276),
#              ('취향', 273),
#              ('은', 15991),
#              ('존중', 36),
#              ('다지', 18),
#              ('내생', 106),
#              ('에', 27021),
#              ('극장', 794),
#              ('중', 3724),
#              ('가장', 1385),
#              ('노잼', 737),
#              ('노', 216),
#              ('감동', 4803),
#              ('임', 2070),
#              ('스토리', 5329),
#              ('어거지', 76),
#              ('ㄱ', 115),
#              ('냥', 178),
#              ('매번', 65),
#              ('긴장', 153),
#              ('되다', 8843),
#              ('재밋음', 81),
#              ('ㅠㅠ', 2473),
#              ('차다', 2301),
#              ('웃기다', 1368),
#              ('바스코', 15),
#              ('이기', 168),
#              ('면', 1873),
#              ('락스', 13),
#              ('코', 397),
#              ('라고', 1778),
#              ('끄다', 1490),
#              ('바비', 24),
#              ('아이돌', 148),
#              ('이라고', 689),
#              ('깔다', 211),
#              ('안달', 22),
#              ('난', 1868),
#              ('처럼', 1065),
#              ('굿바이', 21),
#              ('레닌', 6),
#              ('표절', 182),
#              ('인', 5461),
#              ('이해', 1893),
#              ('왜', 5110),
#              ('뒤', 530),
#              ('갈수록', 512),
#              ('없어지다', 135),
#              ('이건', 2566),
#              ('깨알', 68),
#              ('캐스팅', 572),
#              ('과', 6418),
#              ('질퍽', 3),
#              ('하', 2198),
#              ('지', 3015),
#              ('산뜻하다', 14),
#              ('내', 5884),
#              ('용구성', 6),
#              ('자다', 3609),
#              ('버무러진', 2),
#              ('일드', 37),
#              ('약탈', 4),
#              ('를', 16149),
#              ('위', 859),
#              ('변명', 29),
#              ('이르다', 392),
#              ('저', 2574),
#              ('놈', 739),
#              ('착하다', 217),
#              ('절대', 714),
#              ('아니다', 7738),
#              ('걸', 2315),
#              ('요', 4011),
#              ('나름', 760),
#              ('심오하다', 100),
#              ('뜻', 174),
#              ('듯', 2039),
#              ('그냥', 4049),
#              ('학생', 133),
#              ('선생', 64),
#              ('놀다', 106),
#              ('웃다', 854),
#              ('건', 878),
#              ('불가능하다', 48),
#              ('재미없다', 3416),
#              ('지루하다', 3479),
#              ('같다', 8341),
#              ('음식', 82),
#              ('인데', 2060),
#              ('바베트', 1),
#              ('만찬', 9),
#              ('하고', 3563),
#              ('넘다', 2108),
#              ('차이', 161),
#              ('남바', 1),
#              ('베트', 3),
#              ('게', 4907),
#              ('별로', 1947),
#              ('안', 5492),
#              ('핀란드', 8),
#              ('풍경', 120),
#              ('이라도', 400),
#              ('구', 582),
#              ('경', 132),
#              ('할랫', 1),
#              ('늘다', 1222),
#              ('ㅡㅡ', 2061),
#              ('평범하다', 300),
#              ('수작', 639),
#              ('이라', 947),
#              ('는걸', 176),
#              ('말씀드리다', 6),
#              ('주제', 378),
#              ('중반', 285),
#              ('짤랐을꺼', 1),
#              ('야', 1525),
#              ('그래서', 473),
#              ('납득', 55),
#              ('수', 3430),
#              ('그렇다', 3093),
#              ('꼭', 1621),
#              ('고추', 15),
#              ('털다', 27),
#              ('버리다', 1770),
#              ('카밀라', 10),
#              ('벨', 50),
#              ('발연기', 441),
#              ('재밋는뎅', 1),
#              ('센스', 81),
#              ('연출', 2075),
#              ('력', 708),
#              ('탁월하다', 66),
#              ('점', 7480),
#              ('엄포스', 3),
#              ('위력', 12),
#              ('다시', 2806),
#              ('한번', 1405),
#              ('깨닫다', 148),
#              ('해주다', 1644),
#              ('적남', 1),
#              ('꽃', 92),
#              ('검사', 55),
#              ('님', 1464),
#              ('완전', 2507),
#              ('명품', 136),
#              ('졸', 79),
#              ('쓰레기', 3391),
#              ('진부하다', 518),
#              ('도안', 131),
#              ('돼다', 1041),
#              ('ㅋㅋ', 4272),
#              ('아시', 42),
#              ('간', 513),
#              ('재밌다', 8652),
#              ('이리', 469),
#              ('라도', 406),
#              ('기대하다', 996),
#              ('죄인', 13),
#              ('아직도', 695),
#              ('인생', 1496),
#              ('최고', 5681),
#              ('패션', 38),
#              ('대한', 1055),
#              ('열정', 159),
#              ('안나', 216),
#              ('윈', 10),
#              ('투어', 7),
#              ('키이라', 16),
#              ('나이틀리', 8),
#              ('대체', 431),
#              ('정신장애', 2),
#              ('틱장애', 3),
#              ('허허', 85),
#              ('원', 573),
#              ('작가', 879),
#              ('정신', 579),
#              ('나가다', 524),
#              ('유령', 49),
#              ('재미있다', 3951),
#              ('관객', 617),
#              ('명', 686),
#              ('이네', 1039),
#              ('이렇게', 2325),
#              ('평가', 569),
#              ('받다', 1983),
#              ('모르다', 3208),
#              ('단순하다', 298),
#              ('은은하다', 35),
#              ('매력', 1364),
#              ('알바생', 53),
#              ('인가', 1081),
#              ('내용', 3811),
#              ('무섭다', 1416),
#              ('하나', 2810),
#              ('싱겁다', 55),
#              ('ㅇㅇ', 181),
#              ('ㅇ', 202),
#              ('시간', 3852),
#              ('낚임', 26),
#              ('오다', 2508),
#              ('두다', 534),
#              ('서리', 11),
#              ('굶주리다', 4),
#              ('맘', 530),
#              ('들다', 3196),
#              ('또', 1774),
#              ('방법', 141),
#              ('ㅜㅡ', 17),
#              ('윤제문', 13),
#              ('이라는', 843),
#              ('멋지다', 1254),
#              ('배우', 4282),
#              ('발견', 181),
#              ('소소하다', 144),
#              ('일', 1686),
#              ('탈', 96),
#              ('잔잔하다', 874),
#              ('미소', 202),
#              ('머금', 8),
#              ('음악', 1276),
#              ('조금', 806),
#              ('아쉽다', 1523),
#              ('주다', 3720),
#              ('싶다', 3051),
#              ('올리다', 311),
#              ('속지', 66),
#              ('말다', 1309),
#              ('낭비', 362),
#              ('돈', 2186),
#              ('리얼리티', 72),
#              ('뛰어나다', 271),
#              ('한데', 123),
#              ('크다', 1193),
#              ('공감', 1003),
#              ('간다', 324),
#              ('이민기', 44),
#              ('캐릭터', 1075),
#              ('정신의학', 1),
#              ('상', 469),
#              ('분노조절', 5),
#              ('장애', 54),
#              ('초기', 42),
#              ('증상', 3),
#              ('툭하면', 13),
#              ('패', 102),
#              ('물건', 38),
#              ('파손', 2),
#              ('오', 669),
#              ('바', 332),
#              ('초반', 663),
#              ('엔', 1605),
#              ('신선하다', 619),
#              ('가면', 155),
#              ('상태', 105),
#              ('불가', 163),
#              ('마이너스', 122),
#              ('ㅋ', 2494),
#              ('뮤비', 18),
#              ('수준', 1445),
#              ('딱', 783),
#              ('알', 1272),
#              ('ㅉㅉ', 381),
#              ('북한', 166),
#              ('이렇다', 4583),
#              ('만들다', 6500),
#              ('대다', 612),
#              ('우리', 1187),
#              ('사랑', 2939),
#              ('리스', 34),
#              ('타르', 8),
#              ('가르다', 39),
#              ('엔나', 1),
#              ('용의', 24),
#              ('주인', 46),
#              ('누', 46),
#              ('이랑', 952),
#              ('근친상간', 10),
#              ('이나', 1762),
#              ('다니다', 243),
#              ('소설', 426),
#              ('속', 1405),
#              ('에선', 353),
#              ('제일', 743),
#              ('메', 90),
#              ('라', 2064),
#              ('니스', 14),
#              ('터', 317),
#              ('드래곤', 24),
#              ('용이', 206),
#              ('웃음', 683),
#              ('감독', 4113),
#              ('토르', 27),
#              ('다크', 39),
#              ('월드', 41),
#              ('말', 4500),
#              ('잡수다', 6),
#              ('기본', 158),
#              ('선방', 4),
#              ('영혼', 122),
#              ('어루만지다', 12),
#              ('수도', 180),
#              ('거치다', 76),
#              ('상사', 18),
#              ('잠시', 88),
#              ('잊다', 598),
#              ('동화', 236),
#              ('행복하다', 500),
#              ('세르게이', 6),
#              ('작다', 235),
#              ('맵다', 7),
#              ('맛', 338),
#              ('보여주다', 1467),
#              ('포퐁', 1),
#              ('저그', 20),
#              ('콩', 63),
#              ('진호', 9),
#              ('가슴', 1325),
#              ('시리', 14),
#              ('자체', 1146),
#              ('난또', 6),
#              ('꼬마', 103),
#              ('애가', 96),
#              ('무슨', 1596),
#              ('원한', 22),
#              ('깊다', 749),
#              ('혼자', 392),
#              ('나대다', 24),
#              ('어쩌라고', 34),
#              ('전', 1456),
#              ('충격', 523),
#              ('적다', 516),
#              ('기분', 887),
#              ('완전하다', 149),
#              ('푹', 137),
#              ('꺼지다', 71),
#              ('느낌', 2093),
#              ('활', 34),
#              ('이라고는', 31),
#              ('무겁다', 163),
#              ('지독하다', 51),
#              ('차갑다', 72),
#              ('무자비하다', 12),
#              ('그저', 549),
#              ('일본인', 80),
#              ('상상력', 201),
#              ('대단하다', 886),
#              ('생각', 5312),
#              ('심심하다', 181),
#              ('백봉기', 1),
#              ('언제', 465),
#              ('그대로', 439),
#              ('들어맞다', 15),
#              ('예측', 62),
#              ('카리스마', 122),
#              ('악역', 180),
#              ('불알', 3),
#              ('당황', 90),
#              ('아무튼', 80),
#              ('중간', 992),
#              ('끝나다', 1331),
#              ('녹다', 78),
#              ('일상', 178),
#              ('밋밋하다', 128),
#              ('계속', 954),
#              ('전개도', 137),
#              ('느리다', 154),
#              ('주인공', 2375),
#              ('은희', 26),
#              ('한두', 33),
#              ('컷', 71),
#              ('소', 343),
#              ('극적', 60),
#              ('모습', 973),
#              ('짜증', 464),
#              ('ㅜㅜ', 945),
#              ('맨날', 146),
#              ('대만', 34),
#              ('전개', 1359),
#              ('좀', 3630),
#              ('빨리', 385),
#              ('가슴속', 34),
#              ('온', 326),
#              ('감정', 594),
#              ('헤집다', 5),
#              ('예요', 231),
#              ('많다', 2460),
#              ('다큐', 475),
#              ('우리나라', 647),
#              ('슬프다', 1290),
#              ('현대', 86),
#              ('사의', 29),
#              ('단면', 14),
#              ('대해', 534),
#              ('깊이', 215),
#              ('사죄', 7),
#              ('바로', 379),
#              ('잡기', 18),
#              ('위해', 706),
#              ('노력', 277),
#              ('말로', 169),
#              ('듣다', 297),
#              ('보도', 11),
#              ('연맹', 1),
#              ('민간인', 22),
#              ('학살', 46),
#              ('이정', 128),
#              ('이야', 613),
#              ('명백하다', 20),
#              ('살인', 227),
#              ('살인자', 51),
#              ('어디', 503),
#              ('예전', 463),
#              ('작품', 2975),
#              ('에피소드', 131),
#              ('재탕', 36),
#              ('삼', 162),
#              ('탕', 26),
#              ('사골', 21),
#              ('우려', 105),
#              ('먹듯', 10),
#              ('산', 243),
#              ('으로', 7930),
#              ('가다', 3208),
#              ('시청률', 344),
#              ('아예', 107),
#              ('이제', 866),
#              ('회', 433),
#              ('부작', 81),
#              ('이라니', 258),
#              ('김남길', 30),
#              ('백', 148),
#              ('짜다', 892),
#              ('연기력', 1030),
#              ('몰입도', 548),
#              ('에도', 747),
#              ('불구', 156),
#              ('손예진', 50),
#              ('ㅈㅈ', 3),
#              ('비슷하다', 429),
#              ('분', 1807),
#              ('한테', 788),
#              ('노래실력', 5),
#              ('뽑다', 135),
#              ('맞다', 1413),
#              ('박시환', 17),
#              ('망신', 26),
#              ('일본', 999),
#              ('이런', 1848),
#              ('건가', 515),
#              ('유치하다', 1275),
#              ('이틀', 25),
#              ('만에', 234),
#              ('근데', 993),
#              ('차', 186),
#              ('넣다', 349),
#              ('조작', 107),
#              ('안이', 17),
#              ('열리다', 48),
#              ('집', 486),
#              ('활짝', 9),
#              ('아무나', 56),
#              ('들어가다', 302),
#              ('문자', 16),
#              ('비번', 3),
#              ('걸리다', 308),
#              ('억지스럽다', 324),
#              ('그래도', 1015),
#              ('졸작', 590),
#              ('재밋네', 38),
#              ('달팽이', 8),
#              ('빨', 181),
#              ('라서', 304),
#              ('더', 4352),
#              ('어설프다', 722),
#              ('어이없다', 600),
#              ('결말', 1577),
#              ('부패하다', 7),
#              ('로마노프', 2),
#              ('왕조', 2),
#              ('기리', 34),
#              ('뭣같', 6),
#              ('온몸', 36),
#              ('항거', 3),
#              ('러시아', 72),
#              ('민중', 13),
#              ('폭도', 8),
#              ('냐', 1178),
#              ('무난', 69),
#              ('펴다', 81),
#              ('매우', 512),
#              ('실망', 901),
#              ('한국영', 624),
#              ('화', 1205),
#              ('흥행', 311),
#              ('코드', 171),
#              ('갈등', 138),
#              ('계', 197),
#              ('화해', 34),
#              ('남발', 40),
#              ('뻔하다', 1498),
#              ('뭐', 3732),
#              ('아햏햏', 4),
#              ('시작', 771),
#              ('분만', 99),
#              ('리플릿', 1),
#              ('사진', 110),
#              ('불안하다', 45),
#              ('단연', 129),
#              ('럼', 16),
#              ('먹다', 1684),
#              ('에게', 1592),
#              ('뭘', 649),
#              ('엉망', 288),
#              ('진창', 50),
#              ('개', 2234),
#              ('우뢰매', 82),
#              ('진정', 181),
#              ('위대하다', 211),
#              ('별루', 104),
#              ('내일', 76),
#              ('기대', 999),
#              ('조미', 11),
#              ('막문위', 2),
#              ('좋아하다', 2010),
#              ('가요', 134),
#              ('골깜', 1),
#              ('눈', 1130),
#              ('부라리다', 2),
#              ('쓰러지다', 40),
#              ('성룡', 394),
#              ('최악', 2166),
#              ('골', 93),
#              ('때리다', 293),
#              ('ㅋㅋㅋㅋ', 1055),
#              ('걸스데이', 3),
#              ('이혜리', 1),
#              ('서기', 34),
#              ('ㅋㅋㅋㅋㅋ', 299),
#              ('인공', 30),
#              ('주귀', 1),
#              ('여', 1596),
#              ('ㅋㅋㅋㅋㅋㅋ', 140),
#              ('인상', 577),
#              ('적', 8726),
#              ('어내스트', 1),
#              ('와', 4237),
#              ('셀레스틴', 2),
#              ('강추', 456),
#              ('에요', 372),
#              ('클라라', 54),
#              ('볼라', 52),
#              ('화신', 24),
#              ('설정', 679),
#              ('새롭다', 481),
#              ('메인', 41),
#              ('차차', 4),
#              ('신카이', 4),
#              ('마코토', 5),
#              ('작화', 57),
#              ('밉다', 452),
#              ('유', 186),
#              ('카나', 3),
#              ('잘', 2703),
#              ('대박', 1034),
#              ('진심', 909),
#              ('이훨', 1),
#              ('나', 5554),
#              ('두', 1603),
#              ('인거', 299),
#              ('고은님', 1),
#              ('쓰다', 1175),
#              ('노골', 42),
#              ('술', 291),
#              ('광고', 198),
#              ('어떻다', 1463),
#              ('킬링타임', 526),
#              ('크리스마스', 114),
#              ('떠오르다', 179),
#              ('행복', 159),
#              ('ㅎㅎㅎ', 343),
#              ('빠지다', 847),
#              ('쫌', 157),
#              ('산만하다', 189),
#              ('태어나다', 202),
#              ('처음', 2451),
#              ('불륜', 288),
#              ('로맨스', 423),
#              ('왕', 218),
#              ('아주', 979),
#              ('짬뽕', 64),
#              ('믹스', 15),
#              ('음향', 48),
#              ('별루더', 1),
#              ('기준', 118),
#              ('패널', 8),
#              ('가구', 7),
#              ('머', 512),
#              ('명작', 2007),
#              ('망치', 56),
#              ('서운하다', 7),
#              ('이상하다', 754),
#              ('몬스터', 31),
#              ('주식회사', 7),
#              ('너무나', 503),
#              ('소재', 1508),
#              ('흥미', 275),
#              ('끌', 164),
#              ('지만', 1160),
#              ('투', 114),
#              ('박하다', 56),
#              ('몰입', 907),
#              ('중국인', 38),
#              ('특유', 222),
#              ('과장', 138),
#              ('허풍', 8),
#              ('안간힘', 4),
#              ('쓸다', 533),
#              ('가상하다', 24),
#              ('고증', 59),
#              ('현', 270),
#              ('실감', 159),
#              ('떨어지다', 877),
#              ('거북', 17),
#              ('스럽다', 574),
#              ('도대체', 682),
#              ('까지', 3777),
#              ('스스로', 138),
#              ('과대', 65),
#              ('포장', 182),
#              ('불법체류자', 14),
#              ('잡다', 370),
#              ('우상화', 4),
#              ('미국', 686),
#              ('따뜻하다', 700),
#              ('뭥미', 87),
#              ('삶속', 7),
#              ('생애', 199),
#              ('전부', 347),
#              ('드러나다', 84),
#              ('점점', 338),
#              ('지난', 221),
#              ('후', 895),
#              ('남다', 1923),
#              ('대', 1561),
#              ('지나', 67),
#              ('순수하다', 430),
#              ('숀펜', 21),
#              ('또한', 302),
#              ('올레', 62),
#              ('공짜', 114),
#              ('헐다', 244),
#              ('문제', 567),
#              ('연기자', 255),
#              ('전혀', 1038),
#              ('배역', 111),
#              ('어울리다', 503),
#              ('그리고', 2004),
#              ('상대', 63),
#              ('따로', 114),
#              ('놓다', 620),
#              ('보아', 166),
#              ('라미란', 5),
#              ('아들', 424),
#              ('젤', 174),
#              ('욕심', 94),
#              ('어느', 458),
#              ('쪽', 122),
#              ('만이라도', 16),
#              ('빵점', 106),
#              ('베댓', 14),
#              ('잘쓰다', 30),
#              ('모자라다', 108),
#              ('도둑', 64),
#              ('뫼비우스', 5),
#              ('나라', 398),
#              ('만들어지다', 330),
#              ('믿어지다', 16),
#              ('찌릿짜릿', 1),
#              ('용기', 103),
#              ('교훈', 388),
#              ('영', 1506),
#              ('화이', 24),
#              ('당시', 729),
#              ('상황', 474),
#              ('주입', 13),
#              ('식이', 57),
#              ('전하', 71),
#              ('케이블', 206),
#              ('그만', 383),
#              ('다르다', 655),
#              ('덴', 10),
#              ('이냐', 298),
#              ('리투', 1),
#              ('차이밍량', 1),
#              ('섞이다', 70),
#              ('채', 104),
#              ('그릇', 22),
#              ('담기다', 154),
#              ('여군', 25),
#              ('잼', 813),
#              ('건지다', 1028),
#              ('엠비씨', 26),
#              ('질린다', 30),
#              ('한석규', 57),
#              ('김혜수', 57),
#              ('어딘', 6),
#              ('많이', 1929),
#              ('에볼라', 4),
#              ('바이러스', 30),
#              ('떠들다', 53),
#              ('석', 54),
#              ('해', 606),
#              ('성', 1730),
#              ('어떤', 178),
#              ('에서도', 325),
#              ('년전', 361),
#              ('보기', 1611),
#              ('믿다', 922),
#              ('힘들다', 636),
#              ('정도', 2585),
#              ('마지막', 2756),
#              ('후반', 460),
#              ('부가', 37),
#              ('살짝', 184),
#              ('하지만', 1105),
#              ('만해', 119),
#              ('떨다', 85),
#              ('용가리', 35),
#              ('짱짱맨', 55),
#              ('서다', 547),
#              ('감히', 119),
#              ('하나로', 116),
#              ('꼽', 44),
#              ('살', 597),
#              ('야하다', 1140),
#              ('나르다', 252),
#              ('고민', 194),
#              ('모건', 24),
#              ('프리', 43),
#              ('멀다', 583),
#              ('나이', 401),
#              ('여전하다', 234),
#              ('섹시하다', 129),
#              ('재방송', 46),
#              ('혹', 49),
#              ('시나', 13),
#              ('답', 326),
#              ('여운', 1022),
#              ('왠만하다', 252),
#              ('상업', 124),
#              ('퀄리티', 174),
#              ('쩔다', 219),
#              ('질', 510),
#              ('충분하다', 462),
#              ('개인', 828),
#              ('잔인하다', 435),
#              ('자극', 270),
#              ('노출씬', 11),
#              ('화끈하다', 107),
#              ('국산', 58),
#              ('아끼다', 84),
#              ('보임', 66),
#              ('끝내', 72),
#              ('지겹다', 284),
#              ('역시', 1979),
#              ('드니', 66),
#              ('일품', 116),
#              ('나다', 2242),
#              ('맥스', 41),
#              ('샘', 70),
#              ('죽이다', 666),
#              ('바랬다', 6),
#              ('괜찮다', 1780),
#              ('스러웟음', 1),
#              ('지네', 43),
#              ('뜨다', 354),
#              ('찍을껀데', 1),
#              ('면상', 16),
#              ('알다', 2938),
#              ('자신', 597),
#              ('어린이', 186),
#              ('어리다', 1442),
#              ('동심', 74),
#              ('멀리', 45),
#              ('무술', 113),
#              ('총을드', 1),
#              ('크리스토퍼', 31),
#              ('왈츠', 11),
#              ('타란티노', 67),
#              ('조합', 131),
#              ('이란', 761),
#              ('한국', 1333),
#              ('유명', 33),
#              ('한편', 333),
#              ('외국', 145),
#              ('상상', 247),
#              ('초월', 61),
#              ('유명하다', 205),
#              ('오랜', 759),
#              ('재밋', 384),
#              ('종방', 6),
#              ('되어다', 1363),
#              ('오늘', 584),
#              ('방도', 13),
#              ('방송', 439),
#              ('대본', 98),
#              ('완성', 299),
#              ('요즘', 852),
#              ('막장', 766),
#              ('지치다', 86),
#              ('수백향', 8),
#              ('바른', 6),
#              ('그리다', 675),
#              ('심하다', 438),
#              ('화이팅', 289),
#              ('조절', 113),
#              ('위원회', 29),
#              ('김혜선', 12),
#              ('김', 95),
#              ('순정', 23),
#              ('순', 248),
#              ('정이', 87),
#              ('역할', 231),
#              ('팜므파탈', 7),
#              ('로써', 125),
#              ('해내다', 152),
#              ('의외', 60),
#              ('사극', 177),
#              ('벌어지다', 59),
#              ('그녀', 333),
#              ('논란', 26),
#              ('왠지', 209),
#              ('코미디', 1069),
#              ('장면', 2425),
#              ('끝', 2039),
#              ('쯤', 388),
#              ('멍하다', 37),
#              ('한마디', 425),
#              ('ㅈ', 79),
#              ('공유', 64),
#              ('존잘', 20),
#              ('상쾌', 18),
#              ('발랄하다', 52),
#              ('껄끄런', 1),
#              ('유쾌하다', 534),
#              ('해설', 26),
#              ('소파', 7),
#              ...])

# %%
total_cnt = len(tokenizer.word_index)
total_cnt
# Out:
# 43770

# %%
#사용 단어 수를 지정하여 토큰화
tokenizer = Tokenizer(num_words = 30000)
tokenizer.fit_on_texts(train_df["token"])

# %%
threshold = 3
total_cnt = len(tokenizer.word_index)
rare_cnt = 0
total_freq = 0
rare_freq = 0

for key, value in tokenizer.word_counts.items():
    total_freq += value
    if value < threshold:
        rare_cnt += 1
        rare_freq += value

# %%
print("단어 집합의 크기 : ", total_cnt)
print("등장 빈도가 %d번 이하인 회귀 단어의 수 : %d" % (threshold-1, rare_cnt))
print("단어 집합에서 회귀 단어의 비율 : ", (rare_cnt / total_cnt) * 100)
print("전체 등장 빈도에서 회귀 단어 등장 빈도 비율 : ", (rare_freq / total_freq) * 100)
# Out:
# 단어 집합의 크기 :  43770
# 등장 빈도가 2번 이하인 회귀 단어의 수 : 24340
# 단어 집합에서 회귀 단어의 비율 :  55.608864519076995
# 전체 등장 빈도에서 회귀 단어 등장 빈도 비율 :  1.5747898974035586

# %%
x_train = tokenizer.texts_to_sequences(train_df["token"])
x_test = tokenizer.texts_to_sequences(test_df["token"])

# %%
x_train
# Out:
# [[64, 473, 27, 278, 677],
#  [965, 474, 54, 620, 2, 230, 1466, 37, 979, 694, 31],
#  [403, 2460, 25033, 2330, 5684, 3, 237, 21, 19],
#  [6507, 120, 8133, 234, 70, 11, 14, 39, 3619],
#  [1041,
#   19431,
#   42,
#   5,
#   9158,
#   37,
#   7,
#   849,
#   2,
#   2592,
#   33,
#   1126,
#   256,
#   4,
#   14255,
#   19432,
#   7,
#   1092,
#   270,
#   256],
#  [739,
#   5685,
#   998,
#   1405,
#   443,
#   159,
#   1707,
#   1640,
#   11578,
#   241,
#   2,
#   108,
#   142,
#   1109,
#   9,
#   58,
#   261],
#  [229, 5, 331, 8, 341, 503, 4],
#  [142,
#   1109,
#   9,
#   58,
#   349,
#   36,
#   9801,
#   14256,
#   315,
#   138,
#   1600,
#   1,
#   385,
#   135,
#   242,
#   20,
#   817,
#   29,
#   597,
#   592,
#   536,
#   493,
#   3134,
#   8134,
#   24,
#   1406,
#   1406,
#   1,
#   50,
#   11,
#   301,
#   9,
#   14,
#   37,
#   48,
#   4,
#   52,
#   24,
#   721,
#   1090,
#   83],
#  [110, 1, 14, 70, 16, 385, 113, 2],
#  [1548, 39, 1, 217, 554, 97, 24, 21, 410, 1457, 378, 683, 18, 5686, 16],
#  [399, 4704, 7, 183, 15, 27, 183, 15],
#  [759,
#   401,
#   1243,
#   220,
#   389,
#   5,
#   2543,
#   306,
#   357,
#   11579,
#   11,
#   621,
#   2512,
#   825,
#   5,
#   5514,
#   15],
#  [2257,
#   158,
#   877,
#   10,
#   56,
#   25034,
#   9802,
#   61,
#   1271,
#   296,
#   941,
#   791,
#   3698,
#   37,
#   1007,
#   48,
#   4],
#  [2486,
#   1244,
#   17,
#   491,
#   1199,
#   138,
#   746,
#   1488,
#   3,
#   3,
#   917,
#   6749,
#   42,
#   10,
#   9,
#   52,
#   15,
#   38,
#   8],
#  [895,
#   13,
#   3914,
#   21,
#   6068,
#   24,
#   27,
#   1833,
#   6,
#   343,
#   33,
#   3,
#   2,
#   75,
#   201,
#   367,
#   1066,
#   53,
#   126,
#   46,
#   9,
#   2302,
#   56,
#   53,
#   9,
#   2302],
#  [1721, 1220, 2569, 1384, 22, 2208, 105],
#  [115,
#   52,
#   10,
#   204,
#   6750,
#   7,
#   1286,
#   144,
#   7362,
#   650,
#   151,
#   186,
#   5058,
#   7,
#   1286,
#   144,
#   1421,
#   388,
#   1079,
#   2330,
#   1220,
#   186,
#   5365,
#   145,
#   38,
#   258,
#   256],
#  [5515, 11580, 1193, 45, 38, 13, 143, 4, 49, 504, 29, 528, 70, 1522],
#  [101,
#   20,
#   2487,
#   475,
#   35,
#   16277,
#   118,
#   90,
#   31,
#   7035,
#   40,
#   11581,
#   1,
#   78,
#   19433,
#   2487,
#   3844],
#  [14257,
#   306,
#   12,
#   322,
#   21,
#   4495,
#   655,
#   100,
#   366,
#   10,
#   13,
#   1061,
#   366,
#   10,
#   377,
#   30,
#   114,
#   68],
#  [355, 1920, 1245, 9, 16, 130, 67, 1540, 1, 2593, 35, 1834, 2, 11, 377, 30],
#  [3, 323, 31, 317, 3191],
#  [82,
#   80,
#   26,
#   2185,
#   2,
#   129,
#   9,
#   25035,
#   5,
#   9159,
#   79,
#   123,
#   1325,
#   25036,
#   16278,
#   5,
#   9159,
#   13,
#   120,
#   9,
#   16,
#   2185,
#   3,
#   70,
#   9,
#   16,
#   101,
#   97,
#   51,
#   14,
#   2185,
#   9,
#   139,
#   44,
#   36,
#   9803,
#   1648,
#   645,
#   461,
#   1546,
#   25037,
#   231,
#   592,
#   9,
#   139,
#   44,
#   36,
#   128],
#  [377, 813, 2, 7, 30, 416, 297, 1229, 11582],
#  [674, 11, 17, 859, 159, 80],
#  [19, 25038, 178, 563, 2902, 4, 81, 14, 88, 164, 88, 186],
#  [6751, 12, 4705, 153, 4],
#  [8646, 3090, 594],
#  [25039],
#  [2209, 16, 125, 379, 2544, 475, 389, 5, 2543, 563, 32],
#  [16279,
#   5,
#   7731,
#   8,
#   95,
#   198,
#   1422,
#   163,
#   25040,
#   2026,
#   2903,
#   189,
#   9,
#   37,
#   20,
#   17,
#   103,
#   1516,
#   50],
#  [2243, 84, 516, 1549, 266, 62, 3517, 526, 58],
#  [25, 142, 32, 1, 49, 564, 217],
#  [639, 281, 40, 7, 7363, 15, 7363, 15],
#  [386, 1, 50, 11, 40, 185, 5, 41],
#  [3771, 6, 259, 1340, 1067, 8647, 10575],
#  [6508, 9804, 7, 37, 4, 4, 606, 19434, 15, 16280, 15],
#  [2131, 472, 316, 464, 509, 3135, 297, 69],
#  [474, 11, 16, 256, 431, 13, 391, 267],
#  [1, 2, 7, 49, 112, 100, 477, 136, 85],
#  [822, 3989, 206, 5, 2],
#  [19,
#   2980,
#   254,
#   72,
#   9,
#   14,
#   195,
#   14,
#   204,
#   94,
#   9,
#   14,
#   103,
#   142,
#   2904,
#   2,
#   1200,
#   40,
#   1110,
#   71,
#   123,
#   58,
#   261,
#   103,
#   4823],
#  [102, 499, 8135, 21, 1, 14258],
#  [20, 505, 6, 87, 563, 152, 3, 152, 3, 1476, 1, 14, 6283],
#  [7364,
#   328,
#   228,
#   60,
#   12,
#   1201,
#   4,
#   266,
#   1450,
#   160,
#   1981,
#   1,
#   320,
#   1111,
#   12,
#   9805,
#   51,
#   4,
#   222,
#   13,
#   335,
#   179,
#   105,
#   32,
#   76,
#   89,
#   39,
#   792,
#   89,
#   32,
#   76],
#  [39, 6, 2545, 218, 71, 691, 119, 691, 126],
#  [2392,
#   7,
#   901,
#   1623,
#   235,
#   277,
#   13,
#   44,
#   760,
#   3400,
#   255,
#   11,
#   25041,
#   565,
#   12744,
#   2948,
#   3518,
#   16281,
#   15,
#   7365,
#   52,
#   1895,
#   56,
#   349,
#   79,
#   3772,
#   19435,
#   79,
#   335,
#   404,
#   747,
#   15,
#   357,
#   407,
#   166,
#   429,
#   1369,
#   528,
#   3400,
#   464,
#   1853,
#   277,
#   1315],
#  [1627,
#   11,
#   49,
#   14,
#   104,
#   6069,
#   54,
#   2,
#   193,
#   347,
#   225,
#   24,
#   4,
#   671,
#   1295,
#   33,
#   55,
#   34,
#   119,
#   435],
#  [145, 236, 2, 12, 92, 4],
#  [410,
#   403,
#   4063,
#   9806,
#   3699,
#   25042,
#   9,
#   5059,
#   3293,
#   1,
#   22,
#   89,
#   3294,
#   295,
#   8648,
#   154,
#   4,
#   976,
#   611,
#   199,
#   705,
#   365,
#   228,
#   366,
#   1,
#   306,
#   1,
#   2053,
#   127,
#   7036,
#   778,
#   15,
#   50,
#   199,
#   705,
#   5060,
#   1093,
#   365,
#   228,
#   83,
#   393,
#   65,
#   189,
#   4706,
#   3700,
#   3570,
#   11,
#   57,
#   64,
#   11583,
#   1348,
#   14259,
#   13,
#   4],
#  [2,
#   7,
#   52,
#   5,
#   1628,
#   8,
#   7732,
#   230,
#   1209,
#   16,
#   2303,
#   443,
#   6070,
#   12,
#   2082,
#   445,
#   999,
#   26,
#   2,
#   6,
#   547],
#  [178,
#   11584,
#   1003,
#   6751,
#   5,
#   10576,
#   732,
#   8,
#   188,
#   25043,
#   5687,
#   2612,
#   9160,
#   7,
#   760],
#  [112, 215, 7037, 51, 3, 50, 7, 152, 16, 53, 42, 247],
#  [11585, 100, 1881, 1982, 169, 5366, 1, 361, 4, 67, 656, 5061, 114, 4064],
#  [69],
#  [191, 17],
#  [41],
#  [18,
#   511,
#   519,
#   313,
#   8,
#   1415,
#   1507,
#   2407,
#   4,
#   124,
#   4065,
#   379,
#   4308,
#   94,
#   9,
#   14,
#   1092,
#   1316,
#   3046,
#   2393,
#   7733,
#   489,
#   2225,
#   10,
#   5,
#   1115,
#   13,
#   20,
#   314,
#   26,
#   47,
#   1,
#   87],
#  [1202, 2],
#  [25044, 567, 36],
#  [3, 598, 6752, 2644, 1629, 14, 1210],
#  [16282, 1, 36, 2054, 2226, 2, 7, 284, 6, 214, 124],
#  [813, 199, 6, 2258, 813, 1221, 335, 1578, 965],
#  [3,
#   294,
#   3,
#   1508,
#   1373,
#   111,
#   45,
#   4824,
#   11,
#   4136,
#   2408,
#   36,
#   725,
#   2723,
#   45,
#   290,
#   6,
#   569,
#   1,
#   300,
#   1430,
#   567,
#   214,
#   138,
#   4066,
#   79,
#   16,
#   209,
#   77,
#   665,
#   665,
#   300],
#  [92, 4, 89, 4067, 755, 451, 8, 12745, 2, 1012, 20, 41],
#  [106,
#   52,
#   10,
#   1,
#   1,
#   559,
#   12,
#   54,
#   413,
#   221,
#   2112,
#   4496,
#   4,
#   7038,
#   6,
#   500,
#   1070,
#   47,
#   79,
#   10577,
#   79,
#   672,
#   6071,
#   380,
#   878,
#   4,
#   4,
#   1278,
#   24,
#   826,
#   8136,
#   25045,
#   42,
#   5367,
#   3295,
#   1,
#   1579,
#   9,
#   160,
#   230,
#   434,
#   101,
#   5688,
#   1029,
#   15,
#   3047,
#   10,
#   13,
#   19,
#   544,
#   16],
#  [571,
#   91,
#   255,
#   1550,
#   3915,
#   1322,
#   4825,
#   5516,
#   1854,
#   8649,
#   236,
#   56,
#   72,
#   13,
#   977,
#   28,
#   86,
#   722,
#   13,
#   1823,
#   44,
#   36,
#   321,
#   604,
#   859,
#   129,
#   2210,
#   931],
#  [4399, 5, 1423, 32, 312, 271, 35, 407, 490, 363, 1363, 79, 80, 3091, 16283],
#  [25, 608, 2, 12, 44, 3, 148, 10, 346, 231, 69, 130],
#  [12746, 28, 1523, 197, 6284, 1, 509, 27, 4826, 15],
#  [64, 279, 2, 19, 146, 521, 223],
#  [4953,
#   1004,
#   19,
#   3,
#   25,
#   282,
#   1170,
#   44,
#   6,
#   3772,
#   715,
#   1824,
#   4,
#   4,
#   1170,
#   6285,
#   3192,
#   555,
#   6285,
#   9161,
#   3192,
#   2860,
#   807,
#   6509,
#   12,
#   1824,
#   4,
#   16284,
#   1,
#   44,
#   802,
#   108,
#   88,
#   317,
#   761,
#   275,
#   72,
#   247,
#   11,
#   17],
#  [452],
#  [3773, 68, 9807, 7, 1203, 806, 59, 25],
#  [374, 209, 440, 173],
#  [10578,
#   19436,
#   19437,
#   12,
#   4068,
#   11,
#   11586,
#   13,
#   2,
#   3916,
#   28,
#   16285,
#   4,
#   2394,
#   7366,
#   10,
#   1,
#   489,
#   9808,
#   239],
#  [72, 209, 11, 2461, 21, 2211, 78, 3],
#  [529, 310],
#  [425,
#   233,
#   793,
#   1272,
#   1493,
#   1493,
#   1132,
#   6,
#   199,
#   1493,
#   4069,
#   53,
#   39,
#   32,
#   3620,
#   793,
#   184,
#   74],
#  [14260, 14260, 14260],
#  [74, 239, 352, 79, 1936, 6, 36, 25046, 1790, 3, 3351],
#  [1566, 41, 151, 4],
#  [65,
#   1,
#   6510,
#   161,
#   2,
#   12,
#   34,
#   431,
#   171,
#   412,
#   57,
#   4,
#   85,
#   850,
#   3092,
#   117,
#   3092,
#   15],
#  [101, 74, 239, 2186, 239],
#  [20, 84, 2, 15],
#  [1204, 1080, 2, 41, 126],
#  [1866, 15],
#  [2304, 1, 280, 22],
#  [282, 8137, 7, 19438, 132, 1530],
#  [108, 27, 25047, 62, 250, 19439, 61, 3621, 62],
#  [653, 2, 75, 122, 45, 130, 62],
#  [2021, 836, 260, 16286, 25048, 78, 22],
#  [4070, 7, 270],
#  [103, 25, 818, 1423, 4400, 25049, 170, 261, 1483],
#  [468, 23, 45, 2, 15],
#  [25050, 63, 19440, 103, 580, 680, 20, 25],
#  [69, 2, 15],
#  [2949, 3012, 56, 5062, 3, 30],
#  [27, 3, 18, 221, 2, 19],
#  [396, 1, 25, 556, 1550, 40, 33, 3571, 46, 9, 14261, 36, 25],
#  [14262,
#   12747,
#   5,
#   2820,
#   63,
#   586,
#   1171,
#   63,
#   94,
#   16287,
#   7,
#   37,
#   12,
#   98,
#   163,
#   59,
#   269,
#   1,
#   15],
#  [82, 307, 25051, 43, 475, 168, 48, 21, 130],
#  [320, 47, 3, 97, 24, 21, 2, 819, 26, 104],
#  [65, 189, 87, 25052, 240, 2, 44, 3],
#  [195, 31, 46, 9, 128],
#  [2, 199, 761, 3519, 23, 45, 840, 1127, 12, 77, 3989, 2209, 16, 4, 190],
#  [508],
#  [1732, 4, 1215, 2],
#  [69, 3, 206, 23, 45, 1341, 267, 68, 726],
#  [222, 6, 1415, 326, 97, 81, 16, 2, 1353, 1158, 4],
#  [1112, 107, 28, 2, 3, 284, 6, 36, 851, 1, 617, 239],
#  [1056, 569, 289, 209, 12, 2594, 28, 6753, 4, 3193, 24, 195, 4],
#  [234, 145, 25053, 127, 71, 691, 124],
#  [269],
#  [722,
#   1680,
#   1,
#   22,
#   9809,
#   10579,
#   10,
#   530,
#   4,
#   133,
#   50,
#   19,
#   2861,
#   83,
#   128,
#   40,
#   7,
#   19,
#   10580],
#  [72, 1, 358],
#  [4309, 10581, 25, 3],
#  [72, 209, 7, 545, 1373],
#  [181, 11, 882, 12, 1307, 244, 120, 209, 7, 1733, 2862, 308, 1, 113],
#  [377, 3, 84, 2],
#  [3774,
#   1042,
#   5,
#   1494,
#   9810,
#   16,
#   256,
#   14263,
#   502,
#   878,
#   13,
#   5063,
#   2754,
#   35,
#   903,
#   1342,
#   318,
#   396,
#   1,
#   6286,
#   471,
#   394,
#   42,
#   10,
#   13,
#   49,
#   112,
#   73,
#   1495,
#   12,
#   2570,
#   1194,
#   118,
#   11,
#   38,
#   242],
#  [67,
#   7039,
#   836,
#   681,
#   2,
#   144,
#   17,
#   169,
#   14264,
#   12,
#   34,
#   392,
#   5,
#   383,
#   396,
#   101,
#   2096],
#  [135, 5, 10582, 6, 111, 5, 1125, 7, 717, 2150, 130, 4],
#  [142, 733, 86],
#  [139, 19],
#  [3, 554, 1044, 311, 6, 141, 69],
#  [30, 1, 51, 49, 32, 175, 15],
#  [135,
#   1,
#   2513,
#   95,
#   3,
#   22,
#   2,
#   95,
#   3,
#   42,
#   607,
#   92,
#   6,
#   53,
#   105,
#   5517,
#   5,
#   37,
#   808],
#  [2645,
#   6,
#   1734,
#   29,
#   16,
#   3,
#   62,
#   972,
#   46,
#   7,
#   480,
#   7,
#   30,
#   936,
#   10,
#   1,
#   268,
#   1777,
#   295,
#   546,
#   31,
#   134,
#   2613,
#   60,
#   10,
#   79,
#   19,
#   1735,
#   427,
#   26,
#   101,
#   936,
#   10,
#   9,
#   480,
#   16,
#   1296,
#   11,
#   307,
#   103,
#   139,
#   126,
#   12748,
#   79,
#   614,
#   1,
#   1246,
#   97,
#   24,
#   4],
#  [18, 2006, 1, 106, 2, 579, 4, 1630, 6511, 341, 188],
#  [64, 1835],
#  [7040, 1, 57, 8, 289, 4401],
#  [289, 1810, 31],
#  [2, 2595, 10, 154, 12749, 4, 26, 649, 33, 750, 6512],
#  [3916, 1, 25054, 43, 168, 1882, 12, 86],
#  [20, 69, 661, 23, 45, 182, 5064, 83, 68],
#  [372, 5, 561, 35, 674, 12, 7367, 2821, 30, 331, 16, 25, 2409, 11, 91],
#  [1094, 33, 668, 36, 76],
#  [409, 8650, 823, 25055, 25056, 1, 94, 9, 44, 2430, 1867, 2594, 5368, 6, 1374],
#  [4954, 334, 14, 74, 4, 272, 128, 334, 14, 4827, 19, 334, 14, 4402, 321],
#  [17],
#  [2822, 2823, 37, 24, 849, 2, 11587, 90, 85, 140, 374, 2],
#  [234,
#   14265,
#   4403,
#   7,
#   2981,
#   2950,
#   439,
#   158,
#   3,
#   22,
#   2,
#   129,
#   91,
#   156,
#   154,
#   1222,
#   144,
#   758,
#   170,
#   693,
#   2,
#   151,
#   165,
#   166,
#   304,
#   417,
#   99,
#   29,
#   20,
#   98,
#   34,
#   3,
#   96,
#   575,
#   3845,
#   1180,
#   179,
#   253,
#   1,
#   99,
#   144,
#   416,
#   388,
#   3,
#   71,
#   1,
#   58,
#   31,
#   2],
#  [97, 1664],
#  [69, 9810, 2132, 218],
#  [3990, 27, 2905, 15, 104],
#  [1,
#   2,
#   12,
#   321,
#   492,
#   3,
#   1665,
#   40,
#   185,
#   41,
#   5,
#   2,
#   75,
#   1708,
#   3401,
#   8,
#   81,
#   16,
#   91,
#   190,
#   446,
#   64,
#   249,
#   945,
#   322,
#   21,
#   1140,
#   8,
#   198,
#   59,
#   4,
#   22,
#   71,
#   134,
#   5065,
#   3457,
#   460,
#   643,
#   7,
#   87,
#   1005,
#   1567],
#  [316,
#   7,
#   139,
#   19,
#   40,
#   1093,
#   27,
#   139,
#   126,
#   1430,
#   67,
#   280,
#   79,
#   3296,
#   4,
#   3136,
#   7368,
#   79,
#   3,
#   756,
#   14,
#   27],
#  [133, 9, 55, 133, 1, 16, 89, 54, 152, 3, 273, 1, 141, 2],
#  [64,
#   27,
#   335,
#   24,
#   59,
#   877,
#   77,
#   3,
#   946,
#   1612,
#   2,
#   48,
#   90,
#   31,
#   1247,
#   1055,
#   34,
#   533,
#   81,
#   16,
#   179,
#   275,
#   572,
#   69,
#   332,
#   23,
#   28,
#   335,
#   24,
#   59,
#   603,
#   59,
#   904,
#   23,
#   28,
#   8138,
#   9,
#   1825,
#   4,
#   190,
#   4,
#   2786,
#   2,
#   127,
#   140,
#   2151,
#   130,
#   2546],
#  [668, 77, 1307, 56, 321, 2395, 127, 861, 861],
#  [64],
#  [137, 2547, 29, 5, 37, 11, 1709, 116, 3572, 7, 2431, 8, 406, 11588],
#  [355, 150, 91, 15],
#  [18, 17, 2],
#  [20, 310, 25057],
#  [60,
#   10,
#   13,
#   3458,
#   10,
#   44,
#   702,
#   146,
#   2,
#   25058,
#   49,
#   44,
#   702,
#   27,
#   85,
#   6513,
#   347,
#   3,
#   93,
#   49,
#   3458,
#   447,
#   10,
#   13,
#   85],
#  [1172, 7, 132, 40, 194, 23, 2346, 13, 3352, 702, 493],
#  [1750, 45, 1, 49, 25059, 43],
#  [32],
#  [4310, 8139, 63, 2514, 5, 1551, 354, 105],
#  [212, 705, 4137, 740, 13, 30, 1438, 705, 963, 2683, 21, 1098, 2, 15],
#  [356, 24, 6, 666, 231, 2, 3],
#  [11589,
#   208,
#   179,
#   458,
#   739,
#   7369,
#   98,
#   3,
#   599,
#   1951,
#   1,
#   554,
#   820,
#   9,
#   16,
#   124,
#   136,
#   324,
#   50,
#   10,
#   5,
#   353,
#   6,
#   2113,
#   9811,
#   13,
#   20,
#   11590,
#   50,
#   15,
#   439,
#   68,
#   1210,
#   10,
#   9,
#   402,
#   600,
#   440,
#   31,
#   845],
#  [39,
#   1751,
#   4497,
#   33,
#   36,
#   393,
#   7734,
#   13,
#   2304,
#   1,
#   102,
#   1991,
#   5197,
#   960,
#   2097,
#   1013,
#   1,
#   365,
#   15,
#   10583,
#   1608,
#   42,
#   99,
#   73,
#   98,
#   1392,
#   230,
#   13,
#   20,
#   2724,
#   15,
#   37,
#   135,
#   21,
#   52,
#   171,
#   324,
#   1225,
#   33,
#   2755,
#   16,
#   741,
#   6,
#   259,
#   315,
#   138,
#   4828,
#   13,
#   1084,
#   257,
#   5,
#   21,
#   109,
#   26,
#   393],
#  [2, 131, 509, 61, 662, 6, 3846, 19, 3, 612, 36, 126, 2244, 26],
#  [2596, 5689, 726],
#  [6072, 3013, 2, 19, 57, 4, 25060, 156, 354, 181, 12, 501, 4829, 4],
#  [10584, 6, 684, 803, 1826, 1175, 97, 338, 7, 14, 91],
#  [16288],
#  [7041,
#   7042,
#   1,
#   1172,
#   226,
#   2410,
#   23,
#   45,
#   2114,
#   7,
#   2007,
#   4,
#   31,
#   317,
#   93,
#   253,
#   932,
#   13,
#   723,
#   31,
#   4830,
#   328,
#   111,
#   1,
#   18,
#   6754,
#   139,
#   82,
#   497,
#   9,
#   1649],
#  [1279,
#   2,
#   129,
#   2170,
#   5518,
#   850,
#   141,
#   1326,
#   9,
#   48,
#   1173,
#   72,
#   13,
#   184,
#   791,
#   111,
#   10,
#   677,
#   9,
#   18,
#   44,
#   546,
#   1287,
#   33,
#   1271,
#   509,
#   1119,
#   307,
#   4955,
#   56,
#   89,
#   1791,
#   5,
#   100,
#   1062,
#   333,
#   2,
#   7043,
#   30,
#   9162,
#   9,
#   113],
#  [194, 3, 554, 43, 132, 2787],
#  [9812, 45, 230, 85, 3],
#  [339, 11, 186, 100, 127],
#  [1,
#   2,
#   530,
#   15,
#   49,
#   136,
#   3,
#   592,
#   1,
#   5369,
#   1,
#   2,
#   11,
#   60,
#   10,
#   35,
#   2788,
#   10,
#   1,
#   65,
#   5,
#   8140,
#   15],
#  [435, 122],
#  [20, 162, 2, 15],
#  [904, 23, 45, 38, 6, 6287, 4311, 1, 3, 250, 8, 1405, 729, 125, 379],
#  [19441, 78, 540, 3402, 116, 646],
#  [20,
#   569,
#   5,
#   1559,
#   12,
#   188,
#   2,
#   652,
#   25061,
#   21,
#   124,
#   8141,
#   48,
#   570,
#   213,
#   187,
#   5,
#   594,
#   12,
#   2789,
#   3,
#   9813,
#   45,
#   130,
#   3403,
#   4404,
#   320,
#   2725,
#   1937,
#   5,
#   222,
#   3353,
#   2488,
#   419,
#   278,
#   99,
#   29,
#   638,
#   419,
#   2],
#  [53, 53, 300, 20, 41, 83, 68],
#  [142,
#   32,
#   1467,
#   58,
#   482,
#   72,
#   1,
#   516,
#   349,
#   309,
#   44,
#   36,
#   54,
#   25,
#   4,
#   52,
#   620,
#   10,
#   1541,
#   2863,
#   18,
#   899,
#   940,
#   397,
#   38,
#   9,
#   97,
#   51,
#   14,
#   305,
#   218,
#   67,
#   494,
#   622,
#   1921,
#   21,
#   66,
#   26],
#  [43, 946, 569, 93],
#  [2133, 716, 161, 19442, 415, 109, 705, 7044, 137, 7045, 13, 2860, 4, 30],
#  [153],
#  [223, 80, 855, 1, 102],
#  [382, 1937, 709, 32, 24, 6755],
#  [14266,
#   5370,
#   11,
#   17,
#   19443,
#   13,
#   394,
#   49,
#   7046,
#   93,
#   14,
#   7047,
#   1385,
#   8,
#   415,
#   191,
#   6,
#   2864,
#   3847,
#   6288,
#   35,
#   1385,
#   159,
#   5519,
#   102,
#   405,
#   118,
#   12750,
#   668,
#   77,
#   4],
#  [10585, 21, 91, 542, 38, 9, 54, 89],
#  [40, 1141, 5, 41, 5, 2],
#  [1792, 18, 195, 69, 3, 422, 5, 4831, 377, 448, 1280, 7370, 2614, 1530],
#  [2281, 2726, 2865, 8, 9814, 4, 4, 451, 5, 2512, 7, 1099, 18, 2486, 2],
#  [145,
#   19444,
#   25062,
#   171,
#   4405,
#   326,
#   153,
#   751,
#   1004,
#   4405,
#   62,
#   145,
#   377,
#   445,
#   31,
#   537,
#   1549,
#   4],
#  [147,
#   12,
#   627,
#   481,
#   661,
#   8,
#   3297,
#   68,
#   116,
#   141,
#   185,
#   8,
#   683,
#   241,
#   57,
#   309,
#   44,
#   36],
#  [355, 422, 6, 3622, 87, 17, 62, 397, 47, 192, 694, 1855, 237, 68],
#  [822, 1650, 411, 8, 1778],
#  [1,
#   51,
#   678,
#   6,
#   750,
#   1530,
#   30,
#   571,
#   6,
#   34,
#   95,
#   276,
#   21,
#   521,
#   68,
#   265,
#   18,
#   251,
#   12751,
#   68,
#   265],
#  [123, 647, 2, 19, 105, 54, 315, 1, 405, 3, 123, 298, 105],
#  [1057,
#   2,
#   912,
#   230,
#   81,
#   16,
#   621,
#   1,
#   727,
#   116,
#   1,
#   659,
#   1907,
#   95,
#   1531,
#   31,
#   42,
#   659,
#   1651,
#   2411,
#   4,
#   3623,
#   1,
#   230,
#   81,
#   16,
#   88,
#   621],
#  [333, 5198, 283, 75, 33, 574, 1386, 2282],
#  [2462, 13, 324, 528, 5520, 10, 1, 19, 367, 167, 393, 2684, 145, 19],
#  [4138, 5, 21, 1, 9163, 6514, 6756, 300, 53],
#  [8651,
#   63,
#   92,
#   4,
#   22,
#   1779,
#   23,
#   2463,
#   42,
#   71,
#   1,
#   286,
#   22,
#   31,
#   329,
#   5521,
#   5,
#   2727,
#   8,
#   7371,
#   4,
#   338,
#   522,
#   8,
#   329,
#   1066,
#   7,
#   3246,
#   4,
#   2187,
#   1086,
#   29,
#   59,
#   93,
#   4,
#   47,
#   1477,
#   19,
#   808,
#   329,
#   1066,
#   7,
#   482,
#   2548,
#   8,
#   2512,
#   742,
#   1641,
#   329,
#   177,
#   8,
#   4,
#   878,
#   4,
#   59,
#   188,
#   17,
#   184],
#  [1458,
#   71,
#   6,
#   4,
#   279,
#   2,
#   10,
#   13,
#   717,
#   117,
#   452,
#   15,
#   279,
#   2,
#   472,
#   762,
#   19,
#   1248],
#  [6289, 5, 509, 134, 14267, 5, 7372, 491],
#  [64, 20, 16289, 18, 360, 25063, 9, 323, 66, 20, 118],
#  [6757, 240, 89],
#  [683, 3917, 16290, 361, 62, 1908, 68, 62, 4956, 315, 138, 20, 98, 4, 104],
#  [6758, 322, 21, 2396, 2464, 2],
#  [53, 23, 45, 2],
#  [101, 57, 1, 743, 14, 67, 2866, 3],
#  [12752, 227, 52, 10, 5, 25, 228, 92, 2],
#  [137, 16291, 5, 3137, 20, 93, 14, 42, 3775, 4606, 153, 41],
#  [18, 18, 879],
#  [1, 66, 9815, 2465, 33, 7048, 472, 9, 1495, 349, 4, 31, 260],
#  [64, 18, 538, 56, 2489, 326, 184, 40, 8142, 6, 1, 2, 16],
#  [543, 1, 638, 2212, 2, 137, 623, 39, 13, 304, 14],
#  [10586, 3093, 5, 3991, 8, 3918, 3573, 1457, 91, 75, 201, 82, 452],
#  [1181, 4957, 3048, 125, 242, 196, 156, 1354, 45, 2],
#  [1003,
#   94,
#   363,
#   1128,
#   4,
#   3298,
#   796,
#   42,
#   124,
#   8,
#   95,
#   149,
#   3,
#   71,
#   15,
#   109,
#   94,
#   94,
#   337,
#   94,
#   94,
#   1983,
#   94,
#   94,
#   153,
#   14,
#   50],
#  [307, 70, 14, 18, 39, 224, 6759],
#  [478,
#   82,
#   190,
#   4958,
#   29,
#   9,
#   102,
#   883,
#   31,
#   833,
#   517,
#   80,
#   2,
#   56,
#   11591,
#   94,
#   9,
#   14,
#   2,
#   19],
#  [3992, 20, 37, 98, 4, 1016, 10, 9, 37, 20, 98, 4],
#  [196, 13, 648, 648, 13, 196],
#  [458, 14268, 2756, 1000, 29, 3, 208, 678, 5, 529, 387, 91, 15],
#  [622, 5, 4229, 63, 964, 202],
#  [5880, 79, 627, 481, 59, 25, 260],
#  [2,
#   12,
#   3,
#   180,
#   5,
#   3993,
#   12,
#   2867,
#   124,
#   4139,
#   320,
#   80,
#   31,
#   563,
#   95,
#   3,
#   2,
#   7735,
#   1613,
#   576,
#   3094,
#   19445,
#   35,
#   2022,
#   9,
#   468,
#   23],
#  [479, 21, 317, 17, 1909, 7, 18, 251, 840, 118, 19],
#  [135,
#   796,
#   372,
#   291,
#   236,
#   649,
#   6,
#   55,
#   709,
#   617,
#   7,
#   14,
#   386,
#   4140,
#   5,
#   4406,
#   4312,
#   37,
#   11,
#   512,
#   150,
#   176,
#   2822,
#   5,
#   191,
#   156,
#   329,
#   1431,
#   3192,
#   2,
#   1,
#   61,
#   2822,
#   346,
#   7373,
#   86],
#  [782, 5522, 4, 1176, 26, 3848, 957, 26, 2397, 379],
#  [6290,
#   312,
#   880,
#   54,
#   198,
#   662,
#   97,
#   24,
#   21,
#   2,
#   819,
#   26,
#   3,
#   138,
#   7,
#   115,
#   169,
#   7736,
#   254,
#   220,
#   4407,
#   6,
#   5690,
#   2685,
#   40,
#   797,
#   220,
#   4407,
#   6,
#   739,
#   241,
#   15,
#   26,
#   53,
#   9,
#   14,
#   27,
#   7736,
#   768,
#   2,
#   6,
#   4408,
#   6,
#   61,
#   4498,
#   48,
#   1439,
#   84,
#   2,
#   5881,
#   310],
#  [1,
#   71,
#   77,
#   2245,
#   3919,
#   23,
#   45,
#   50,
#   54,
#   89,
#   3,
#   3,
#   1466,
#   118,
#   11,
#   37,
#   10,
#   1,
#   1649,
#   37,
#   2305,
#   403,
#   25064,
#   43,
#   19446,
#   14269,
#   837,
#   9816,
#   43,
#   14270,
#   14271,
#   495,
#   79,
#   1568,
#   530,
#   285,
#   87,
#   420,
#   2757,
#   6515,
#   129,
#   3920,
#   21,
#   38,
#   24,
#   54,
#   89],
#  [5371, 5, 3354, 254, 25065, 5, 3354, 254],
#  [190, 55, 963, 8, 314],
#  [77, 615, 495, 4, 513, 6, 259, 989, 7, 78, 85],
#  [279,
#   33,
#   5691,
#   749,
#   34,
#   413,
#   705,
#   5691,
#   28,
#   7374,
#   7737,
#   226,
#   101,
#   77,
#   2412,
#   30],
#  [21, 25066, 7, 7049, 3, 40, 3299, 19447, 7049, 2982, 128],
#  [21, 411, 526, 964, 3459, 168, 60, 5, 19448],
#  [6760, 1, 66, 280, 44, 4, 137, 43, 2906, 104],
#  [772, 1836, 5, 12753, 2868, 328, 578, 23, 783, 7, 16],
#  [1856, 23, 45, 1532, 28, 1580, 1375, 124, 5, 92, 4832, 23, 1],
#  [456, 11, 5523, 21, 285, 706, 8, 25067, 299, 299, 143, 44, 266],
#  [147, 11, 465, 520, 8, 3, 65, 1, 274, 1614, 1581, 29, 34, 899, 558, 99, 128],
#  [1666, 25068, 35, 8652, 3994, 216, 141, 14],
#  [1007, 82, 71, 1, 119, 15, 40, 71, 13, 865, 3138],
#  [489, 612, 216, 10587],
#  [27, 1601, 149, 81, 16],
#  [25, 39, 1, 358, 89, 99, 29, 217],
#  [12754, 9817, 1790, 6, 32, 141, 86, 4141, 103, 269, 15, 27, 2983, 278],
#  [50, 18, 25069],
#  [64, 27, 18, 17, 300, 1182],
#  [37, 362],
#  [55, 2, 1152, 44, 36, 796, 602, 8, 98, 2615, 26, 176],
#  [284, 99, 159, 3, 554, 43, 314],
#  [2612, 13, 186, 210, 732, 2612, 13, 186, 210, 732],
#  [9818, 5, 611, 82],
#  [919, 7, 30, 1186, 1288, 2, 19, 251, 1186, 1288, 8143, 1451, 292],
#  [264, 93, 14, 206, 6, 980, 2],
#  [7375,
#   12,
#   9819,
#   5199,
#   21,
#   3047,
#   7,
#   616,
#   156,
#   187,
#   695,
#   57,
#   1,
#   22,
#   53,
#   136,
#   52,
#   10,
#   1407,
#   10,
#   1,
#   1667,
#   7,
#   22,
#   53,
#   136,
#   4,
#   307,
#   1068],
#  [25, 39, 1, 49, 112, 25070],
#  [64, 138, 1, 114, 3, 40, 250, 1, 58, 128, 27, 64, 427, 27, 138, 133, 267, 68],
#  [1489, 1868, 1, 58, 70, 478, 14, 32, 159, 32, 193, 38, 10, 2616],
#  [152, 54, 89, 786, 3],
#  [2, 69, 798, 24, 176],
#  [426,
#   111,
#   271,
#   1837,
#   267,
#   68,
#   3355,
#   831,
#   449,
#   2488,
#   9,
#   18,
#   417,
#   8653,
#   3574,
#   148,
#   1,
#   426,
#   111,
#   4,
#   1693,
#   17,
#   47,
#   1,
#   87,
#   99,
#   2,
#   247,
#   11,
#   870,
#   97,
#   24,
#   4],
#  [32, 1, 347, 110, 327, 129, 110, 35, 510, 1, 14],
#  [103, 46, 9, 850, 3921, 103, 906, 703],
#  [2, 412, 1009, 4, 85, 769],
#  [17, 2],
#  [473, 1, 358, 1668, 11, 1752, 762, 2869, 25071],
#  [1, 51, 642, 36],
#  [243, 51, 810, 19, 469, 810],
#  [20, 57, 598, 1490, 4, 2],
#  [135,
#   191,
#   6,
#   3,
#   172,
#   1,
#   116,
#   31,
#   25072,
#   7,
#   25073,
#   65,
#   539,
#   443,
#   78,
#   172,
#   4,
#   499],
#  [7050, 1142, 37, 98, 4, 345, 9, 98, 794, 96, 604, 323, 534, 3, 9164, 5, 1952],
#  [1, 51, 204],
#  [507],
#  [219, 5, 1223, 28, 3, 513, 3, 302, 215, 1, 161, 161, 4],
#  [52,
#   10,
#   1,
#   82,
#   4,
#   1602,
#   280,
#   44,
#   4,
#   47,
#   3,
#   97,
#   24,
#   246,
#   282,
#   2115,
#   177,
#   3849,
#   5882,
#   177,
#   6291,
#   109,
#   1811,
#   1187,
#   14,
#   266,
#   47,
#   246,
#   490,
#   995,
#   2982,
#   2331,
#   370],
#  [396, 1, 6761, 26, 124, 1, 87, 253, 60, 10, 5, 37, 7, 901],
#  [170, 111, 3624, 4, 61, 80, 220, 93, 128, 67, 100, 1220, 508, 333, 327],
#  [191,
#   586,
#   6292,
#   11592,
#   322,
#   62,
#   67,
#   1343,
#   4,
#   521,
#   190,
#   146,
#   2,
#   7,
#   322,
#   12,
#   4,
#   542,
#   389,
#   2186,
#   193,
#   5,
#   19449,
#   1349,
#   267,
#   62,
#   877,
#   33,
#   506,
#   877,
#   33,
#   19449,
#   509,
#   409,
#   74,
#   90],
#  [65, 1, 157, 19, 3, 11593, 1, 140, 2515],
#  [152, 54, 152, 344],
#  [55,
#   2,
#   11,
#   94,
#   5,
#   524,
#   156,
#   24,
#   14,
#   833,
#   34,
#   153,
#   5066,
#   474,
#   5,
#   270,
#   290,
#   24,
#   426,
#   8,
#   2],
#  [787, 787],
#  [46,
#   9,
#   57,
#   1,
#   113,
#   1681,
#   641,
#   92,
#   120,
#   9,
#   30,
#   1,
#   114,
#   54,
#   2549,
#   685,
#   5,
#   71,
#   35,
#   119,
#   8,
#   2151,
#   640,
#   275,
#   3,
#   1869],
#  [83, 366, 8, 503, 9165, 166, 8654, 1, 58, 1509, 5, 2332],
#  [39,
#   1,
#   18,
#   224,
#   268,
#   69,
#   31,
#   2116,
#   57,
#   24,
#   106,
#   55,
#   382,
#   5,
#   2,
#   11,
#   1016,
#   10,
#   5,
#   12755,
#   1,
#   872,
#   1016,
#   10,
#   5,
#   72,
#   247,
#   7,
#   268,
#   14,
#   808,
#   632,
#   9,
#   139,
#   206,
#   14,
#   4953,
#   191,
#   6,
#   19450,
#   56,
#   10588,
#   350,
#   7738,
#   8,
#   54,
#   1,
#   2,
#   12,
#   3,
#   42,
#   1050,
#   1014],
#  [9166, 43, 11, 50],
#  [9820, 254, 814, 86, 4409, 4, 61, 36, 117, 4833],
#  [101,
#   2789,
#   692,
#   49,
#   293,
#   1,
#   9167,
#   4313,
#   15,
#   121,
#   604,
#   7,
#   1765,
#   4142,
#   9821,
#   1765,
#   398,
#   33,
#   1459,
#   7,
#   515,
#   4,
#   1,
#   66,
#   616,
#   1003,
#   88,
#   152,
#   4,
#   659,
#   6,
#   243,
#   114,
#   5692,
#   27,
#   441,
#   5,
#   4230],
#  [643, 10, 2686, 143, 7, 86, 2],
#  [105, 1145],
#  [109,
#   524,
#   1255,
#   14,
#   1883,
#   13,
#   37,
#   9,
#   48,
#   79,
#   169,
#   9822,
#   6,
#   36,
#   2283,
#   1181,
#   135,
#   1438,
#   2413,
#   407,
#   24,
#   88,
#   2907,
#   4071,
#   2],
#  [1, 2, 20, 1866, 1012, 173, 1, 358],
#  [1323, 70, 11, 14, 12756],
#  [2347,
#   11,
#   20,
#   37,
#   12,
#   4,
#   380,
#   1112,
#   3850,
#   1100,
#   236,
#   11,
#   2951,
#   8,
#   149,
#   137,
#   2347,
#   11,
#   37,
#   2413],
#  [279, 2, 2259, 3139, 602, 363, 605, 5883, 29, 660, 3, 3851, 5, 133, 64, 402],
#  [1029,
#   8,
#   181,
#   29,
#   4,
#   2,
#   7,
#   1,
#   2152,
#   25,
#   230,
#   434,
#   1029,
#   6,
#   259,
#   65,
#   5,
#   1452,
#   1,
#   20,
#   2908,
#   16,
#   435,
#   60,
#   189,
#   87,
#   170,
#   693,
#   290,
#   9,
#   25074,
#   56,
#   104,
#   20,
#   501,
#   25],
#  [3294, 586, 16292, 19451, 1393, 44, 3],
#  [1094, 33, 668, 77, 6073],
#  [228, 20, 359, 228, 57, 3404, 166, 4, 57, 1, 14],
#  [135,
#   6,
#   190,
#   146,
#   2,
#   7,
#   750,
#   1355,
#   5372,
#   41,
#   5,
#   2,
#   121,
#   3,
#   4607,
#   33,
#   1938,
#   318,
#   31],
#  [121, 1, 66, 494, 29, 119, 245, 3, 40, 7, 913],
#  [84, 1440, 4499, 5, 641, 713],
#  [362, 17],
#  [106, 53, 8, 459, 50, 15],
#  [817,
#   1488,
#   496,
#   2,
#   9823,
#   111,
#   6762,
#   504,
#   29,
#   52,
#   10,
#   8144,
#   742,
#   838,
#   16,
#   817,
#   594,
#   817,
#   430,
#   72,
#   9,
#   20,
#   74,
#   26,
#   108],
#  [870, 4, 567, 214],
#  [445, 81, 14, 5693, 827, 8655, 1603, 2306, 63, 25075],
#  [3140,
#   5694,
#   65,
#   135,
#   457,
#   1001,
#   215,
#   1,
#   161,
#   161,
#   4,
#   20,
#   947,
#   23,
#   45,
#   65,
#   129,
#   926,
#   28,
#   884,
#   105,
#   321,
#   63,
#   492,
#   95,
#   3,
#   243,
#   91,
#   1,
#   993],
#  [106, 47, 8, 4, 266, 914, 3852, 3300, 89, 505, 13, 16, 35, 4, 3575, 5200],
#  [64, 25076, 24, 1522, 142, 1034],
#  [194,
#   954,
#   1226,
#   371,
#   93,
#   7,
#   643,
#   7,
#   87,
#   1,
#   51,
#   185,
#   2307,
#   4,
#   1669,
#   2,
#   381,
#   8,
#   1038,
#   528,
#   102,
#   883,
#   2571,
#   381,
#   13,
#   8145,
#   8145,
#   285,
#   383,
#   369,
#   151],
#  [287, 1, 1092, 228],
#  [605, 7, 16, 3, 678, 45, 230, 85, 99, 29, 98, 34, 331, 9, 16],
#  [1694, 16293, 466],
#  [135,
#   6,
#   750,
#   25,
#   2,
#   7,
#   436,
#   77,
#   5201,
#   181,
#   9,
#   17,
#   308,
#   1289,
#   138,
#   175,
#   263,
#   2516,
#   48,
#   21,
#   288,
#   9,
#   16,
#   37,
#   11,
#   779,
#   19,
#   98,
#   4],
#  [1992,
#   1044,
#   1226,
#   257,
#   63,
#   12757,
#   16,
#   4500,
#   5,
#   120,
#   12,
#   2213,
#   779,
#   19,
#   80,
#   11594,
#   12,
#   3701,
#   4,
#   60,
#   10,
#   13,
#   165,
#   1652,
#   37,
#   12,
#   3301,
#   172,
#   6,
#   141,
#   317,
#   94,
#   9,
#   14],
#  [3194, 192, 78, 846, 22, 70, 9, 14, 480],
#  [1202, 3, 25, 2153, 37, 48, 4, 93, 60, 1993, 116, 78],
#  [56, 9824, 150],
#  [64, 3247, 569, 809, 177, 1560, 1652, 220],
#  [32, 13, 48, 76],
#  [3014, 2, 1722, 879, 11595, 25077],
#  [122, 5, 486, 80, 82, 46, 1387, 516],
#  [17, 704, 1264, 409, 1334, 286, 948],
#  [3302, 3195, 298, 1952, 13, 1, 66, 3, 693, 1780, 19],
#  [429],
#  [3460,
#   1608,
#   5,
#   4,
#   52,
#   5,
#   185,
#   35,
#   372,
#   438,
#   23,
#   561,
#   8,
#   533,
#   149,
#   81,
#   16,
#   133],
#  [4608,
#   7,
#   18,
#   179,
#   2,
#   6763,
#   177,
#   1327,
#   59,
#   6516,
#   65,
#   5,
#   2952,
#   167,
#   59,
#   942,
#   1210,
#   15],
#  [7051, 1297, 3853, 1, 8656, 2870, 25078, 191, 1281, 8, 199, 3520, 61, 750, 2],
#  [121, 494, 33, 4, 48, 3],
#  [2115, 21, 391, 1, 78, 48, 4, 385, 391, 1, 220, 62, 756, 9, 14, 104],
#  [653, 5, 1517, 292, 75, 1566, 41, 90, 108],
#  [1837],
#  [65, 5, 704, 12, 268, 9168, 48, 4],
#  [2517,
#   1,
#   2066,
#   8,
#   102,
#   34,
#   1460,
#   1,
#   1582,
#   2188,
#   496,
#   2,
#   250,
#   1753,
#   305,
#   697,
#   180,
#   28,
#   3],
#  [1682, 355, 885, 21, 410, 5884, 7739, 7, 220, 77, 179, 32, 1, 1230, 186],
#  [2786, 257, 2, 75, 33, 145, 10589, 5, 19452, 1, 365, 17, 264, 11596, 383],
#  [122, 15, 182, 873, 927, 78, 498, 126, 80, 19453, 8, 791],
#  [841, 60, 10, 22, 530, 4, 272],
#  [2, 7, 733, 131, 8, 5067, 490, 7, 59, 4314, 2, 11, 710, 1, 107, 267, 68],
#  [462,
#   65,
#   447,
#   1,
#   4,
#   89,
#   2953,
#   8,
#   11597,
#   5695,
#   4315,
#   4,
#   21,
#   130,
#   11597,
#   1029,
#   13,
#   3702,
#   79,
#   2687,
#   1793,
#   1,
#   15,
#   613,
#   1793,
#   328],
#  [418,
#   6517,
#   12,
#   637,
#   225,
#   56,
#   102,
#   14272,
#   63,
#   18,
#   14273,
#   1,
#   44,
#   266,
#   25079,
#   3049,
#   75,
#   724,
#   6764,
#   41,
#   81,
#   11,
#   25080,
#   28,
#   225,
#   56,
#   16,
#   10590,
#   3,
#   48,
#   4,
#   890,
#   6764,
#   13,
#   1030,
#   753,
#   6764,
#   2490,
#   245,
#   26,
#   134,
#   25081,
#   1,
#   724,
#   11,
#   2617,
#   3995,
#   18,
#   14273,
#   1,
#   7052,
#   118,
#   1045,
#   104,
#   5885,
#   16294,
#   14274,
#   2432],
#  [978, 2, 193, 5, 2333, 4707, 6074, 299, 572, 202, 287, 411],
#  [32, 13, 14],
#  [25],
#  [82, 280, 103, 4, 103, 48, 4, 310],
#  [14275, 14, 185, 5, 16295, 25082, 11, 1424, 1416],
#  [119, 35, 71, 1, 58, 2],
#  [10591,
#   11,
#   94,
#   9,
#   14,
#   360,
#   222,
#   2284,
#   4708,
#   29,
#   2,
#   34,
#   38,
#   13,
#   1,
#   114,
#   29,
#   214,
#   98,
#   4,
#   222,
#   6,
#   5886,
#   4],
#  [60, 10, 5, 37, 11, 17, 412, 57, 4, 272],
#  [19454,
#   9825,
#   10592,
#   1199,
#   4834,
#   10,
#   24,
#   1766,
#   2,
#   252,
#   49,
#   88,
#   1076,
#   2151,
#   461,
#   14276,
#   4],
#  [234],
#  [103, 69, 187, 10, 9, 165, 6, 5696],
#  [603, 4, 195, 265, 2153, 13, 428],
#  [195, 31, 313, 24, 448, 1552],
#  [3194, 14, 1244, 713, 942, 990, 1009, 7376, 5, 115, 17, 2],
#  [1, 2, 11, 485, 67, 41, 178, 88, 230, 225, 64],
#  [11598, 9169, 3625, 35, 283, 26, 475, 1, 58],
#  [665, 3356, 4, 3, 1670, 506, 140, 87, 38, 26, 2348, 507, 319],
#  [394,
#   74,
#   7,
#   25,
#   272,
#   85,
#   169,
#   3095,
#   283,
#   5,
#   847,
#   9,
#   1781,
#   4,
#   786,
#   323,
#   249,
#   85,
#   72,
#   9,
#   303,
#   90,
#   1335,
#   14,
#   1510,
#   2466,
#   11,
#   152,
#   303,
#   90,
#   49,
#   112,
#   39,
#   1,
#   224,
#   85],
#  [49,
#   357,
#   8,
#   1026,
#   2027,
#   16,
#   255,
#   7,
#   16,
#   4,
#   225,
#   51,
#   22,
#   2,
#   2227,
#   63,
#   7053,
#   4,
#   134,
#   856,
#   8,
#   1754,
#   4,
#   593,
#   1,
#   14,
#   134,
#   49,
#   96,
#   6,
#   19,
#   2189,
#   4,
#   940,
#   2398,
#   406,
#   646,
#   143,
#   4,
#   14,
#   606,
#   19455,
#   4609,
#   11,
#   49,
#   36],
#  [587, 312, 1153, 117, 84, 2, 19, 54, 116, 20, 1533, 2, 377, 3],
#  [2688,
#   1441,
#   454,
#   7054,
#   232,
#   5,
#   451,
#   8,
#   423,
#   56,
#   447,
#   6,
#   500,
#   1140,
#   4,
#   462,
#   232,
#   1,
#   208,
#   220,
#   6293,
#   5,
#   290,
#   40,
#   7,
#   3,
#   2,
#   75,
#   758,
#   41,
#   5,
#   53,
#   8,
#   2572,
#   21,
#   2],
#  [3141, 63, 3922, 5202, 283, 11, 1553, 2, 19],
#  [620,
#   61,
#   6294,
#   754,
#   1,
#   605,
#   29,
#   1073,
#   492,
#   3,
#   172,
#   1,
#   116,
#   18,
#   70,
#   14,
#   282,
#   1027,
#   6,
#   981,
#   95,
#   3,
#   25,
#   42,
#   954,
#   49,
#   525,
#   70,
#   7,
#   14,
#   135,
#   1,
#   144,
#   40,
#   7,
#   1707,
#   1640,
#   61,
#   481,
#   16296,
#   1,
#   372,
#   355,
#   6518,
#   605,
#   12,
#   1073,
#   102,
#   26],
#  [80, 8146, 5524, 329, 16297, 6, 5697, 361, 3405, 35, 7740],
#  [2, 27, 54, 1298, 344, 18, 221, 26, 2646],
#  [585, 59, 3355, 831, 3521, 4, 16298, 15, 26],
#  [187, 779, 2515, 5203, 5, 42, 4501, 1534, 162, 287, 3571, 2055],
#  [138,
#   36,
#   574,
#   44,
#   2689,
#   120,
#   10,
#   1,
#   106,
#   749,
#   13,
#   20,
#   71,
#   86,
#   85,
#   3,
#   137,
#   1299,
#   1895],
#  [117, 367, 264, 46, 9, 469, 19, 358, 27],
#  [756, 14, 74, 4, 272],
#  [2518,
#   35,
#   1145,
#   199,
#   758,
#   447,
#   8,
#   1195,
#   342,
#   5,
#   2728,
#   8,
#   2040,
#   21,
#   2984,
#   3196,
#   170],
#  [7055, 251, 26, 818],
#  [71, 1, 828, 8657, 22, 31, 732, 1, 16, 2],
#  [27, 4231, 273, 8, 76, 825, 2, 680, 319],
#  [725,
#   716,
#   3197,
#   725,
#   1736,
#   57,
#   26,
#   31,
#   851,
#   1,
#   72,
#   19,
#   682,
#   811,
#   724,
#   578,
#   291,
#   88,
#   784,
#   26,
#   120,
#   11,
#   268,
#   14,
#   111,
#   684,
#   8,
#   61,
#   2871,
#   11,
#   241,
#   612,
#   2171,
#   3406,
#   35,
#   5204,
#   890,
#   5373,
#   7741,
#   5,
#   1317,
#   5698,
#   436,
#   377,
#   12758,
#   48,
#   136],
#  [879, 383, 2414, 8, 149, 350, 5205],
#  [334],
#  [191, 20, 69, 3],
#  [3015,
#   33,
#   7742,
#   160,
#   160,
#   38,
#   26,
#   124,
#   1,
#   942,
#   5068,
#   97,
#   1,
#   55,
#   2,
#   12,
#   34,
#   338,
#   11,
#   1459,
#   724,
#   29,
#   626,
#   4,
#   4,
#   675,
#   26,
#   11599,
#   1752,
#   7,
#   16,
#   187,
#   10,
#   1,
#   3,
#   323],
#  [19456, 5, 24, 32, 276, 372, 343, 33, 3, 2, 302, 3573, 10593, 167, 89, 62],
#  [1478, 269, 3407, 283, 11, 294, 22],
#  [20,
#   25083,
#   5,
#   825,
#   11,
#   1196,
#   54,
#   54,
#   152,
#   3,
#   294,
#   3,
#   2,
#   2729,
#   2729,
#   19,
#   118,
#   1364,
#   1188,
#   297,
#   88,
#   14277,
#   124,
#   1,
#   87],
#  [723, 3, 632, 10, 270, 1827],
#  [46, 110, 881, 530, 94, 272, 14, 1082, 67, 932, 3996, 857],
#  [67, 1553, 19, 1553],
#  [730,
#   7743,
#   12,
#   995,
#   836,
#   89,
#   20,
#   1,
#   2,
#   82,
#   47,
#   4,
#   70,
#   9,
#   16,
#   40,
#   185,
#   6,
#   2308,
#   1,
#   201,
#   235,
#   2,
#   15,
#   1407,
#   1,
#   9170,
#   56,
#   89,
#   164,
#   3,
#   185,
#   8,
#   766,
#   1614],
#  [874, 2824, 4072, 1249, 41, 5, 110, 2],
#  [181,
#   7,
#   162,
#   2,
#   1120,
#   179,
#   288,
#   10,
#   1,
#   16,
#   338,
#   11,
#   1,
#   2,
#   11,
#   2,
#   1071,
#   2723,
#   617,
#   536,
#   77,
#   59,
#   418,
#   23,
#   28,
#   4,
#   213,
#   5,
#   180,
#   35,
#   1223,
#   8,
#   57,
#   79,
#   89,
#   155,
#   30],
#  [5699, 11, 30, 17, 198, 54, 6075, 2, 7, 30, 1154, 2],
#  [137, 25084, 137, 25, 108, 3915, 75],
#  [7377],
#  [3923, 12759, 10, 1870, 1417, 13, 161, 976],
#  [77, 9826, 22, 187, 10, 77, 3246, 299, 3408, 2756, 444, 4],
#  [64, 20, 278, 6519, 3, 25085, 36],
#  [221, 105],
#  [122, 5, 2260, 199, 33, 55, 514, 639, 34, 52, 10, 171, 3409, 12, 800],
#  [273, 1, 421, 916, 141, 2, 25086, 8, 92, 4, 2],
#  [450, 51, 212, 2, 695],
#  [312, 1, 2491, 170, 303],
#  [362, 306, 263, 16299],
#  [183,
#   15,
#   319,
#   656,
#   1302,
#   1939,
#   4232,
#   456,
#   42,
#   4835,
#   10,
#   417,
#   4232,
#   1010,
#   8658,
#   25087,
#   61,
#   9,
#   350,
#   982,
#   285,
#   462,
#   301,
#   319,
#   809,
#   211,
#   52,
#   9,
#   47,
#   3,
#   122,
#   1,
#   30,
#   157,
#   11,
#   804,
#   4233,
#   4,
#   2825,
#   42,
#   57,
#   1,
#   1084,
#   1432,
#   883,
#   319,
#   43,
#   656,
#   924,
#   19457,
#   886,
#   90,
#   57,
#   306,
#   728,
#   146,
#   737,
#   960,
#   21,
#   47,
#   1477,
#   19],
#  [9, 139, 56, 1508, 139, 56, 37, 9, 139, 56, 612, 29, 82],
#  [248, 7056, 829, 7057],
#  [18, 647, 53, 23, 45, 2, 20, 17],
#  [41, 5, 2],
#  [693,
#   3016,
#   95,
#   3,
#   4410,
#   650,
#   19458,
#   230,
#   167,
#   14278,
#   2492,
#   83,
#   103,
#   48,
#   570,
#   176,
#   2190,
#   2909,
#   11,
#   10594,
#   61,
#   8147,
#   10595,
#   600,
#   121,
#   1008,
#   59,
#   1036,
#   3626,
#   13,
#   228,
#   1126,
#   108,
#   95,
#   3,
#   204],
#  [19459],
#  [1328, 1205, 4, 1328, 44, 4, 770, 185, 1150],
#  [67, 485],
#  [513,
#   549,
#   5,
#   1394,
#   8,
#   78,
#   1442,
#   2,
#   96,
#   109,
#   1,
#   2758,
#   1273,
#   6520,
#   230,
#   225,
#   64,
#   478,
#   583,
#   43,
#   2308,
#   1,
#   624,
#   10596,
#   4,
#   4234,
#   171,
#   478,
#   6295,
#   388,
#   57,
#   21,
#   109,
#   713,
#   6520,
#   3522,
#   21,
#   418,
#   6520,
#   16300,
#   8,
#   3,
#   3775,
#   451,
#   10,
#   8,
#   9827,
#   2309,
#   8,
#   3248,
#   909,
#   4836,
#   4,
#   4709,
#   1159,
#   2],
#  [356, 24, 6, 999, 577, 999, 12, 3, 313, 15],
#  [667, 1196, 667],
#  [399, 499, 1723],
#  [8148, 5, 185, 35, 2056, 1, 30, 8148, 35, 42, 5, 213, 10],
#  [2, 7, 72, 1, 14],
#  [1710,
#   4959,
#   5,
#   1755,
#   8,
#   9171,
#   5,
#   659,
#   258,
#   9171,
#   5,
#   659,
#   8,
#   1035,
#   172,
#   28,
#   628,
#   71,
#   5,
#   25088,
#   7378,
#   6,
#   920,
#   4],
#  [10597, 5, 9172, 37, 4073],
#  [3, 2067, 5206, 2, 70, 9, 16, 460, 53, 1683],
#  [1340, 1324, 19460, 79, 89, 34, 2],
#  [271, 33, 3142, 4, 48, 4],
#  [4837, 70, 9, 14, 381, 8, 1857, 531, 4, 7379, 9, 14],
#  [483, 878, 4, 14279, 8, 1922, 1782, 827, 38, 13, 1256, 7, 44, 22],
#  [2910, 845, 3576, 845, 262, 2028],
#  [453, 1, 123, 221],
#  [455, 6, 86, 3, 59, 17, 1792, 29, 1001, 124, 1, 87, 24, 330, 1],
#  [20, 41, 15, 105, 4411, 200, 63, 2519, 200, 37, 18, 17],
#  [385, 113, 25, 3, 2],
#  [5887,
#   71,
#   6,
#   54,
#   77,
#   511,
#   161,
#   2,
#   96,
#   6,
#   18,
#   221,
#   2467,
#   127,
#   449,
#   1177,
#   25089,
#   7,
#   712,
#   227,
#   1838,
#   12,
#   57,
#   21,
#   317,
#   1443,
#   6,
#   259,
#   5888,
#   949,
#   221,
#   3523,
#   12760,
#   96,
#   6,
#   77,
#   11600,
#   26,
#   4],
#  [98, 3],
#  [44, 195, 957, 1, 1496, 127, 610, 317, 90, 67, 3017, 4, 4, 216, 434],
#  [74, 4, 2098, 243, 38, 1, 19, 374],
#  [60, 10, 5, 383, 37, 9, 1221, 5, 6076, 261, 8, 402, 903, 1342, 9, 19, 17],
#  [2826, 10, 20, 2759, 271, 1837, 14280, 9828, 315, 138, 735, 6, 795, 3],
#  [1170,
#   6296,
#   5525,
#   587,
#   1057,
#   10,
#   2228,
#   63,
#   1329,
#   379,
#   13,
#   1509,
#   513,
#   8,
#   2520,
#   5371,
#   10,
#   35,
#   513,
#   8,
#   10598,
#   4,
#   10599,
#   6765,
#   10,
#   5,
#   47,
#   13,
#   1509],
#  [520, 1388, 1604, 227, 1223, 150],
#  [40,
#   7,
#   1,
#   66,
#   49,
#   3,
#   89,
#   4235,
#   295,
#   3249,
#   36,
#   3,
#   130,
#   25090,
#   9,
#   117,
#   5374,
#   62],
#  [234, 9173, 7, 74, 239, 588, 478, 109, 24, 376, 99, 19],
#  [102, 25091, 189, 2310, 3410, 31, 271, 78, 3, 629, 91, 33, 152, 6077, 675],
#  [205, 1, 717, 7, 30, 2, 385, 248, 8, 3, 152, 54, 89, 2],
#  [1667, 24, 16, 11601, 11, 14],
#  [1034,
#   460,
#   111,
#   1,
#   90,
#   656,
#   780,
#   9,
#   48,
#   4,
#   1593,
#   33,
#   163,
#   675,
#   2283,
#   1896,
#   386,
#   1671,
#   128],
#  [429, 181, 1825, 110, 12761, 21, 209],
#  [1,
#   2,
#   5,
#   5069,
#   11,
#   3198,
#   15,
#   20,
#   14281,
#   5,
#   1247,
#   11,
#   517,
#   213,
#   5,
#   92,
#   6,
#   259,
#   989,
#   292,
#   75,
#   6,
#   2822,
#   11,
#   1459,
#   12,
#   92,
#   4,
#   180,
#   13,
#   20,
#   3198,
#   905,
#   314,
#   96,
#   515,
#   5,
#   4316,
#   202,
#   1751,
#   1,
#   517,
#   1,
#   2,
#   7,
#   20,
#   228],
#  [3997, 3250, 741, 911, 32, 1224, 6, 572],
#  [53, 23, 45, 2, 19],
#  [372, 269, 296, 2, 150],
#  [761,
#   430,
#   80,
#   209,
#   174,
#   3,
#   48,
#   21,
#   543,
#   522,
#   174,
#   13,
#   44,
#   36,
#   116,
#   7380,
#   292,
#   60,
#   10,
#   1,
#   182,
#   873,
#   11,
#   250,
#   1,
#   14,
#   457],
#  [2008, 2872, 113, 2],
#  [1, 2, 7, 39, 1, 224, 338, 12, 85, 128],
#  [1095, 172, 4, 21, 2, 2521, 23, 45, 181, 11, 30],
#  [324, 561, 54, 1, 2, 7, 395],
#  [106,
#   38,
#   8,
#   47,
#   4,
#   34,
#   2,
#   15,
#   96,
#   6,
#   52,
#   10,
#   1,
#   3854,
#   28,
#   937,
#   56,
#   10600,
#   7,
#   52,
#   26,
#   256],
#  [27, 70, 14, 2, 9174, 6078, 1063, 2, 1134, 36, 2],
#  [2099, 2547, 29, 5, 2873, 5, 780, 37, 12, 8149, 4, 16, 416, 3848, 2760],
#  [53, 53, 53, 5, 12762],
#  [772,
#   544,
#   8659,
#   1282,
#   4710,
#   1231,
#   613,
#   1583,
#   6,
#   3776,
#   1653,
#   7,
#   4143,
#   21,
#   561,
#   454,
#   1653,
#   12,
#   3918,
#   1476,
#   1,
#   14,
#   4144,
#   45,
#   38,
#   26],
#  [298, 2083, 3998, 2083, 360, 298, 369, 25092, 319],
#  [372, 276, 558, 54, 2257, 158, 36, 119, 58, 62],
#  [20, 41, 5, 2],
#  [320,
#   2874,
#   2,
#   125,
#   1,
#   314,
#   4145,
#   6,
#   1433,
#   2985,
#   1984,
#   89,
#   99,
#   29,
#   1468,
#   451,
#   286,
#   814,
#   6,
#   10601,
#   5,
#   37,
#   73],
#  [430,
#   125,
#   37,
#   579,
#   38,
#   94,
#   1858,
#   48,
#   21,
#   71,
#   1,
#   123,
#   58,
#   566,
#   1376,
#   753,
#   2041,
#   14282],
#  [2040, 4, 6297, 28, 100, 2084, 8],
#  [668,
#   7058,
#   660,
#   3018,
#   4,
#   113,
#   3,
#   386,
#   692,
#   1026,
#   278,
#   467,
#   583,
#   158,
#   152,
#   1953,
#   658,
#   152,
#   692,
#   1307,
#   144,
#   27,
#   278,
#   665,
#   665,
#   3018,
#   3018,
#   205,
#   1,
#   16,
#   316,
#   189,
#   1,
#   50,
#   92,
#   79,
#   207,
#   123,
#   1026,
#   278],
#  [1155,
#   3,
#   49,
#   564,
#   4711,
#   1,
#   224,
#   1672,
#   72,
#   9,
#   2827,
#   14,
#   1330,
#   3411,
#   2,
#   239,
#   1,
#   66],
#  [281, 31, 2, 5, 162, 261, 1, 2522, 554, 150, 2],
#  [27,
#   21,
#   4960,
#   59,
#   146,
#   2,
#   719,
#   4,
#   1256,
#   4,
#   31,
#   121,
#   2,
#   3,
#   11602,
#   79,
#   350,
#   64,
#   427,
#   27],
#  [241, 16, 6521, 8, 829, 5889],
#  [16301, 10, 5, 913, 422, 860],
#  [194, 23, 6, 238, 983, 323, 172, 6, 5890, 384, 95, 3],
#  [3524, 35, 7059, 211, 168, 674, 5, 8150],
#  [16302, 1, 37, 7, 1524, 239, 30, 119, 1, 14, 502, 11603, 476, 3, 14, 2],
#  [934,
#   788,
#   111,
#   1,
#   1017,
#   258,
#   12763,
#   5,
#   3924,
#   15,
#   17,
#   26,
#   255,
#   2790,
#   7060,
#   358],
#  [656, 3, 18, 58, 135, 1344, 5, 2],
#  [96, 5207, 568, 41, 62, 7381, 6, 11604, 2009, 108],
#  [19461, 32, 175],
#  [17, 7744, 41, 30, 10602, 840, 41],
#  [84, 3357, 153, 3019, 19],
#  [1525, 43, 1264, 44, 197, 4838, 5, 2, 75, 94, 231, 87, 24, 246],
#  [4502],
#  [353,
#   9,
#   70,
#   7,
#   16,
#   305,
#   70,
#   9,
#   14,
#   569,
#   24,
#   426,
#   1238,
#   111,
#   1,
#   546,
#   795,
#   3,
#   27,
#   44,
#   546,
#   1871,
#   19,
#   25,
#   3,
#   27,
#   40,
#   797,
#   75,
#   365,
#   122,
#   1,
#   15,
#   918,
#   1045,
#   111,
#   10,
#   159,
#   352,
#   4,
#   1897,
#   117,
#   358,
#   532,
#   138,
#   2042,
#   1,
#   756,
#   15],
#  [3703, 8660, 11, 643, 7, 87, 228],
#  [40, 7, 3, 3844, 75, 1711],
#  [137, 133, 13, 133, 15],
#  [4074, 921, 2, 293, 8, 1113, 54, 2172, 21, 40, 1113, 1, 1230, 186],
#  [67,
#   1923,
#   2,
#   83,
#   68,
#   77,
#   59,
#   1070,
#   16,
#   72,
#   8,
#   281,
#   310,
#   15,
#   2,
#   9,
#   264,
#   484,
#   7061,
#   68],
#  [67,
#   520,
#   28,
#   540,
#   59,
#   3627,
#   4,
#   1624,
#   2,
#   11,
#   72,
#   8,
#   18,
#   6079,
#   79,
#   1859,
#   4,
#   25093,
#   8,
#   2911,
#   520,
#   33,
#   5208,
#   115,
#   124,
#   35,
#   2191,
#   29,
#   243,
#   38,
#   1,
#   484,
#   701],
#  [545, 53, 23, 45, 2],
#  [14283, 156, 189, 550, 1, 2, 12, 1290],
#  [2229, 2010, 45, 43, 5, 39, 13, 32, 773, 199, 1954, 19, 1330],
#  [43, 1, 66, 54, 2309, 2334, 1138, 1322],
#  [1673, 1910, 6522, 254],
#  [643,
#   161,
#   933,
#   10,
#   1,
#   25094,
#   2466,
#   4,
#   2,
#   117,
#   910,
#   339,
#   673,
#   903,
#   1342,
#   117,
#   27,
#   19462,
#   29],
#  [10603, 13, 102, 668, 986, 8, 829, 1654, 48, 4, 731, 13, 1654, 38, 1, 30],
#  [25, 298, 1666],
#  [474,
#   11,
#   307,
#   117,
#   1265,
#   3925,
#   12,
#   2828,
#   4,
#   1860,
#   26,
#   3199,
#   13,
#   9175,
#   3,
#   48,
#   21,
#   2],
#  [722, 231, 1615, 518, 82, 1, 7062, 226, 86, 1225, 18, 48, 24, 798, 83],
#  [324, 3200, 3, 123, 25, 49, 722, 13, 11605, 89, 499, 4075],
#  [125,
#   37,
#   287,
#   1,
#   162,
#   2,
#   15,
#   4146,
#   45,
#   943,
#   29,
#   2986,
#   996,
#   235,
#   469,
#   212,
#   1828,
#   6,
#   556,
#   1058,
#   1103,
#   25095,
#   7,
#   22,
#   126,
#   8,
#   304,
#   106,
#   1631,
#   3999,
#   1461,
#   159,
#   3143,
#   767,
#   163,
#   1582,
#   10,
#   307,
#   28,
#   667],
#  [39,
#   1,
#   49,
#   112,
#   217,
#   1,
#   66,
#   152,
#   577,
#   136,
#   248,
#   1695,
#   20,
#   207,
#   131,
#   6,
#   1478,
#   79,
#   175,
#   2085,
#   79,
#   890,
#   954,
#   20,
#   215,
#   1,
#   1861,
#   1196,
#   207,
#   3,
#   958,
#   880,
#   1418,
#   40,
#   7,
#   339,
#   30,
#   93],
#  [1, 51, 190, 39, 1, 217, 16],
#  [2468,
#   4961,
#   3303,
#   1,
#   2690,
#   410,
#   313,
#   1007,
#   351,
#   76,
#   6080,
#   1051,
#   522,
#   28,
#   6766,
#   4962,
#   186,
#   671],
#  [3461,
#   2493,
#   1226,
#   663,
#   2,
#   1114,
#   810,
#   7063,
#   10,
#   1,
#   586,
#   1018,
#   9,
#   182,
#   10604,
#   197,
#   1408,
#   4],
#  [32, 1767],
#  [987, 3020, 1104, 5, 535, 6, 161, 1839, 8, 21, 2],
#  [972, 213, 1211, 3, 313, 17],
#  [44,
#   3,
#   142,
#   32,
#   2068,
#   76,
#   382,
#   2,
#   26,
#   62,
#   2043,
#   933,
#   63,
#   964,
#   202,
#   65,
#   45,
#   130,
#   108],
#  [20, 517, 41, 5, 2, 75, 6, 3577, 2],
#  [1518,
#   223,
#   100,
#   1062,
#   382,
#   202,
#   2,
#   19,
#   46,
#   6,
#   1070,
#   1289,
#   14,
#   633,
#   23,
#   28,
#   2285,
#   4],
#  [27,
#   74,
#   239,
#   12764,
#   43,
#   5891,
#   11,
#   473,
#   59,
#   263,
#   299,
#   113,
#   473,
#   1,
#   482,
#   872,
#   146,
#   187,
#   10,
#   8,
#   299,
#   2368,
#   1549,
#   21,
#   187,
#   10,
#   8,
#   1440,
#   2433,
#   921,
#   622,
#   6],
#  [67, 70, 7, 14, 105],
#  [1490, 12, 439, 127, 1490],
#  [2027, 1, 1046, 1181, 2069, 423, 56, 6081, 2829, 81, 12, 4503],
#  [466, 315, 60, 10, 5, 539, 24, 172, 6, 426],
#  [67, 44, 3, 6523],
#  [874, 11606, 11606, 11606, 11606, 138],
#  [25096, 9829, 1526, 1522, 153],
#  [27, 278, 2],
#  [1257,
#   13,
#   78,
#   2134,
#   9,
#   31,
#   52,
#   220,
#   509,
#   61,
#   11,
#   698,
#   3777,
#   21,
#   222,
#   24,
#   36,
#   268,
#   180,
#   6,
#   102,
#   883,
#   31,
#   396,
#   10],
#  [1082],
#  [638, 25, 3],
#  [40, 6767, 2100, 59, 25, 104],
#  [479, 13, 479, 28, 3, 1768, 79, 6524, 3778, 11, 70, 9, 16],
#  [966,
#   2594,
#   267,
#   347,
#   5892,
#   1640,
#   2,
#   19,
#   1707,
#   4839,
#   16,
#   301,
#   148,
#   1077,
#   237,
#   246],
#  [3926, 121, 645, 3462, 212, 336, 77, 503, 3],
#  [12, 1047, 3, 20, 25, 78, 3, 68, 1829, 3, 2, 75, 41, 45, 130],
#  [280, 31, 3, 6082, 34, 14284, 1288, 83, 885, 4],
#  [5700, 12, 1872, 29, 24, 618, 1031, 1134, 2647, 7, 180, 6, 44, 1940, 32],
#  [2225, 1042, 5, 488, 37, 170, 111, 37, 18, 48, 4],
#  [1583,
#   23,
#   28,
#   1316,
#   124,
#   5,
#   2,
#   83,
#   68,
#   12765,
#   14285,
#   35,
#   732,
#   258,
#   1444,
#   368,
#   25097,
#   65,
#   189,
#   3144,
#   3463,
#   288,
#   6,
#   6298,
#   1584,
#   8,
#   7745,
#   19,
#   3,
#   125,
#   288,
#   6,
#   16,
#   77,
#   4610,
#   31,
#   60,
#   10,
#   271,
#   13,
#   150],
#  [1017, 3, 25, 60, 72, 262, 1941],
#  [991, 1316, 181, 12, 4147, 69, 34],
#  [2369, 91, 565, 1981, 24, 21, 2369, 6, 872, 515, 808, 3096],
#  [1937,
#   25098,
#   25099,
#   90,
#   108,
#   2370,
#   21,
#   5209,
#   28,
#   524,
#   156,
#   14,
#   60,
#   10,
#   1,
#   10605],
#  [147,
#   543,
#   17,
#   148,
#   10,
#   62,
#   1769,
#   369,
#   177,
#   373,
#   182,
#   873,
#   56,
#   3779,
#   1,
#   2,
#   17,
#   25,
#   26,
#   14286,
#   369,
#   10,
#   13,
#   143,
#   4,
#   48,
#   4,
#   1614,
#   62,
#   27,
#   122,
#   4076,
#   46,
#   111,
#   1043,
#   524,
#   156,
#   14,
#   2573,
#   526,
#   5,
#   9176,
#   122,
#   108,
#   9177,
#   62,
#   112,
#   251,
#   1258,
#   286,
#   22,
#   2,
#   634,
#   297,
#   2246,
#   104],
#  [1, 968, 668, 54, 89, 739, 266, 161, 5210],
#  [57, 1, 743, 14, 617, 1290, 40, 7, 3, 61, 5211, 4, 38, 26, 5070],
#  [210,
#   895,
#   23,
#   167,
#   1250,
#   180,
#   8,
#   1415,
#   1395,
#   153,
#   221,
#   72,
#   8,
#   203,
#   504,
#   180,
#   8,
#   3358,
#   299],
#  [287, 1812, 137, 41, 83, 68],
#  [14287],
#  [137, 425, 233, 11, 3, 266],
#  [150, 2],
#  [324, 25],
#  [181,
#   11,
#   115,
#   17,
#   1322,
#   32,
#   76,
#   744,
#   22,
#   2,
#   11,
#   325,
#   9,
#   327,
#   9,
#   30,
#   6083,
#   8,
#   445,
#   50,
#   30,
#   50,
#   26,
#   124,
#   15,
#   37,
#   125,
#   13,
#   150,
#   1085,
#   352,
#   159,
#   131,
#   73,
#   80,
#   216,
#   15,
#   152,
#   190,
#   109,
#   10,
#   13,
#   1180,
#   223],
#  [213, 129, 3, 344, 706, 1479, 98, 163],
#  [457, 216, 457, 216],
#  [1083, 13, 52, 10, 1, 1151, 155, 6, 750, 2011, 1303, 306, 19],
#  [67, 5375, 349, 1336, 44, 36],
#  [357,
#   1924,
#   158,
#   44,
#   3,
#   40,
#   527,
#   12,
#   1840,
#   153,
#   210,
#   185,
#   41,
#   5,
#   12766,
#   19,
#   6508,
#   91,
#   75,
#   758,
#   41,
#   15,
#   25100,
#   297],
#  [11607, 10, 5, 3628, 19463, 1684],
#  [605, 1898, 239, 1942, 565, 19464, 823, 1943, 1673, 7, 721, 239],
#  [101, 1278, 866, 4, 81, 14, 223, 27, 1489, 1, 58],
#  [14288, 5, 1412, 1068, 2, 713, 6084, 13, 18, 584, 36],
#  [6299, 8661, 33, 9830],
#  [469,
#   2,
#   7,
#   30,
#   469,
#   2,
#   53,
#   1,
#   16,
#   795,
#   131,
#   73,
#   19,
#   3,
#   307,
#   28,
#   112,
#   82,
#   149,
#   107],
#  [14289, 5, 1139, 12, 3412, 768, 1, 5526, 4],
#  [1569, 20, 356, 24, 6, 1497, 323, 176, 2304, 1, 280, 22],
#  [1057, 291, 11608, 7, 14],
#  [8151, 1396, 36, 198, 3, 310, 429, 205, 8, 76, 3, 524, 1255, 14, 74, 55],
#  [17, 181, 6, 1685, 125],
#  [8152, 1, 36, 1712, 100, 99, 695, 310, 15],
#  [614,
#   366,
#   13,
#   131,
#   73,
#   809,
#   346,
#   949,
#   451,
#   14,
#   265,
#   181,
#   7,
#   429,
#   2,
#   247,
#   11,
#   1135,
#   9,
#   3704,
#   46,
#   7,
#   1909,
#   16,
#   31,
#   38,
#   26],
#  [14290,
#   8,
#   1944,
#   17,
#   7064,
#   1,
#   16,
#   5893,
#   8,
#   4,
#   88,
#   1498,
#   240,
#   1,
#   3016,
#   165,
#   675,
#   42,
#   460,
#   16303,
#   3917,
#   6,
#   7382,
#   1,
#   22,
#   11609,
#   158,
#   86,
#   22,
#   1994,
#   25101,
#   6,
#   2308,
#   1,
#   22,
#   115,
#   356,
#   24,
#   6,
#   2618,
#   641,
#   7746,
#   118,
#   909,
#   3,
#   3464,
#   3016,
#   443],
#  [221, 919, 2173, 310, 6300, 19, 12767, 5, 2311, 35, 6085, 28, 214, 18, 833],
#  [1899, 33, 1, 66, 54, 261, 27, 53, 23],
#  [25102,
#   891,
#   11610,
#   128,
#   232,
#   23,
#   45,
#   144,
#   1,
#   1353,
#   505,
#   6,
#   1940,
#   32,
#   76,
#   282,
#   27,
#   4611,
#   4148,
#   9831,
#   315,
#   138,
#   1841,
#   60,
#   10,
#   875,
#   650,
#   450,
#   84,
#   2,
#   252,
#   128,
#   27,
#   2,
#   3,
#   25103,
#   80,
#   2730,
#   128],
#  [545, 383, 53, 23, 45, 2],
#  [202, 2, 9, 113, 160, 348, 58, 623, 11, 1627, 351, 9, 34, 1469],
#  [46, 5, 10606, 13, 110, 5, 70, 73, 3201, 299],
#  [562, 43, 728, 827, 25104, 25105, 8, 2, 2954, 362],
#  [2789, 9832, 57, 4, 4, 303, 90, 85, 65, 590, 992, 772, 6, 326, 34, 26, 2],
#  [1609, 9178, 12, 1375, 53, 8, 76, 2, 15],
#  [191,
#   466,
#   2174,
#   33,
#   3,
#   8662,
#   1364,
#   276,
#   21,
#   130,
#   1370,
#   63,
#   2912,
#   6,
#   500,
#   198,
#   59,
#   47,
#   4,
#   87,
#   2,
#   100,
#   1062,
#   1753,
#   87,
#   65,
#   5,
#   878,
#   1,
#   368,
#   235,
#   1183,
#   12,
#   800,
#   845],
#  [3, 323, 25],
#  [92, 6, 1239, 136, 95, 2469, 22, 16, 4, 47, 1, 87, 2],
#  [357, 1924, 158, 203, 2, 75, 240, 502, 1394, 8, 107, 28, 149, 163, 12768],
#  [41, 59, 169, 477, 7, 624, 2153],
#  [447, 5, 342, 6, 500, 95, 198, 47, 4, 2],
#  [339, 366, 10, 1561, 9, 14, 460, 54, 1710, 720, 11, 66, 239],
#  [678, 29, 1001, 163, 128],
#  [2086, 700, 117, 1055, 205, 94, 54, 102, 4, 232, 10, 143, 1315],
#  [7044,
#   117,
#   177,
#   169,
#   834,
#   8,
#   4,
#   8651,
#   7,
#   1112,
#   160,
#   203,
#   366,
#   10,
#   27,
#   464,
#   1853,
#   358],
#  [1, 3016, 3, 3705, 2, 11, 212, 1, 59, 98, 34, 114, 149, 22],
#  [285, 550, 303, 410, 7065, 12, 1079],
#  [25, 1432, 862, 206, 15],
#  [102,
#   105,
#   40,
#   2830,
#   16304,
#   549,
#   6,
#   27,
#   221,
#   2,
#   15,
#   105,
#   96,
#   6,
#   238,
#   2312,
#   300,
#   9179,
#   311,
#   363,
#   152,
#   3],
#  [25106, 1182, 1216, 6, 289, 69, 54, 16, 2057, 3413],
#  [8663,
#   2756,
#   110,
#   13,
#   3145,
#   2955,
#   1,
#   172,
#   6,
#   3097,
#   725,
#   716,
#   5,
#   725,
#   716,
#   6,
#   1674,
#   716,
#   12,
#   322,
#   21,
#   283,
#   29,
#   100,
#   2761,
#   602,
#   3,
#   70,
#   11,
#   335,
#   318],
#  [2044, 7066, 825, 11, 583, 33],
#  [40, 1095, 41, 5, 582, 196, 19465, 772, 12, 2082, 1090, 203, 130, 21, 124],
#  [40, 185, 41, 5, 2],
#  [27, 237, 4],
#  [474,
#   7,
#   1570,
#   18,
#   196,
#   23,
#   1724,
#   60,
#   10,
#   13,
#   1484,
#   1995,
#   658,
#   233,
#   16305,
#   1470,
#   14291,
#   64,
#   12769,
#   285,
#   656,
#   1308,
#   203,
#   191,
#   47,
#   6,
#   2029,
#   1955,
#   1318],
#  [530, 7, 6301, 328, 66, 178, 43, 220, 1632, 24, 9833, 9834, 16],
#  [115, 25, 2, 176],
#  [1203, 7067, 131, 945, 42, 107, 166, 25, 93, 74, 178, 564, 82],
#  [357,
#   6,
#   268,
#   308,
#   113,
#   109,
#   15,
#   1996,
#   1286,
#   378,
#   2070,
#   846,
#   125,
#   379,
#   1,
#   1309,
#   14],
#  [1134, 2647, 7, 408, 353, 126],
#  [402, 195, 16306, 1, 411, 6, 625, 25107],
#  [1,
#   4712,
#   3465,
#   3,
#   39,
#   1,
#   224,
#   143,
#   3359,
#   760,
#   147,
#   950,
#   107,
#   632,
#   7,
#   19466,
#   9180,
#   159,
#   14292,
#   474,
#   7,
#   59,
#   195,
#   7068,
#   182,
#   71,
#   302,
#   474,
#   24,
#   188,
#   572,
#   2030],
#  [27, 1121, 57, 309, 1067, 63],
#  [17, 60, 10, 8, 1862, 56, 91, 5, 2415],
#  [30,
#   49,
#   32,
#   175,
#   695,
#   1829,
#   6,
#   3,
#   3700,
#   1510,
#   1028,
#   75,
#   33,
#   41,
#   15,
#   289,
#   67,
#   12770,
#   171,
#   802,
#   4412,
#   3927,
#   819,
#   680],
#  [3098, 352, 4, 344, 214],
#  [72, 209, 7, 484, 701, 80, 99, 29, 70, 7, 14, 2192],
#  [119, 16307, 29, 6302, 391, 109, 15, 62],
# ...
#   144,
#   672,
#   1,
#   2,
#   12,
#   3,
#   38,
#   15,
#   241,
#   220,
#   191,
#   6,
#   198,
#   164,
#   3,
#   4,
#   2],
#  [47, 3, 97, 24, 4, 104, 170, 111, 1, 37, 7, 17, 83, 170],
#  [917,
#   412,
#   1873,
#   4,
#   3707,
#   79,
#   7074,
#   4,
#   4,
#   165,
#   3100,
#   134,
#   19482,
#   12,
#   380,
#   1186,
#   7,
#   16316,
#   169,
#   25131,
#   90,
#   396,
#   823],
#  [102],
#  [465, 191, 4618, 12, 5212, 105],
#  [241,
#   107,
#   463,
#   370,
#   553,
#   806,
#   335,
#   2054,
#   471,
#   234,
#   2,
#   247,
#   11,
#   447,
#   5,
#   3251,
#   6,
#   2046,
#   820,
#   9,
#   137,
#   901,
#   642,
#   244,
#   132,
#   143,
#   4,
#   48,
#   4,
#   104],
#  [458, 219, 1862, 56, 3, 219, 11, 132, 176, 9191, 5379, 5892, 1172, 171, 237],
#  [1, 38, 8, 131, 73, 795, 3, 40, 7, 365, 4004],
#  [3580, 11619, 83, 19],
#  [44, 3, 22, 2],
#  [229, 682],
#  [67, 76, 32, 13, 30, 130],
#  [448, 31, 332, 23, 1149, 80],
#  [3781, 14, 46, 157, 684, 8, 61, 393, 36, 4849, 239],
#  [607, 4073, 17, 65, 189, 13, 431, 10, 1, 412, 1151, 3022, 273, 1, 140, 141],
#  [138,
#   1164,
#   145,
#   964,
#   856,
#   549,
#   122,
#   5,
#   2,
#   25,
#   52,
#   10,
#   304,
#   3,
#   19,
#   2980,
#   45,
#   130,
#   300],
#  [617, 63, 327, 2594, 427, 412, 57, 79, 89, 272, 46, 9, 8160, 22, 124],
#  [101, 77, 30],
#  [3631, 13, 113, 472, 7075, 189, 475, 6, 3053, 163, 91, 2861, 144, 113],
#  [121, 47, 597, 40, 797, 2, 75, 6, 147, 11, 40, 1125, 41, 5, 2, 15, 26],
#  [4850, 6, 576, 4, 921, 286, 4, 729, 25132, 21, 2],
#  [851,
#   8,
#   860,
#   21,
#   2,
#   141,
#   52,
#   10,
#   13,
#   4064,
#   152,
#   119,
#   2261,
#   1378,
#   44,
#   4,
#   52,
#   10,
#   5,
#   120,
#   12,
#   277,
#   118,
#   151,
#   3146,
#   4,
#   2,
#   222,
#   295,
#   287,
#   4229,
#   32],
#  [485, 354, 345, 11, 472, 1959, 3, 2, 199, 345, 7, 9192, 9193, 17],
#  [181, 7, 652, 429],
#  [7076, 177, 874, 2824, 4072, 1249],
#  [168,
#   57,
#   4,
#   6529,
#   192,
#   41,
#   5,
#   91,
#   185,
#   6,
#   500,
#   158,
#   47,
#   370,
#   4,
#   1070,
#   16,
#   182,
#   11620,
#   414,
#   8161,
#   210,
#   292,
#   587,
#   171,
#   235,
#   1183,
#   12,
#   800],
#  [234, 8162, 4, 4],
#  [57, 1, 442, 653, 2, 705, 1462, 12, 227, 38, 8, 149],
#  [8163,
#   8,
#   4,
#   88,
#   334,
#   350,
#   25133,
#   104,
#   1633,
#   6,
#   369,
#   284,
#   284,
#   1066,
#   143,
#   1027,
#   6,
#   1452,
#   105,
#   25134,
#   19],
#  [574,
#   2315,
#   22,
#   31,
#   1105,
#   541,
#   10,
#   170,
#   3357,
#   4237,
#   6,
#   9846,
#   25135,
#   7751,
#   1328,
#   79,
#   3462],
#  [1086,
#   484,
#   634,
#   6,
#   422,
#   686,
#   3,
#   418,
#   229,
#   247,
#   9,
#   4851,
#   192,
#   209,
#   22,
#   2087,
#   13,
#   72,
#   1945,
#   9,
#   192,
#   739,
#   1830,
#   464,
#   14,
#   1110,
#   60,
#   10,
#   13,
#   520,
#   540,
#   340,
#   337,
#   598,
#   503,
#   10614,
#   42,
#   2195,
#   108,
#   634,
#   6,
#   611,
#   29,
#   540],
#  [117,
#   84,
#   26,
#   38,
#   10,
#   64,
#   1665,
#   3526,
#   4154,
#   4507,
#   494,
#   891,
#   12,
#   1345,
#   64,
#   161],
#  [172, 13, 1824, 22, 4714, 42, 52, 1, 30, 246, 4715, 57, 4, 57, 306],
#  [25,
#   3,
#   489,
#   25136,
#   6,
#   8164,
#   7752,
#   12782,
#   7,
#   30,
#   9847,
#   5,
#   707,
#   1251,
#   42,
#   5368,
#   1,
#   579,
#   99,
#   15,
#   78,
#   188,
#   91,
#   1,
#   30,
#   89,
#   430,
#   9,
#   430,
#   244,
#   60,
#   10,
#   37,
#   7,
#   1709,
#   15],
#  [8165,
#   2958,
#   6,
#   4852,
#   6,
#   2959,
#   494,
#   3,
#   86,
#   2,
#   1106,
#   33,
#   2287,
#   865,
#   81,
#   192,
#   3,
#   1027,
#   291,
#   12783,
#   1826,
#   3,
#   2,
#   103,
#   308,
#   22,
#   355,
#   46,
#   9,
#   1984,
#   4155,
#   2597,
#   577,
#   110,
#   17,
#   100,
#   11,
#   5532,
#   9,
#   2,
#   730,
#   9,
#   30,
#   2,
#   1946,
#   3,
#   2410,
#   213,
#   52,
#   126],
#  [2512, 5, 2793, 1, 30, 441, 5, 1559, 7, 22, 153, 6773, 86],
#  [455, 33, 165, 166, 119, 58, 234, 82, 300],
#  [232, 5, 234, 256, 76, 89, 55, 1476, 11613, 227, 1476, 1, 5074, 1, 16],
#  [20, 92, 6, 500, 95, 47, 21, 66, 26, 53, 854],
#  [72, 13, 1687, 23, 154, 20, 80, 703],
#  [889, 340, 4508, 177, 19483, 260, 206, 658],
#  [1112, 3, 2, 75, 6, 365, 82],
#  [745, 8, 2764, 28, 766, 4, 389, 292],
#  [19484, 44, 2434, 252, 18, 82, 420, 40, 935, 14],
#  [27, 84, 2, 119, 58, 220, 93, 1902, 305, 218],
#  [19485, 404, 4238, 10615, 247],
#  [1189, 2, 904, 23, 167, 2470, 23, 388, 523, 254],
#  [160,
#   203,
#   2,
#   177,
#   608,
#   5380,
#   149,
#   1530,
#   9194,
#   1519,
#   5075,
#   19486,
#   1156,
#   96,
#   6,
#   1095,
#   1519,
#   461,
#   9195,
#   136,
#   4716,
#   7,
#   112,
#   73,
#   7753,
#   22,
#   16,
#   250,
#   272,
#   85,
#   1039],
#  [27,
#   112,
#   70,
#   9,
#   14,
#   53,
#   9,
#   14,
#   2,
#   11,
#   107,
#   267,
#   340,
#   43,
#   3928,
#   56,
#   4005,
#   167,
#   243,
#   593,
#   10,
#   1,
#   2832,
#   4,
#   61,
#   877,
#   252,
#   874,
#   5533,
#   2316,
#   31,
#   108,
#   2832,
#   745,
#   10,
#   13,
#   863,
#   7077,
#   24,
#   2411,
#   1406,
#   22,
#   251,
#   463,
#   597,
#   18,
#   251,
#   1258,
#   60,
#   10,
#   37,
#   9,
#   8166,
#   167],
#  [41, 5, 10616, 50],
#  [1129,
#   1385,
#   306,
#   10,
#   5,
#   987,
#   5534,
#   4717,
#   211,
#   5381,
#   330,
#   1,
#   2400,
#   22,
#   193,
#   15,
#   5710,
#   1116,
#   13,
#   7754,
#   4237,
#   28,
#   34,
#   17,
#   130,
#   111,
#   1,
#   3136,
#   170,
#   2352,
#   476,
#   9,
#   277,
#   113,
#   9848,
#   5,
#   8167,
#   645,
#   2902,
#   1,
#   22,
#   99,
#   29,
#   451,
#   8,
#   1873,
#   4,
#   4418,
#   7,
#   2544],
#  [708,
#   708,
#   88,
#   708,
#   30,
#   1725,
#   5,
#   162,
#   261,
#   6,
#   274,
#   153,
#   232,
#   160,
#   216,
#   572,
#   1075,
#   905,
#   636],
#  [117, 82, 353, 46, 2302, 62],
#  [74, 94, 3054, 38, 1, 14, 41],
#  [86, 17, 2],
#  [8168,
#   36,
#   3708,
#   25137,
#   231,
#   4239,
#   1338,
#   46,
#   859,
#   159,
#   403,
#   19487,
#   984,
#   1046,
#   1046,
#   1046,
#   861,
#   9196,
#   225],
#  [3848, 9, 14, 510, 9, 14],
#  [413, 1233, 79, 44, 197],
#  [544, 775, 7, 140, 3, 1037, 46],
#  [41, 5, 50],
#  [236, 262, 11, 1459, 171, 25138, 15],
#  [25139, 1, 94, 14, 111, 10, 1535, 1, 19, 326],
#  [18, 18, 298, 2],
#  [830, 23, 45, 279, 378, 2732, 8169, 650, 868, 42, 1655, 1671, 49, 90],
#  [102,
#   1,
#   114,
#   32,
#   263,
#   459,
#   52,
#   10,
#   13,
#   74,
#   90,
#   2879,
#   749,
#   75,
#   6,
#   201,
#   1232,
#   138],
#  [5535,
#   878,
#   354,
#   4967,
#   136,
#   4714,
#   15,
#   355,
#   7385,
#   7755,
#   7,
#   16,
#   17,
#   12784,
#   8,
#   8170,
#   91],
#  [6306, 344],
#  [1357, 13, 1024, 1266],
#  [219, 10, 35, 487, 165, 17, 67, 88],
#  [1903, 8, 149],
#  [3632,
#   3417,
#   72,
#   6,
#   1,
#   1357,
#   45,
#   52,
#   10,
#   5,
#   910,
#   1190,
#   746,
#   96,
#   28,
#   528,
#   722,
#   44,
#   36,
#   739,
#   19488],
#  [139, 103, 139, 96, 376, 123, 223, 82],
#  [1755,
#   1,
#   688,
#   95,
#   3,
#   264,
#   161,
#   161,
#   246,
#   1,
#   409,
#   277,
#   4,
#   52,
#   1,
#   476,
#   4067,
#   6,
#   133,
#   28,
#   426,
#   8,
#   130],
#  [219, 10, 1, 165, 166, 17],
#  [627, 481, 2194, 156, 1, 77, 443, 26, 275, 110, 13, 17],
#  [4853, 3709, 12, 149, 572, 6774, 2, 15],
#  [631,
#   1757,
#   4718,
#   29,
#   21,
#   1393,
#   633,
#   23,
#   45,
#   432,
#   43,
#   497,
#   13,
#   17,
#   72,
#   13,
#   80],
#  [685, 1, 5530, 7, 30, 1, 2, 12, 305, 218],
#  [426,
#   1,
#   7756,
#   33,
#   19489,
#   118,
#   1229,
#   148,
#   2833,
#   3307,
#   79,
#   16,
#   6307,
#   11,
#   133,
#   297,
#   47,
#   4,
#   1,
#   2,
#   11,
#   27,
#   444,
#   94],
#  [830, 23, 45, 100, 533, 2],
#  [756, 8, 93, 4],
#  [70, 350, 529],
#  [27, 78, 34, 416],
#  [465, 77, 252, 8171, 116, 57, 854],
#  [1092, 383, 180, 1, 383, 198, 662, 447, 8, 4320, 34, 2],
#  [264, 4156, 469, 2, 1727, 5897, 12785, 1554, 1727, 874, 1137, 3418],
#  [1,
#   66,
#   115,
#   181,
#   11,
#   115,
#   17,
#   72,
#   209,
#   7,
#   1191,
#   52,
#   1209,
#   106,
#   552,
#   9,
#   16,
#   1367,
#   285,
#   87,
#   1260,
#   1010,
#   19,
#   11621,
#   4719,
#   23,
#   28,
#   10617,
#   83,
#   814,
#   19,
#   19490,
#   297,
#   1641,
#   286,
#   8,
#   708,
#   29,
#   4,
#   2155,
#   78,
#   8172,
#   28,
#   1100,
#   5898,
#   1,
#   11622,
#   22,
#   3854,
#   233,
#   208,
#   286,
#   645,
#   16],
#  [474,
#   24,
#   88,
#   2907,
#   3305,
#   328,
#   539,
#   24,
#   86,
#   502,
#   2,
#   103,
#   452,
#   15,
#   110,
#   3468,
#   117,
#   251,
#   840,
#   79,
#   46,
#   9,
#   358],
#  [606, 49, 82, 852, 145, 518, 25],
#  [3101,
#   10,
#   5,
#   3917,
#   1,
#   18,
#   2765,
#   23,
#   15,
#   336,
#   46,
#   9,
#   17,
#   222,
#   13,
#   279,
#   336,
#   75,
#   6,
#   2153,
#   28,
#   901],
#  [392, 1803, 25140, 3419, 4968, 517, 3469, 4],
#  [42, 7, 12786, 31, 190, 208],
#  [32,
#   175,
#   11,
#   36,
#   67,
#   822,
#   110,
#   1860,
#   1,
#   30,
#   331,
#   325,
#   330,
#   125,
#   1055,
#   222,
#   9,
#   17,
#   385,
#   135,
#   1,
#   688,
#   961,
#   468,
#   23,
#   45,
#   708,
#   411,
#   129,
#   39,
#   18,
#   312,
#   1165],
#  [1883, 37, 11, 17, 72, 13, 84],
#  [27,
#   82,
#   343,
#   33,
#   3,
#   14,
#   399,
#   327,
#   127,
#   986,
#   762,
#   3,
#   2248,
#   393,
#   309,
#   44,
#   36,
#   1227,
#   43,
#   4,
#   377,
#   3,
#   27,
#   465],
#  [39, 13, 304, 1794, 25],
#  [1, 66, 17, 366, 10, 13, 74, 4, 38, 10, 434, 128],
#  [1, 51, 2, 239, 678, 2, 239, 1232, 138, 10, 64],
#  [12, 304, 306, 10],
#  [18, 5899, 28, 204, 246, 3, 302, 861, 261],
#  [55, 132, 52, 10, 464, 772, 7, 581],
#  [7757, 5, 196, 8, 3420, 4, 180, 13, 93, 2, 5, 70, 11, 14, 80, 684, 8, 791, 4],
#  [289, 69, 520, 28, 3, 20, 69],
#  [1814, 25],
#  [6775, 2284, 8, 119, 245, 3, 493, 11, 47, 1, 87, 21, 2],
#  [179,
#   348,
#   16,
#   46,
#   6,
#   197,
#   432,
#   43,
#   497,
#   4720,
#   16317,
#   5,
#   342,
#   522,
#   8,
#   78,
#   989],
#  [2693,
#   174,
#   35,
#   197,
#   318,
#   78,
#   34,
#   2,
#   41,
#   5,
#   1550,
#   9849,
#   5,
#   1947,
#   35,
#   4419,
#   16318,
#   5,
#   1960,
#   8,
#   93,
#   1553],
#  [9197, 7, 298, 298, 6776],
#  [9198, 7078, 3710, 475, 6, 161, 317, 14],
#  [1656, 2, 41, 5, 452],
#  [461, 6089, 2177],
#  [1323, 3054, 38, 9, 4073, 38, 9, 14, 2072, 23, 4240],
#  [2, 5, 2027, 13, 137, 46, 45, 38, 8, 205, 5, 205, 18, 69],
#  [1, 30, 1, 30],
#  [115, 69, 37, 12, 817, 29, 4, 663, 60, 10, 535, 3, 108],
#  [25],
#  [1, 38, 9, 25, 62],
#  [348, 58, 764, 240, 38, 9, 3023, 3, 302, 769, 1087, 1008, 230, 93],
#  [280, 44, 79, 3, 2, 3, 302, 308, 4, 69, 3],
#  [501,
#   327,
#   23,
#   45,
#   777,
#   7,
#   78,
#   546,
#   133,
#   2012,
#   3,
#   589,
#   206,
#   16,
#   499,
#   499,
#   3147,
#   4,
#   168,
#   1641,
#   3252,
#   54,
#   89,
#   2],
#  [17, 150],
#  [133, 18, 17, 50, 46, 475, 37, 222, 125, 262, 517],
#  [150, 182, 6308, 233, 9, 150, 14309, 1142, 103, 12787, 56, 360, 105],
#  [782,
#   69,
#   4420,
#   385,
#   2024,
#   29,
#   1758,
#   23,
#   28,
#   9199,
#   702,
#   1466,
#   471,
#   88,
#   290,
#   1,
#   236,
#   11,
#   262,
#   7,
#   9,
#   63,
#   86,
#   241,
#   1379,
#   5,
#   2727,
#   354,
#   990,
#   11,
#   1804,
#   53,
#   23,
#   15],
#  [121,
#   498,
#   3,
#   604,
#   24,
#   3,
#   97,
#   186,
#   3,
#   1555,
#   11623,
#   11624,
#   4,
#   273,
#   1,
#   140,
#   141,
#   50],
#  [486, 8173, 1, 179, 11625, 9, 88, 37, 9, 88, 120, 9, 88, 489, 88],
#  [280, 31, 4, 1560, 27, 72, 9, 17, 70, 9, 16],
#  [17],
#  [221, 19491, 16319, 6, 4150, 118, 127],
#  [6530, 132],
#  [25, 415],
#  [4078, 7, 208, 153, 257, 2880, 6777],
#  [43, 3055, 555, 6, 102, 1634, 43, 5, 41, 5, 2],
#  [43, 11, 1215, 42, 542, 2786, 336, 14310, 5, 4509, 1],
#  [103, 910, 84, 2, 19, 1329, 23, 193, 8, 637, 757, 1, 918, 1635],
#  [19492, 8666, 10, 3144, 169, 834, 8, 25141],
#  [2317, 1034, 2088],
#  [3, 18, 18, 69],
#  [9850, 437, 22, 18, 25],
#  [3581, 1445, 102, 1803, 213, 63, 890, 61, 69, 108, 4854, 1672],
#  [2369,
#   2,
#   7,
#   710,
#   2687,
#   6,
#   140,
#   1311,
#   534,
#   4,
#   42,
#   72,
#   10,
#   1,
#   49,
#   564,
#   516,
#   838,
#   2369,
#   2,
#   12,
#   349,
#   1161,
#   4,
#   449,
#   19],
#  [946, 251, 5536, 233, 9, 69, 3, 101, 2694, 1904],
#  [190, 562, 9, 227, 3094, 342, 35, 888, 6, 500, 10618, 11626, 4, 960, 14],
#  [3782, 152, 4, 25142, 127, 465, 105],
#  [5900, 3144, 794, 210, 7, 583, 16],
#  [4855,
#   306,
#   7,
#   119,
#   106,
#   933,
#   171,
#   11627,
#   8,
#   10619,
#   56,
#   7758,
#   311,
#   462,
#   4616,
#   1328,
#   4,
#   25143,
#   1431,
#   11,
#   516,
#   173],
#  [20, 25, 3, 11628, 9, 1881, 9, 37, 18, 98, 4, 319],
#  [234, 229, 3, 589, 493, 229, 169, 232, 1, 57, 9, 48, 4, 396, 4],
#  [57, 1, 442, 64, 307, 117, 25, 105],
#  [627, 481, 1, 3421, 1, 2353, 1023, 65, 267],
#  [362, 2262, 369, 177, 152, 54, 89],
#  [70, 27, 2263, 4, 282, 1, 832, 920, 16320, 7, 108],
#  [9167, 4313, 3, 850, 441],
#  [16321, 3250, 668, 551, 405],
#  [1528,
#   135,
#   654,
#   3,
#   243,
#   2,
#   4856,
#   158,
#   122,
#   5,
#   2,
#   71,
#   1,
#   3783,
#   61,
#   3,
#   71,
#   1,
#   58,
#   812,
#   202,
#   84,
#   2],
#  [53,
#   15,
#   795,
#   29,
#   1,
#   2,
#   2288,
#   601,
#   96,
#   453,
#   288,
#   6,
#   1134,
#   3996,
#   2436,
#   288,
#   350,
#   1,
#   51,
#   7068,
#   33,
#   596,
#   211,
#   852,
#   27,
#   1602,
#   962,
#   724,
#   29,
#   596,
#   211,
#   218,
#   2987,
#   1,
#   3253,
#   78,
#   559,
#   252,
#   42,
#   559,
#   33,
#   453,
#   109,
#   359,
#   27,
#   724,
#   7,
#   30,
#   3633,
#   7079,
#   496],
#  [25144, 16322, 891, 3422, 116, 25145, 3, 93, 1227, 1783, 1081, 65, 1, 2043],
#  [70, 1007, 14, 108],
#  [178, 11584, 1003, 6751, 5, 10576, 732, 8, 188],
#  [25146,
#   35,
#   11629,
#   25147,
#   73,
#   46,
#   841,
#   17,
#   60,
#   10,
#   9,
#   37,
#   115,
#   98,
#   4,
#   1238,
#   111,
#   10,
#   2695,
#   9,
#   17,
#   1195,
#   97,
#   81,
#   309,
#   14,
#   50,
#   1380],
#  [117, 2, 83, 68, 40, 935, 14, 67, 1202, 34, 2, 7],
#  [168,
#   117,
#   11,
#   1657,
#   4,
#   339,
#   7,
#   106,
#   64,
#   311,
#   3,
#   14,
#   1106,
#   660,
#   95,
#   227,
#   410,
#   29,
#   660,
#   87],
#  [49, 32, 13, 230, 81, 14],
#  [2348, 6, 426, 8, 91, 12788, 5, 820, 3],
#  [1302, 8, 525, 836],
#  [1, 51, 606, 169, 72, 434],
#  [3423,
#   1677,
#   19,
#   32,
#   154,
#   25148,
#   2008,
#   1,
#   51,
#   32,
#   202,
#   101,
#   32,
#   312,
#   72,
#   9,
#   173,
#   9,
#   241,
#   241,
#   74,
#   450],
#  [53, 519, 17],
#  [407,
#   6,
#   117,
#   82,
#   3,
#   733,
#   25,
#   984,
#   1632,
#   1,
#   40,
#   7,
#   93,
#   4079,
#   6,
#   36,
#   1632,
#   1,
#   30],
#  [11630, 1423, 988, 31],
#  [704, 11, 17, 18, 308, 1, 113, 3857],
#  [223, 694, 97, 24, 246],
#  [683,
#   2988,
#   155,
#   6,
#   250,
#   1,
#   433,
#   42,
#   355,
#   748,
#   7759,
#   7757,
#   157,
#   1756,
#   6,
#   500,
#   286,
#   1392,
#   26,
#   3,
#   27,
#   9200,
#   650,
#   3424,
#   844,
#   315,
#   19493,
#   10,
#   9,
#   16,
#   26,
#   198,
#   7760,
#   90,
#   48,
#   79,
#   93,
#   52,
#   10,
#   1,
#   558,
#   190,
#   92,
#   118,
#   239,
#   88,
#   337,
#   36,
#   61,
#   591,
#   686,
#   1440,
#   10,
#   13,
#   106,
#   5537,
#   115,
#   4321],
#  [3, 16323, 688, 386, 1601, 1616, 957, 5, 780, 7, 27, 195],
#  [287, 1, 5076, 2598, 91, 26, 88, 554, 43, 106, 711, 2, 126, 291, 1604],
#  [1815, 12775, 4721],
#  [1200],
#  [27, 440, 181, 151, 47, 4, 3, 117, 204, 213, 1251, 11, 234, 335, 13, 794, 16],
#  [191, 1713, 7, 58],
#  [1707,
#   61,
#   1443,
#   1,
#   188,
#   2,
#   71,
#   1,
#   828,
#   961,
#   8667,
#   6,
#   802,
#   141,
#   10620,
#   15,
#   796,
#   3,
#   2,
#   7,
#   74,
#   15,
#   581,
#   42,
#   2,
#   7,
#   672,
#   5515,
#   1985,
#   10621,
#   15,
#   135,
#   191,
#   154,
#   3784,
#   43,
#   133,
#   13,
#   71,
#   1,
#   828,
#   133,
#   15],
#  [123, 25, 25149],
#  [5711, 6090, 129, 678, 2, 6, 190, 36],
#  [7386, 5, 1688, 1, 30, 7080, 2471, 9201, 293, 808, 468, 23, 1, 3711],
#  [108, 82],
#  [3930,
#   145,
#   1948,
#   73,
#   3931,
#   4510,
#   5,
#   41,
#   5,
#   2,
#   11,
#   3,
#   16324,
#   2960,
#   12789,
#   1957,
#   5704,
#   461,
#   4,
#   1737,
#   93,
#   265,
#   25150],
#  [120, 247, 7, 882, 12, 1307, 90, 48, 4],
#  [558, 1636, 4, 34, 1057, 1501, 1035],
#  [16325, 1142, 183, 1, 636, 103, 334, 350, 319],
#  [182,
#   824,
#   360,
#   17,
#   1413,
#   969,
#   1,
#   71,
#   1,
#   123,
#   407,
#   148,
#   6,
#   699,
#   19,
#   509,
#   421,
#   80,
#   873,
#   555,
#   3,
#   313,
#   279,
#   2,
#   1042,
#   5,
#   42,
#   143,
#   48,
#   4,
#   4722,
#   16],
#  [46, 1688, 268, 113, 821, 4, 2086, 700, 50, 1728, 91],
#  [157, 111, 1, 360, 131, 73, 3],
#  [1379, 12, 1175, 3136, 1, 91, 8, 54, 34, 317, 30],
#  [1130, 417, 2, 12, 34, 49, 425, 233, 11, 19, 84, 239],
#  [1913,
#   778,
#   7,
#   241,
#   3425,
#   1,
#   387,
#   120,
#   11,
#   490,
#   16,
#   3785,
#   7386,
#   13,
#   669,
#   4,
#   31,
#   2523,
#   8,
#   322,
#   7387,
#   211,
#   14,
#   1025,
#   3,
#   650,
#   166,
#   65,
#   206,
#   23,
#   45,
#   2,
#   12,
#   34,
#   428,
#   52],
#  [96, 1, 77, 1072, 17, 2],
#  [981, 12, 660, 86, 9202, 958, 135, 526, 3, 257, 2, 75, 41],
#  [315, 138, 362, 845, 4, 1350],
#  [1617,
#   3527,
#   958,
#   292,
#   8,
#   759,
#   401,
#   149,
#   1986,
#   110,
#   553,
#   639,
#   841,
#   430,
#   11,
#   2,
#   5,
#   4080,
#   211,
#   38,
#   8,
#   134,
#   685,
#   1,
#   281,
#   16326,
#   11,
#   1126],
#  [32, 13, 14, 32, 13, 18, 311, 4],
#  [3102, 1, 11, 7757, 12, 1580, 3786, 12, 3308, 4],
#  [2089, 22, 431, 10],
#  [14311, 10, 1771, 6, 39, 1, 217],
#  [5712,
#   60,
#   10,
#   1,
#   34,
#   331,
#   1,
#   355,
#   331,
#   16,
#   890,
#   3,
#   4,
#   9,
#   19494,
#   10,
#   6,
#   1674,
#   3309,
#   393,
#   36],
#  [213,
#   111,
#   3101,
#   232,
#   28,
#   1156,
#   214,
#   1171,
#   39,
#   54,
#   44,
#   3,
#   4,
#   3,
#   25,
#   1171,
#   3,
#   55,
#   7761,
#   1783,
#   1081,
#   7,
#   59,
#   3,
#   70,
#   7,
#   16,
#   4723,
#   204,
#   4,
#   1171,
#   1528,
#   1926,
#   293,
#   3205,
#   13,
#   579,
#   928,
#   7,
#   21,
#   4724,
#   67,
#   3101,
#   232,
#   1,
#   30],
#  [20,
#   41,
#   5,
#   133,
#   1234,
#   1,
#   22,
#   3,
#   6309,
#   5,
#   3254,
#   11,
#   152,
#   227,
#   53,
#   42,
#   247,
#   83,
#   68],
#  [147, 24, 2056, 4, 16327, 7, 6, 25151, 177, 25152, 4, 160, 13, 14],
#  [2067, 4, 613, 196, 105],
#  [280, 12, 94, 1549, 118, 144, 4, 160, 14, 61, 165, 17, 2],
#  [6778, 16328, 9851, 4, 27, 615, 188, 2, 343, 33, 276, 4, 1966],
#  [283, 44, 36, 11631],
#  [214, 418, 1, 18, 221, 215, 1, 3426, 6779, 153, 26],
#  ...]

# %%
y_train = np.array(train_df["label"])
y_test = np.array(test_df["label"])

# %%
y_train
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
train_df["label"].values
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
length = np.array([len(x) for x in x_train])

# %%
print(np.mean(length), np.median(length), np.max(length), np.min(length))
# Out:
# 13.13909230126688 10.0 75 0

# %% [markdown]
# ## 모델

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, stratify = y_train,
                                                  test_size = 0.2, random_state = 42)

# %%
train_seq = pad_sequences(x_train, maxlen = 80)
val_seq = pad_sequences(x_val, maxlen = 80)
test_seq = pad_sequences(x_test, maxlen = 80)

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(30000, 100, input_shape = (80,)))
model.add(keras.layers.LSTM(128, dropout = 0.4, return_sequences = True))
model.add(keras.layers.LSTM(128, dropout = 0.4))
model.add(keras.layers.Dense(1, activation = "sigmoid"))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:89: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 80, 100)             │       3,000,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 80, 128)             │         117,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 128)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,248,961 (12.39 MB)
#  Trainable params: 3,248,961 (12.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = keras.optimizers.Adam(learning_rate = 0.005)
model.compile(optimizer = adam, loss = "binary_crossentropy", metrics = ["accuracy"])
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 3, restore_best_weights = True)

# %%
history = model.fit(train_seq, y_train, epochs = 100, batch_size = 128,
                   validation_data = (val_seq, y_val),
                   callbacks = [early_stopping_cb])
# Out:
# Epoch 1/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 177s 193ms/step - accuracy: 0.7878 - loss: 0.4394 - val_accuracy: 0.8482 - val_loss: 0.3398
# Epoch 2/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 177s 197ms/step - accuracy: 0.8833 - loss: 0.2810 - val_accuracy: 0.8503 - val_loss: 0.3472
# Epoch 3/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 213s 237ms/step - accuracy: 0.9056 - loss: 0.2291 - val_accuracy: 0.8494 - val_loss: 0.3832
# Epoch 4/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 215s 240ms/step - accuracy: 0.9216 - loss: 0.1957 - val_accuracy: 0.8473 - val_loss: 0.3892

# %%
def sent_predict(text):
    text = re.sub(r"[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", text)
    text = okt.morphs(text, stem = True)
    encoded = tokenizer.texts_to_sequences([text])
    pad_new = pad_sequences(encoded, maxlen = 80)
    score = model.predict(pad_new)
    
    return score

# %%
sent_predict("잘도 그러겠다")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# array([[0.44767293]], dtype=float32)

# %%
sent_predict("엿같고 참 좋아요")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# array([[0.58925676]], dtype=float32)

# %%
sent_predict("시간낭비하기 좋아요")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# array([[0.02318932]], dtype=float32)

# %%
sent_predict("돈낭비는 즐거워")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# array([[0.07015264]], dtype=float32)
