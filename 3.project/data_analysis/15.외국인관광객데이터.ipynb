# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# matplotlib 한글 폰트 수정
from matplotlib import font_manager, rc
import matplotlib
font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family=font_name)

# %%
kto = pd.read_excel("./data/실습데이터/kto_201001.xlsx", usecols = "A:G", header = 1, skipfooter = 4)
kto.head()
# Out:
#      국적      관광     상용   공용  유학/연수     기타       계
# 0  아시아주  329131  18238  421   4339  80916  433045
# 1    일본  202825   1750   89    549   3971  209184
# 2    대만   35788     41   17     37    516   36399
# 3    홍콩   13874     55    0     21    595   14545
# 4   마카오     554      0    0      0      0     554

# %%
kto.tail()
# Out:
#          국적   관광   상용  공용  유학/연수     기타      계
# 62  아프리카 기타  349  594  25     86    296   1350
# 63     기타대륙   10    3   0      0      0     13
# 64     국적미상   10    3   0      0      0     13
# 65     교포소계    0    0   0      0  22537  22537
# 66       교포    0    0   0      0  22537  22537

# %% [markdown]
# # 데이터 탐색
#
# - 데이터가 2010년 01월 부터 2020년 5월 까지 월별로 분할되어 있기 때문에 각각 월별로 데이터를 하나씩 가져와 하나의 테이블로 통합해야 함

# %%
kto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto.describe()
# Out:
#                   관광            상용           공용        유학/연수            기타  \
# count      67.000000     67.000000    67.000000    67.000000     67.000000
# mean    11964.716418    683.462687    81.731343   152.776119   4115.910448
# std     47055.349998   2639.234303   370.034666   622.299519  11560.294887
# min         0.000000      0.000000     0.000000     0.000000      0.000000
# 25%       254.000000     23.500000     0.000000     6.000000    161.500000
# 50%       554.000000     47.000000     2.000000    17.000000    449.000000
# 75%      3638.000000    301.000000    14.000000    54.500000   1608.000000
# max    329131.000000  18238.000000  2159.000000  4339.000000  80916.000000
#
#                    계
# count      67.000000
# mean    16998.597015
# std     59189.624627
# min        13.000000
# 25%       605.000000
# 50%      1350.000000
# 75%      7582.000000
# max    433045.000000

# %% [markdown]
# - 평균적으로 관광 목적으로 가장 많은 외국인이 입국함
# - 계를 제외한 모든 컬럼에서 최솟값이 0임
#     - 확인 필요

# %%
kto[(kto["관광"] == 0) | (kto["상용"] == 0) | (kto["공용"] == 0) | (kto["유학/연수"] == 0) | (kto["기타"] == 0)]
# Out:
#           국적     관광   상용  공용  유학/연수     기타      계
# 3         홍콩  13874   55   0     21    595  14545
# 4        마카오    554    0   0      0      0    554
# 6      말레이시아   3292   61   0     49   1157   4559
# 16      캄보디아    102   22   0     25    131    280
# 19        이란     69  309   0      3    217    598
# 20      이스라엘    792   11   0      0     53    856
# 24       GCC    223  134   0     18     55    430
# 38       스위스    512   30   0      7     77    626
# 40       덴마크    378   28   0      5     94    505
# 41      노르웨이    517  274   0      6    149    946
# 45       그리스    345   47   0      0    213    605
# 46      포르투갈    256    9   0      1     44    310
# 47       핀란드    376   16   0     12    131    535
# 48      아일랜드    311   16   0      1    198    526
# 49     우크라이나    386   29   0      6   1515   1936
# 51     크로아티아    166   20   0      1    298    485
# 52      루마니아    142   12   0      9    370    533
# 53      불가리아    103    0   0      9    414    526
# 54       폴란드    378   29   0     10    431    848
# 55     구주 기타   1219   37   0     49    410   1715
# 59    대양주 기타    730    0   4      4    168    906
# 61  남아프리카공화국    214   27   0      2    545    788
# 63      기타대륙     10    3   0      0      0     13
# 64      국적미상     10    3   0      0      0     13
# 65      교포소계      0    0   0      0  22537  22537
# 66        교포      0    0   0      0  22537  22537

# %% [markdown]
# - 교포소계와 교포는 4개 컬럼이 모두 0임

# %% [markdown]
# ## 기준년월 추가
#
# - 각 월별 데이터가 추가될 예정이기 때문에 각 데이터마다 기준년월 정보가 추가되어야 구별이 가능

# %%
kto["기준년월"] = "2010-01"

# %%
kto.head()
# Out:
#      국적      관광     상용   공용  유학/연수     기타       계     기준년월
# 0  아시아주  329131  18238  421   4339  80916  433045  2010-01
# 1    일본  202825   1750   89    549   3971  209184  2010-01
# 2    대만   35788     41   17     37    516   36399  2010-01
# 3    홍콩   13874     55    0     21    595   14545  2010-01
# 4   마카오     554      0    0      0      0     554  2010-01

# %% [markdown]
# ## 국적 컬럼 확인

# %%
kto["국적"].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %% [markdown]
# - 아시아주, 미주, 교포소계 등 국가가 아닌 값이 포함되어 있음

# %%
contents_list = ["아시아주", "미주", "구주", "대양주", "아프리카주", "기타대륙", "교포소계"]

# %%
kto_country = kto[kto["국적"].isin(contents_list) == False]

# %%
kto_country.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월
# 1   일본  202825  1750  89    549  3971  209184  2010-01
# 2   대만   35788    41  17     37   516   36399  2010-01
# 3   홍콩   13874    55   0     21   595   14545  2010-01
# 4  마카오     554     0   0      0     0     554  2010-01
# 5   태국   13374    39  13     53  4335   17814  2010-01

# %%
kto_country_newindex = kto_country.reset_index(drop = True)

# %%
kto_country.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월
# 1   일본  202825  1750  89    549  3971  209184  2010-01
# 2   대만   35788    41  17     37   516   36399  2010-01
# 3   홍콩   13874    55   0     21   595   14545  2010-01
# 4  마카오     554     0   0      0     0     554  2010-01
# 5   태국   13374    39  13     53  4335   17814  2010-01

# %% [markdown]
# - 대륙 컬럼 추가

# %%
kto[kto["국적"].isin(contents_list)]
# Out:
#        국적      관광     상용    공용  유학/연수     기타       계     기준년월
# 0    아시아주  329131  18238   421   4339  80916  433045  2010-01
# 26     미주   33067   1391  2159    200  17022   53839  2010-01
# 32     구주   28798   2250   119    476  14866   46509  2010-01
# 56    대양주    9249    393    14     15   1701   11372  2010-01
# 60  아프리카주     563    621    25     88    841    2138  2010-01
# 63   기타대륙      10      3     0      0      0      13  2010-01
# 65   교포소계       0      0     0      0  22537   22537  2010-01

# %% [markdown]
# - 대륙 컬럼의 내용은 순서대로 아시아 25개, 미주 5개, 유럽 23개, 오세아니아 3개, 아프리카 2개, 기타 1개, 교포 1개

# %%
continents = ["아시아"] * 25 + ["아메리카"] * 5 + ["유럽"] * 23 + ["오세아니아"] * 3 + ["아프리카"] * 2 + ["기타대륙"] +  ["교포"]

# %%
continents
# Out:
# ['아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '오세아니아',
#  '오세아니아',
#  '오세아니아',
#  '아프리카',
#  '아프리카',
#  '기타대륙',
#  '교포']

# %%
kto_country_newindex["대륙"] = continents

# %%
kto_country_newindex.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아
# 3  마카오     554     0   0      0     0     554  2010-01  아시아
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아

# %% [markdown]
# ## 국적별 관광객 비율

# %%
kto_country_newindex["관광객비율(%)"] = round(kto_country_newindex["관광"] / kto_country_newindex["계"] * 100, 1)

# %%
kto_country_newindex.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1

# %%
# 관광객 비율 컬럼으로 내림차순 정렬
kto_country_newindex.sort_values("관광객비율(%)", ascending = False)
# Out:
#           국적      관광     상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 3        마카오     554      0     0      0      0     554  2010-01    아시아
# 1         대만   35788     41    17     37    516   36399  2010-01    아시아
# 0         일본  202825   1750    89    549   3971  209184  2010-01    아시아
# 2         홍콩   13874     55     0     21    595   14545  2010-01    아시아
# 19      이스라엘     792     11     0      0     53     856  2010-01    아시아
# 36      이탈리아    1157     40    12     12    155    1376  2010-01     유럽
# 53   오스트레일리아    6974    340     9     10   1098    8431  2010-01  오세아니아
# 43      포르투갈     256      9     0      1     44     310  2010-01     유럽
# 35       스위스     512     30     0      7     77     626  2010-01     유럽
# 55    대양주 기타     730      0     4      4    168     906  2010-01  오세아니아
# 8       싱가포르    4201    120     3     27   1017    5368  2010-01    아시아
# 41       스페인     542     29    11      8    108     698  2010-01     유럽
# 58      국적미상      10      3     0      0      0      13  2010-01   기타대륙
# 31        독일    5838    255    24     68   1458    7643  2010-01     유럽
# 30        영국    5746    383     4     20   1368    7521  2010-01     유럽
# 54      뉴질랜드    1545     53     1      1    435    2035  2010-01  오세아니아
# 4         태국   13374     39    13     53   4335   17814  2010-01    아시아
# 37       덴마크     378     28     0      5     94     505  2010-01     유럽
# 40     오스트리아     440     13     2      9    141     605  2010-01     유럽
# 5      말레이시아    3292     61     0     49   1157    4559  2010-01    아시아
# 52     구주 기타    1219     37     0     49    410    1715  2010-01     유럽
# 44       핀란드     376     16     0     12    131     535  2010-01     유럽
# 16        몽골    2333    234     6    197    554    3324  2010-01    아시아
# 39       벨기에     322     25     1      8    104     460  2010-01     유럽
# 33      네덜란드    1205     47     1     20    449    1722  2010-01     유럽
# 34       스웨덴     579     63     5     17    185     849  2010-01     유럽
# 27       멕시코     252     29     1      4     93     379  2010-01   아메리카
# 32       프랑스    3019    343    44    115   1145    4666  2010-01     유럽
# 25        미국   26943   1195  2145    135  12647   43065  2010-01   아메리카
# 28       브라질     459     46     1     11    248     765  2010-01   아메리카
# 45      아일랜드     311     16     0      1    198     526  2010-01     유럽
# 29     미주 기타     501     25     8     29    291     854  2010-01   아메리카
# 42       그리스     345     47     0      0    213     605  2010-01     유럽
# 22     카자흐스탄     238     48     4     22    107     419  2010-01    아시아
# 26       캐나다    4912     96     4     21   3743    8776  2010-01   아메리카
# 38      노르웨이     517    274     0      6    149     946  2010-01     유럽
# 23       GCC     223    134     0     18     55     430  2010-01    아시아
# 20        터키     472     15     2     15    465     969  2010-01    아시아
# 47       러시아    4861    505    15     83   5409   10873  2010-01     유럽
# 51       폴란드     378     29     0     10    431     848  2010-01     유럽
# 17        중국   40425  11930    55   2751  36091   91252  2010-01    아시아
# 24    아시아 기타     700    629    14     56    333    1732  2010-01    아시아
# 7      인도네시아    1840    327     3     65   2826    5061  2010-01    아시아
# 15      캄보디아     102     22     0     25    131     280  2010-01    아시아
# 48     크로아티아     166     20     0      1    298     485  2010-01     유럽
# 10       베트남    1384    284    21    150   2676    4515  2010-01    아시아
# 11        인도    1646   1387     7     68   2918    6026  2010-01    아시아
# 56  남아프리카공화국     214     27     0      2    545     788  2010-01   아프리카
# 49      루마니아     142     12     0      9    370     533  2010-01     유럽
# 57   아프리카 기타     349    594    25     86    296    1350  2010-01   아프리카
# 46     우크라이나     386     29     0      6   1515    1936  2010-01     유럽
# 50      불가리아     103      0     0      9    414     526  2010-01     유럽
# 6        필리핀    3984    219   104     87  16820   21214  2010-01    아시아
# 21    우즈베키스탄     190    293    17     40    740    1280  2010-01    아시아
# 9        미얀마     630     18    54     10   3882    4594  2010-01    아시아
# 14     방글라데시      86     84     9     42    489     710  2010-01    아시아
# 18        이란      69    309     0      3    217     598  2010-01    아시아
# 13      파키스탄      70    200     1     41    402     714  2010-01    아시아
# 12      스리랑카      39     28     2     13    566     648  2010-01    아시아
# 59        교포       0      0     0      0  22537   22537  2010-01     교포
#
#     관광객비율(%)
# 3      100.0
# 1       98.3
# 0       97.0
# 2       95.4
# 19      92.5
# 36      84.1
# 53      82.7
# 43      82.6
# 35      81.8
# 55      80.6
# 8       78.3
# 41      77.7
# 58      76.9
# 31      76.4
# 30      76.4
# 54      75.9
# 4       75.1
# 37      74.9
# 40      72.7
# 5       72.2
# 52      71.1
# 44      70.3
# 16      70.2
# 39      70.0
# 33      70.0
# 34      68.2
# 27      66.5
# 32      64.7
# 25      62.6
# 28      60.0
# 45      59.1
# 29      58.7
# 42      57.0
# 22      56.8
# 26      56.0
# 38      54.7
# 23      51.9
# 20      48.7
# 47      44.7
# 51      44.6
# 17      44.3
# 24      40.4
# 7       36.4
# 15      36.4
# 48      34.2
# 10      30.7
# 11      27.3
# 56      27.2
# 49      26.6
# 57      25.9
# 46      19.9
# 50      19.6
# 6       18.8
# 21      14.8
# 9       13.7
# 14      12.1
# 18      11.5
# 13       9.8
# 12       6.0
# 59       0.0

# %%
# 대륙별 관광객 비율 평균
kto_country_newindex.pivot_table(index = "대륙", values = "관광객비율(%)", aggfunc = "mean")
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   76.900000
# 아메리카   60.760000
# 아시아    49.544000
# 아프리카   26.550000
# 오세아니아  79.733333
# 유럽     60.926087

# %% [markdown]
# - 평균 관광객 비율이 높은 대륙은 오세아니아
# - 아프리카에서 관광목적으로 방문하는 외국인은 26.6% 뿐임
# - 아시아의 관광객 비율은 49.5%로 유럽보다 낮음

# %%
# 중국 국적 필터링
kto_country_newindex[kto_country_newindex["국적"] == "중국"]
# Out:
#     국적     관광     상용  공용  유학/연수     기타      계     기준년월   대륙  관광객비율(%)
# 17  중국  40425  11930  55   2751  36091  91252  2010-01  아시아      44.3

# %% [markdown]
# ## 전체 외국인 관광객 대비 국적별 관광객 비율

# %%
# 전체 외국인 관광객
tourist_sum = sum(kto_country_newindex["관광"])
tourist_sum
# Out:
# 400818

# %%
kto_country_newindex["전체비율(%)"] = round(kto_country_newindex["관광"] / tourist_sum * 100, 1)

# %%
kto_country_newindex.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  전체비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0     50.6
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3      8.9
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4      3.5
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0      0.1
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1      3.3

# %%
kto_country_newindex.sort_values("전체비율(%)", ascending = False)
# Out:
#           국적      관광     상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 0         일본  202825   1750    89    549   3971  209184  2010-01    아시아
# 17        중국   40425  11930    55   2751  36091   91252  2010-01    아시아
# 1         대만   35788     41    17     37    516   36399  2010-01    아시아
# 25        미국   26943   1195  2145    135  12647   43065  2010-01   아메리카
# 2         홍콩   13874     55     0     21    595   14545  2010-01    아시아
# 4         태국   13374     39    13     53   4335   17814  2010-01    아시아
# 53   오스트레일리아    6974    340     9     10   1098    8431  2010-01  오세아니아
# 31        독일    5838    255    24     68   1458    7643  2010-01     유럽
# 30        영국    5746    383     4     20   1368    7521  2010-01     유럽
# 47       러시아    4861    505    15     83   5409   10873  2010-01     유럽
# 26       캐나다    4912     96     4     21   3743    8776  2010-01   아메리카
# 8       싱가포르    4201    120     3     27   1017    5368  2010-01    아시아
# 6        필리핀    3984    219   104     87  16820   21214  2010-01    아시아
# 32       프랑스    3019    343    44    115   1145    4666  2010-01     유럽
# 5      말레이시아    3292     61     0     49   1157    4559  2010-01    아시아
# 16        몽골    2333    234     6    197    554    3324  2010-01    아시아
# 7      인도네시아    1840    327     3     65   2826    5061  2010-01    아시아
# 11        인도    1646   1387     7     68   2918    6026  2010-01    아시아
# 54      뉴질랜드    1545     53     1      1    435    2035  2010-01  오세아니아
# 36      이탈리아    1157     40    12     12    155    1376  2010-01     유럽
# 10       베트남    1384    284    21    150   2676    4515  2010-01    아시아
# 33      네덜란드    1205     47     1     20    449    1722  2010-01     유럽
# 52     구주 기타    1219     37     0     49    410    1715  2010-01     유럽
# 9        미얀마     630     18    54     10   3882    4594  2010-01    아시아
# 24    아시아 기타     700    629    14     56    333    1732  2010-01    아시아
# 19      이스라엘     792     11     0      0     53     856  2010-01    아시아
# 55    대양주 기타     730      0     4      4    168     906  2010-01  오세아니아
# 39       벨기에     322     25     1      8    104     460  2010-01     유럽
# 46     우크라이나     386     29     0      6   1515    1936  2010-01     유럽
# 45      아일랜드     311     16     0      1    198     526  2010-01     유럽
# 44       핀란드     376     16     0     12    131     535  2010-01     유럽
# 43      포르투갈     256      9     0      1     44     310  2010-01     유럽
# 51       폴란드     378     29     0     10    431     848  2010-01     유럽
# 3        마카오     554      0     0      0      0     554  2010-01    아시아
# 56  남아프리카공화국     214     27     0      2    545     788  2010-01   아프리카
# 42       그리스     345     47     0      0    213     605  2010-01     유럽
# 57   아프리카 기타     349    594    25     86    296    1350  2010-01   아프리카
# 41       스페인     542     29    11      8    108     698  2010-01     유럽
# 40     오스트리아     440     13     2      9    141     605  2010-01     유럽
# 34       스웨덴     579     63     5     17    185     849  2010-01     유럽
# 38      노르웨이     517    274     0      6    149     946  2010-01     유럽
# 35       스위스     512     30     0      7     77     626  2010-01     유럽
# 29     미주 기타     501     25     8     29    291     854  2010-01   아메리카
# 28       브라질     459     46     1     11    248     765  2010-01   아메리카
# 27       멕시코     252     29     1      4     93     379  2010-01   아메리카
# 23       GCC     223    134     0     18     55     430  2010-01    아시아
# 22     카자흐스탄     238     48     4     22    107     419  2010-01    아시아
# 37       덴마크     378     28     0      5     94     505  2010-01     유럽
# 20        터키     472     15     2     15    465     969  2010-01    아시아
# 15      캄보디아     102     22     0     25    131     280  2010-01    아시아
# 58      국적미상      10      3     0      0      0      13  2010-01   기타대륙
# 12      스리랑카      39     28     2     13    566     648  2010-01    아시아
# 13      파키스탄      70    200     1     41    402     714  2010-01    아시아
# 14     방글라데시      86     84     9     42    489     710  2010-01    아시아
# 50      불가리아     103      0     0      9    414     526  2010-01     유럽
# 18        이란      69    309     0      3    217     598  2010-01    아시아
# 21    우즈베키스탄     190    293    17     40    740    1280  2010-01    아시아
# 49      루마니아     142     12     0      9    370     533  2010-01     유럽
# 48     크로아티아     166     20     0      1    298     485  2010-01     유럽
# 59        교포       0      0     0      0  22537   22537  2010-01     교포
#
#     관광객비율(%)  전체비율(%)
# 0       97.0     50.6
# 17      44.3     10.1
# 1       98.3      8.9
# 25      62.6      6.7
# 2       95.4      3.5
# 4       75.1      3.3
# 53      82.7      1.7
# 31      76.4      1.5
# 30      76.4      1.4
# 47      44.7      1.2
# 26      56.0      1.2
# 8       78.3      1.0
# 6       18.8      1.0
# 32      64.7      0.8
# 5       72.2      0.8
# 16      70.2      0.6
# 7       36.4      0.5
# 11      27.3      0.4
# 54      75.9      0.4
# 36      84.1      0.3
# 10      30.7      0.3
# 33      70.0      0.3
# 52      71.1      0.3
# 9       13.7      0.2
# 24      40.4      0.2
# 19      92.5      0.2
# 55      80.6      0.2
# 39      70.0      0.1
# 46      19.9      0.1
# 45      59.1      0.1
# 44      70.3      0.1
# 43      82.6      0.1
# 51      44.6      0.1
# 3      100.0      0.1
# 56      27.2      0.1
# 42      57.0      0.1
# 57      25.9      0.1
# 41      77.7      0.1
# 40      72.7      0.1
# 34      68.2      0.1
# 38      54.7      0.1
# 35      81.8      0.1
# 29      58.7      0.1
# 28      60.0      0.1
# 27      66.5      0.1
# 23      51.9      0.1
# 22      56.8      0.1
# 37      74.9      0.1
# 20      48.7      0.1
# 15      36.4      0.0
# 58      76.9      0.0
# 12       6.0      0.0
# 13       9.8      0.0
# 14      12.1      0.0
# 50      19.6      0.0
# 18      11.5      0.0
# 21      14.8      0.0
# 49      26.6      0.0
# 48      34.2      0.0
# 59       0.0      0.0

# %% [markdown]
# # 데이터 전처리
#
# - 모든 파일에 대해 같은 작업을 반복해야 하기 때문에 함수로 정리해야함

# %%
def create_kto_data(yy, mm):
    # 1. 불러올 엑셀 파일 경로를 지정
    file_path = f"./data/실습데이터/kto_{yy}{mm}.xlsx"
    
    # 2. 엑셀 파일 불러오기
    df = pd.read_excel(file_path, usecols = "A:G", header = 1, skipfooter = 4)
    
    # 3. "기준년월" 컬럼 추가
    df["기준년월"] = f"{yy}-{mm}"
    
    # 4. "국적" 컬럼에서 대륙 제거하고 국가만 남기기
    # 제거할 대륙명 선정
    ignore_list = ["아시아주", "미주", "구주", "대양주", "아프리카주", "기타대륙", "교포소계"]
    condition = (df["국적"].isin(ignore_list) == False) # 대륙이 미포함된 데이터만 추출
    df_country = df[condition].reset_index(drop = True)
    
    # 5. "대륙" 컬럼 추가
    continents = ["아시아"] * 25 + ["아메리카"] * 5 + ["유럽"] * 23 + ["오세아니아"] * 3 + ["아프리카"] * 2 + ["기타대륙"] +  ["교포"]
    df_country["대륙"] = continents
    
    # 6. 국가별 "관광객비율(%)" 컬럼 추가
    df_country["관광객비율(%)"] = round(df_country["관광"] / df_country["계"] * 100, 1)
    
    # 7. "전체비율(%)" 컬럼 추가
    tourist_sum = sum(df_country["관광"])
    df_country["전체비율(%)"] = round(df_country["관광"] / tourist_sum * 100, 1)
    
    return df_country

# %%
"1".zfill(2)
# Out:
# '01'

# %%
# 2020년 2월 데이터로 함수 테스트
kto_test = create_kto_data(2010, "2".zfill(2))

# %%
kto_test
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 0         일본  224475  1455    63   1172   3197  230362  2010-02    아시아
# 1         대만   35758    45    18    234    596   36651  2010-02    아시아
# 2         홍콩   22462    47     0     65    477   23051  2010-02    아시아
# 3        마카오     916     0     0      2      0     918  2010-02    아시아
# 4         태국   12358    33    36    131   4125   16683  2010-02    아시아
# 5      말레이시아    5914    58     3    358   1150    7483  2010-02    아시아
# 6        필리핀    4638   225    47     90  15411   20411  2010-02    아시아
# 7      인도네시아    2142   235     7    164   2374    4922  2010-02    아시아
# 8       싱가포르    4677   112     4     77    928    5798  2010-02    아시아
# 9        미얀마     584    19     3     35   3823    4464  2010-02    아시아
# 10       베트남    2447   235     9    755   3303    6749  2010-02    아시아
# 11        인도     951  1540     5    140   2803    5439  2010-02    아시아
# 12      스리랑카      68    36     3     18    571     696  2010-02    아시아
# 13      파키스탄      78   199     1     77    431     786  2010-02    아시아
# 14     방글라데시      78   102    12    100    367     659  2010-02    아시아
# 15      캄보디아     195    21     2     65    116     399  2010-02    아시아
# 16        몽골    2320   199     5    491    567    3582  2010-02    아시아
# 17        중국   60590  7907    68  29546  42460  140571  2010-02    아시아
# 18        이란      44   271     1     17    158     491  2010-02    아시아
# 19      이스라엘     800     5     2      3     34     844  2010-02    아시아
# 20        터키     418    17    12     43    384     874  2010-02    아시아
# 21    우즈베키스탄     205   296    22     59    714    1296  2010-02    아시아
# 22     카자흐스탄     168    80     0    101    120     469  2010-02    아시아
# 23       GCC     305   101     5     24     37     472  2010-02    아시아
# 24    아시아 기타     534   473    36    143    250    1436  2010-02    아시아
# 25        미국   26268   997  1315    391  12106   41077  2010-02   아메리카
# 26       캐나다    5033    68     1     31   3370    8503  2010-02   아메리카
# 27       멕시코     287     8     1     26    107     429  2010-02   아메리카
# 28       브라질     442    45     2     21    282     792  2010-02   아메리카
# 29     미주 기타     578    13     5     68    291     955  2010-02   아메리카
# 30        영국    4958   280     4     21   1207    6470  2010-02     유럽
# 31        독일    4849   157    12    150   1318    6486  2010-02     유럽
# 32       프랑스    2831   253    35    230    903    4252  2010-02     유럽
# 33      네덜란드     960    26     1     34    359    1380  2010-02     유럽
# 34       스웨덴     634    52     8     36    125     855  2010-02     유럽
# 35       스위스     454    14     0     18     48     534  2010-02     유럽
# 36      이탈리아    1106    28     2     19    101    1256  2010-02     유럽
# 37       덴마크     338    21     0      7    104     470  2010-02     유럽
# 38      노르웨이     474   241     0     12     87     814  2010-02     유럽
# 39       벨기에     324    17     1      8    100     450  2010-02     유럽
# 40     오스트리아     435    10     3     24    107     579  2010-02     유럽
# 41       스페인     478    11     5     25     81     600  2010-02     유럽
# 42       그리스     230    29     0      1    184     444  2010-02     유럽
# 43      포르투갈     370     7     0      1     37     415  2010-02     유럽
# 44       핀란드     354    10     1     57    129     551  2010-02     유럽
# 45      아일랜드     283     8     0      6    214     511  2010-02     유럽
# 46     우크라이나     318    15     0     23   1259    1615  2010-02     유럽
# 47       러시아    3156   429     8    220   4861    8674  2010-02     유럽
# 48     크로아티아     195    12     3      1    286     497  2010-02     유럽
# 49      루마니아     173     9     0      2    283     467  2010-02     유럽
# 50      불가리아     104     0     0      9    434     547  2010-02     유럽
# 51       폴란드     321     7     0     28    395     751  2010-02     유럽
# 52     구주 기타     914    23     0     86    457    1480  2010-02     유럽
# 53   오스트레일리아    4516   390    29     36    986    5957  2010-02  오세아니아
# 54      뉴질랜드    1056    41     1      4    385    1487  2010-02  오세아니아
# 55    대양주 기타     264     0     0      5    140     409  2010-02  오세아니아
# 56  남아프리카공화국     278    24     0      2    572     876  2010-02   아프리카
# 57   아프리카 기타     413   588    25    147    301    1474  2010-02   아프리카
# 58      국적미상       6     0     0      1      3      10  2010-02   기타대륙
# 59        교포       0     0     0      0  21338   21338  2010-02     교포
#
#     관광객비율(%)  전체비율(%)
# 0       97.4     50.3
# 1       97.6      8.0
# 2       97.4      5.0
# 3       99.8      0.2
# 4       74.1      2.8
# 5       79.0      1.3
# 6       22.7      1.0
# 7       43.5      0.5
# 8       80.7      1.0
# 9       13.1      0.1
# 10      36.3      0.5
# 11      17.5      0.2
# 12       9.8      0.0
# 13       9.9      0.0
# 14      11.8      0.0
# 15      48.9      0.0
# 16      64.8      0.5
# 17      43.1     13.6
# 18       9.0      0.0
# 19      94.8      0.2
# 20      47.8      0.1
# 21      15.8      0.0
# 22      35.8      0.0
# 23      64.6      0.1
# 24      37.2      0.1
# 25      63.9      5.9
# 26      59.2      1.1
# 27      66.9      0.1
# 28      55.8      0.1
# 29      60.5      0.1
# 30      76.6      1.1
# 31      74.8      1.1
# 32      66.6      0.6
# 33      69.6      0.2
# 34      74.2      0.1
# 35      85.0      0.1
# 36      88.1      0.2
# 37      71.9      0.1
# 38      58.2      0.1
# 39      72.0      0.1
# 40      75.1      0.1
# 41      79.7      0.1
# 42      51.8      0.1
# 43      89.2      0.1
# 44      64.2      0.1
# 45      55.4      0.1
# 46      19.7      0.1
# 47      36.4      0.7
# 48      39.2      0.0
# 49      37.0      0.0
# 50      19.0      0.0
# 51      42.7      0.1
# 52      61.8      0.2
# 53      75.8      1.0
# 54      71.0      0.2
# 55      64.5      0.1
# 56      31.7      0.1
# 57      28.0      0.1
# 58      60.0      0.0
# 59       0.0      0.0

# %% [markdown]
# # 반복문을 통해 다수의 엑셀 데이터를 불러와서 합치기

# %%
df = pd.DataFrame()

for yy in range(2010, 2021):
    for mm in range(1, 13):
        tmp = create_kto_data(str(yy), str(mm).zfill(2))
        df = pd.concat([df, tmp], ignore_index = True)
        if yy == 2020 and mm == 5:
            break

# %%
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  전체비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0     50.6
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3      8.9
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4      3.5
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0      0.1
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1      3.3

# %%
df.tail()
# Out:
#             국적  관광  상용  공용  유학/연수   기타    계     기준년월     대륙  관광객비율(%)  전체비율(%)
# 7495    대양주 기타   1   0   1      0    3    5  2020-05  오세아니아      20.0      0.0
# 7496  남아프리카공화국   1   0   3      0   25   29  2020-05   아프리카       3.4      0.0
# 7497   아프리카 기타   3   1   3      6  118  131  2020-05   아프리카       2.3      0.0
# 7498      국적미상   1   0   0      0    3    4  2020-05   기타대륙      25.0      0.0
# 7499        교포   0   0   0      0  790  790  2020-05     교포       0.0      0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        7500 non-null   object
#  1   관광        7500 non-null   int64
#  2   상용        7500 non-null   int64
#  3   공용        7500 non-null   int64
#  4   유학/연수     7500 non-null   int64
#  5   기타        7500 non-null   int64
#  6   계         7500 non-null   int64
#  7   기준년월      7500 non-null   object
#  8   대륙        7500 non-null   object
#  9   관광객비율(%)  7500 non-null   float64
#  10  전체비율(%)   7500 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 644.7+ KB

# %%
# 통합 데이터 저장
df.to_excel("kto_total.xlsx", index = False)

# %% [markdown]
# # 데이터 분석

# %% [markdown]
# ## 꺾은선 그래프

# %%
# 중국 국적 데이터 필터링
df_filter = df[df["국적"] == "중국"]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)
# 17      10.1
# 77      13.6
# 137      9.2
# 197     15.5
# 257     17.0

# %%
x_tick = [f"{i}-01" for i in range(2010, 2021)]

# %%
plt.figure(figsize = (12, 4))

plt.plot(df_filter["기준년월"], df_filter["관광"])
plt.title("중국 국적의 관광객 추이")
plt.xlabel("기준년월")
plt.ylabel("관광객수")
plt.xticks(x_tick)

plt.show()

# %%
country_list = ["일본", "중국", "대만", "미국", "홍콩"]

# %%
for country in country_list:
    # 해당 국적 관광객만 필터링
    df_filter = df[df["국적"] == country]
    
    # 그래프
    plt.figure(figsize = (12, 4))

    plt.plot(df_filter["기준년월"], df_filter["관광"])
    plt.title(f"{country} 국적의 관광객 추이")
    plt.xlabel("기준년월")
    plt.ylabel("관광객수")
    plt.xticks(x_tick)

    plt.show()

# %% [markdown]
# ## 히트맵
#
# - x축에 month, y축에 year을 넣고 내용에는 관광객 숫자가 들어가는 히트맵

# %%
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  전체비율(%)
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0     50.6
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3      8.9
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4      3.5
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0      0.1
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1      3.3

# %%
df["년도"] = df["기준년월"].str.slice(0, 4)
df["월"] = df["기준년월"].str.slice(5, 7)

# %%
df.head()
# Out:
#     국적      관광    상용  공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  202825  1750  89    549  3971  209184  2010-01  아시아      97.0
# 1   대만   35788    41  17     37   516   36399  2010-01  아시아      98.3
# 2   홍콩   13874    55   0     21   595   14545  2010-01  아시아      95.4
# 3  마카오     554     0   0      0     0     554  2010-01  아시아     100.0
# 4   태국   13374    39  13     53  4335   17814  2010-01  아시아      75.1
#
#    전체비율(%)    년도   월
# 0     50.6  2010  01
# 1      8.9  2010  01
# 2      3.5  2010  01
# 3      0.1  2010  01
# 4      3.3  2010  01

# %%
# 중국 데이터 필터링
df_filter = df[df["국적"] == "중국"]

# %%
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)    년도   월
# 17      10.1  2010  01
# 77      13.6  2010  02
# 137      9.2  2010  03
# 197     15.5  2010  04
# 257     17.0  2010  05

# %%
df_pivot = df_filter.pivot_table(index = "년도", columns = "월", values = "관광")
df_pivot
# Out:
# 월           01        02        03        04        05        06        07  \
# 년도
# 2010   40425.0   60590.0   50330.0   84252.0   89056.0   87080.0  122432.0
# 2011   55070.0   53863.0   72003.0   86397.0   85668.0  108060.0  170524.0
# 2012  106606.0   74895.0  110965.0  166843.0  154841.0  179074.0  258907.0
# 2013  148118.0  169395.0  182850.0  250549.0  196306.0  280319.0  417991.0
# 2014  230706.0  219533.0  313400.0  429419.0  410971.0  429991.0  540683.0
# 2015  327225.0  413096.0  386386.0  536428.0  517154.0  223101.0  172075.0
# 2016  456636.0  424232.0  500018.0  601460.0  614636.0  671493.0  823016.0
# 2017  489256.0  458952.0  263788.0  158784.0  172527.0  181507.0  207099.0
# 2018  236825.0  237075.0  281020.0  283533.0  284317.0  303405.0  332657.0
# 2019  320113.0  324291.0  369165.0  410542.0  413949.0  395196.0  439699.0
# 2020  393336.0   49520.0    5040.0     522.0     179.0       NaN       NaN
#
# 월           08        09        10        11        12
# 년도
# 2010  142180.0   93545.0  107237.0   75686.0   58987.0
# 2011  178937.0  144704.0  141824.0  113856.0  101605.0
# 2012  268988.0  203857.0  204866.0  155503.0  148320.0
# 2013  472005.0  353359.0  249850.0  208175.0  210950.0
# 2014  588181.0  423133.0  459708.0  381118.0  345957.0
# 2015  372990.0  453670.0  518651.0  409635.0  381722.0
# 2016  747818.0  611538.0  588561.0  452082.0  456882.0
# 2017  226153.0  229172.0  244541.0  223743.0  260983.0
# 2018  360982.0  326438.0  382922.0  327664.0  345135.0
# 2019  451570.0  432018.0  476460.0  426849.0  433577.0
# 2020       NaN       NaN       NaN       NaN       NaN

# %%
plt.figure(figsize = (16, 10))

sns.heatmap(df_pivot, annot = True, fmt = ".0f", cmap = "rocket_r")

plt.title("중국 관광객 히트맵")

plt.show()

# %%
for country in country_list:
    df_filter = df[df["국적"] == country]
    
    df_pivot = df_filter.pivot_table(index = "년도", columns = "월", values = "관광")
    
    plt.figure(figsize = (16, 10))

    sns.heatmap(df_pivot, annot = True, fmt = ".0f", cmap = "rocket_r")

    plt.title(f"{country} 관광객 히트맵")

    plt.show()

# %% [markdown]
# # 시각화 해석
#
# - 중국인 그래프에서 보이는 특징
#     - 2010년부터 2016년까지 관광객 수가 꾸준히 증가하는 추세
#     - 2017년 초에 관광객 수가 큰 폭으로 감소
#     - 2017년 중순부터 관광객 수가 완만하게 증가하는 추세
#     - 매년 여름에 관광객 수가 최댓값을 가짐
#     - 단, 2015년 여름에는 관광객 수가 큰 폭으로 감소
#     - 2020년 초에 관광객 수가 0에 가까워질만큼 급격히 감소
#
#     - 계절적 특징
#         - 여름 > 봄, 가을 > 겨울 순으로 많이 방문함
#
#     - 트렌드
#         - 중국인 관광객 수가 계속 증가
#
#     - 이벤트
#         - 2015년 여름, 2017년 3월, 2020년 2월에 부정적인 이벤트가 있음
